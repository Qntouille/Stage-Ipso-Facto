# %%
# Nettoyage complet
print("Nettoyage...")
# %reset -f

# %whos
# Out:
# Nettoyage...
# Interactive namespace is empty.

# %% [markdown]
# **Connexion à LGPDEV et nettoyage des tables de la BDD**

# %%
# Import de tout ce qui pourra être utile
import logging
logging.getLogger("cmdstanpy").setLevel(logging.WARNING)
logging.basicConfig(level=logging.WARNING)
import os
os.environ['CMDSTANPY_LOGGING'] = 'CRITICAL'
os.environ['CMDSTANPY_SHOW_PROGRESS'] = 'False'
from datetime import datetime, timedelta # Important pour manipuler des dates
import pandas as pd # Bibliothèque complète pour la manipulation de dataframes
import matplotlib.pyplot as plt # Pour tracer des graphiques
import numpy as np # Pour manipuler des tableaux, formatage différent de celui de pandas
import pmdarima as pmd # Pour effectuer des analyses de séries temporelles avec des modèles ARIMA
from sqlalchemy import create_engine # Pour créer une connexion à la BDD
from sqlalchemy.engine import URL # Pareil
from sqlalchemy import text # Pareil
import sqlalchemy # Pareil
import pyodbc # Pareil
from collections import Counter
from scipy.stats import skew, kurtosis
from prophet import serialize
serialize.USE_STAN_BACKEND = 'pystan'
from prophet import Prophet
from pandas.api.types import is_datetime64_any_dtype as is_datetime # Pour manipuler des dates
from statsmodels.stats.diagnostic import acorr_ljungbox # Pour tester l'autocorrélation des résidus d'une série temporelle
from sklearn.metrics import mean_squared_error # Pour calculer l'erreur quadratique moyenne d'un modèle
from scipy import stats # Data science
import warnings # Permettra de cacher certains messages d'avertissement qui encombrent les outputs
from prophet.diagnostics import cross_validation, performance_metrics # Pour évaluer la robustesse et la performance des résultats d'un modèle
import contextlib 
import io
for lib in ['cmdstanpy', 'prophet'] :
    logger = logging.getLogger(lib)
    logger.handlers = []
    logger.setLevel(logging.CRITICAL)
import subprocess
import sys
import re
import time
import cmdstanpy
from scipy.stats import linregress
from statsmodels.tsa.stattools import adfuller
from scipy.fft import fft
from scipy.stats import entropy

# %%
# Connexion pyodbc à SQL Server

conn_str = (
    "DRIVER={ODBC Driver 17 for SQL Server};"
    "SERVER=172.16.11.34;"
    "DATABASE=Superset;"
    "UID=quentin;"
    "PWD={Barbidur1;SQL}"
)

conn = pyodbc.connect(conn_str)
cursor = conn.cursor()

# Suppression systématique du contenu existant dans les deux tables
# Le but est de les remplir par la suite avec les noms et identifiants des graphiques de base ("historiques") puis avec
# les données de prévisions

print(f"Suppression du contenu de la table previsions_graphiques...")
cursor.execute(f"DELETE FROM previsions_graphiques")
print(f"Suppression du contenu de la table previsions_graphiques_noms...")
cursor.execute(f"DELETE FROM previsions_graphiques_noms")
conn.commit()

print("Normalement à ce stade les tables sont totalement vides")
# Out:
# Suppression du contenu de la table dbo.t_graphique_donnee...
# Suppression du contenu de la table dbo.tr_graphique...
# Normalement à ce stade les tables sont totalement vides

# %%
# Remplissage de la table dbo.tr_graphique : on y met les noms et identifiants des graphiques de données historiques

# C'est ce tableau qu'on modifie si on veut référencer ici une nouvelle série temporelle potentiellement exploitable
# pour la prévision, ou si on veut changer le numéro auquel correspond un graphique de données historiques (en cas de 
# suppression dans Superset d'un graphique historique qu'on recrée ensuite, son identifiant ne sera plus le même !)

libelles = [
    (146, "Action proposition et visite"),
    (147, "Nombre de transactions par négociateur"),
    (148, "Stock de demande par négociateur en surface"),
    (149, "Stock de demande par négociateur en nombre"),
    (150, "Stock d'offre par négociateur en surface"),
    (151, "Stock d'offre par négociateur en nombre"),
    (152, "Offres entrées"),
    (153, "Demandes entrées"),
    (154, "Nombre de plaintes et de désinscriptions"),
    (155, "Total emails envoyés"),
    (156, "Actions générales"),
    (157, "Evolution nombre de mails par opération"),
    (158, "Evolution activité globale"),
    (159, "Evolution activité de marché"),
    (160, "Analyse des erreurs"),
    (161, "Analyse des retours"),
    (162, "Origine des demandes"),
    (163, "Origine des offres"),
    (164, "Stock de mandats actifs"),
    (165, "Offres actives"),
    (166, "Demandes actives")
]

# Insertion SQL des noms et ids des graphiques historiques

for graphique_id, libelle in libelles :
    cursor.execute(
        "INSERT INTO previsions_graphiques_noms (graphique_id, gra_libelle) VALUES (?, ?)",
        (graphique_id, libelle)
    )
conn.commit()

cursor.close()
conn.close()

print("Normalement à ce stade la table previsions_graphiques_noms contient les noms et identifiants des graphiques")
# Out:
# Normalement à ce stade la table dbo.tr_graphique contient les noms et identifiants des graphiques
# (La connexion est toujours ouverte)

# %% [markdown]
# **Import et nettoyage des données**

# %%
# On commence par remonter les requêtes des datasets
# Ces requêtes sont des copié / collés des requêtes utilisées dans Superset pour créer les datasets utilisés pour générer
# les graphiques historiques. On remanipule ces datasets pour les mettre sous un format plus exploitable pour la prévision
# dans la suite de ce programme.

# Action proposition et visite
requete146 = """
SELECT
  A.groupe_id,
  CAST(A.act_date AS DATE) AS jour,
  AG.age_nom AS agence_nom,
  CASE A.action_type_id
    WHEN 1 THEN 'Visite'
    WHEN 2 THEN 'Visite Confrère'
    WHEN 3 THEN 'Proposition'
    WHEN 4 THEN 'Rdv Présentation'
    ELSE 'Autre'
  END AS type_action,
  COUNT(DISTINCT A.action_id) AS total_actions
FROM t_action A
  INNER JOIN t_negociateur N ON A.negociateur_id = N.negociateur_id
  INNER JOIN t_agence AG ON N.agence_id = AG.agence_id
  INNER JOIN tj_action_offre AO ON AO.action_id = A.action_id
  INNER JOIN t_offre O ON AO.offre_id = O.offre_id
  INNER JOIN tr_nature_offre NO ON NO.nature_offre_id = O.nature_offre_id AND NO.langue_id = 1
  INNER JOIN t_adresse AD ON AD.adresse_id = O.adresse_id
WHERE
  A.act_date BETWEEN DATEADD(YEAR, -17, GETDATE()) AND GETDATE()
  AND A.action_type_id IN (1, 2, 3, 4)
GROUP BY
  A.groupe_id,
  CAST(A.act_date AS DATE),
  AG.age_nom,
  CASE A.action_type_id
    WHEN 1 THEN 'Visite'
    WHEN 2 THEN 'Visite Confrère'
    WHEN 3 THEN 'Proposition'
    WHEN 4 THEN 'Rdv Présentation'
    ELSE 'Autre'
  END
"""

# Nombre de transactions par négociateur
requete147 = """ 
SELECT
    CAST(T.tra_date_signature AS DATE) AS jour,
    T.groupe_id,
    T.negociateur_id,
    N.neg_nom + ' ' + N.neg_prenom AS negociateur_nom,
    A.agence_id,
    A.age_nom AS agence_nom,
    COUNT(DISTINCT T.transaction_id) AS nb_transactions
FROM t_transaction T
INNER JOIN t_negociateur N ON T.negociateur_id = N.negociateur_id
INNER JOIN t_agence A ON N.agence_id = A.agence_id
WHERE
    T.tra_actif = 1
    AND T.tra_date_signature BETWEEN DATEADD(YEAR, -17, CAST(GETDATE() AS DATE)) AND CAST(GETDATE() AS DATE)
GROUP BY
    CAST(T.tra_date_signature AS DATE),
    T.groupe_id,
    T.negociateur_id,
    N.neg_nom,
    N.neg_prenom,
    A.agence_id,
    A.age_nom
"""

# Stock de demande par négociateur, en nombre et en surface
requete148et149 = """ 
SELECT 
  D.groupe_id,
  CAST(D.dem_date_creation AS DATE) AS jour,
  N.negociateur_id,
  N.agence_id,
  A.age_nom AS agence_nom,
  N.neg_nom + ' ' + N.neg_prenom AS negociateur_nom,
  COUNT(DISTINCT D.demande_id) AS nb_demandes,
  CAST(SUM(ISNULL(D.dem_recherche_surface_minimum1, 0)) AS BIGINT) AS surface_totale
FROM t_demande D
INNER JOIN tj_demande_negociateur DN ON DN.demande_id = D.demande_id
INNER JOIN t_negociateur N ON DN.negociateur_id = N.negociateur_id
INNER JOIN t_agence A ON N.agence_id = A.agence_id
WHERE 
  D.dem_date_creation BETWEEN DATEADD(YEAR, -17, GETDATE()) AND GETDATE()
GROUP BY 
  D.groupe_id,
  CAST(D.dem_date_creation AS DATE),
  N.negociateur_id,
  N.agence_id,
  A.age_nom,
  N.neg_nom,
  N.neg_prenom
"""

# Stock d'offre par négociateur, en nombre et en surface
requete150et151 = """ 
SELECT 
  O.groupe_id,
  CAST(COALESCE(O.off_date_creation, O.off_date_reactivation) AS DATE) AS jour,
  N.negociateur_id,
  N.agence_id,
  A.age_nom AS agence_nom,
  LTRIM(RTRIM(N.neg_nom)) + ' ' + LTRIM(RTRIM(N.neg_prenom)) AS negociateur_nom,
  COUNT(DISTINCT O.offre_id) AS nb_offres,
  CAST(ROUND(SUM(ISNULL(O.off_surface_totale, 0)), 0) AS BIGINT) AS surface_totale
FROM t_offre O
INNER JOIN tj_offre_negociateur ONEG ON ONEG.offre_id = O.offre_id
INNER JOIN t_negociateur N ON ONEG.negociateur_id = N.negociateur_id
INNER JOIN t_agence A ON N.agence_id = A.agence_id
WHERE 
  COALESCE(O.off_date_creation, O.off_date_reactivation) BETWEEN DATEADD(YEAR, -17, GETDATE()) AND GETDATE()
GROUP BY 
  O.groupe_id,
  CAST(COALESCE(O.off_date_creation, O.off_date_reactivation) AS DATE),
  N.negociateur_id,
  N.agence_id,
  A.age_nom,
  N.neg_nom,
  N.neg_prenom
"""

# Offres entrées 
requete152 = """ 
SELECT 
  CAST(
    CASE 
      WHEN O.off_date_creation BETWEEN DATEADD(YEAR, -17, CAST(GETDATE() AS DATE)) AND CAST(GETDATE() AS DATE)
        THEN O.off_date_creation
      ELSE O.off_date_reactivation
    END AS DATE
  ) AS jour,
  O.groupe_id,
  N.negociateur_id,
  A.agence_id,
  A.age_nom AS agence_nom,
  LTRIM(RTRIM(N.neg_nom)) + ' ' + LTRIM(RTRIM(N.neg_prenom)) AS negociateur_nom,
  COUNT(DISTINCT O.offre_id) AS nb_offres
FROM t_offre O
JOIN tj_offre_negociateur ONEG ON ONEG.offre_id = O.offre_id
JOIN t_negociateur N ON ONEG.negociateur_id = N.negociateur_id
JOIN t_agence A ON N.agence_id = A.agence_id
WHERE 
  (
    O.off_date_creation BETWEEN DATEADD(YEAR, -17, CAST(GETDATE() AS DATE)) AND CAST(GETDATE() AS DATE)
    OR O.off_date_reactivation BETWEEN DATEADD(YEAR, -17, CAST(GETDATE() AS DATE)) AND CAST(GETDATE() AS DATE)
  )
  AND N.neg_actif = 1
GROUP BY 
  CAST(
    CASE 
      WHEN O.off_date_creation BETWEEN DATEADD(YEAR, -17, CAST(GETDATE() AS DATE)) AND CAST(GETDATE() AS DATE)
        THEN O.off_date_creation
      ELSE O.off_date_reactivation
    END AS DATE
  ),
  O.groupe_id,
  N.negociateur_id,
  N.neg_nom,
  N.neg_prenom,
  A.agence_id,
  A.age_nom
"""

# Demandes entrées
requete153 = """ 
SELECT 
  CAST(D.dem_date_creation AS DATE) AS jour,
  D.groupe_id,
  N.negociateur_id,
  A.agence_id,
  A.age_nom AS agence_nom,
  LTRIM(RTRIM(N.neg_nom)) + ' ' + LTRIM(RTRIM(N.neg_prenom)) AS negociateur_nom,
  COUNT(DISTINCT D.demande_id) AS nb_demandes
FROM t_demande D
JOIN tj_demande_negociateur DNEG ON DNEG.demande_id = D.demande_id
JOIN t_negociateur N ON DNEG.negociateur_id = N.negociateur_id
JOIN t_agence A ON N.agence_id = A.agence_id
WHERE 
  D.dem_date_creation BETWEEN DATEADD(YEAR, -17, CAST(GETDATE() AS DATE)) AND CAST(GETDATE() AS DATE)
  AND N.neg_actif = 1
GROUP BY 
  CAST(D.dem_date_creation AS DATE),
  D.groupe_id,
  N.negociateur_id,
  N.neg_nom,
  N.neg_prenom,
  A.agence_id,
  A.age_nom
"""

# Nombre de plaintes et de désinscriptions ET Total emails envoyés
requete154et155 = """
SELECT
  CONVERT(date, OPE.op_date_envoi) AS date_envoi,
  OP.groupe_id,
  N.negociateur_id,
  LTRIM(RTRIM(N.neg_nom)) + ' ' + LTRIM(RTRIM(N.neg_prenom)) AS negociateur_nom,
  A.agence_id,
  A.age_nom AS agence_nom,
  COUNT(DISTINCT OPE.operation_personne_id) AS total_emails,
  COUNT(DISTINCT CASE WHEN ORS_plaintes.operation_personne_id IS NOT NULL THEN OPE.operation_personne_id END) AS nb_plaintes,
  COUNT(DISTINCT CASE WHEN ORS_desabo.operation_personne_id IS NOT NULL THEN OPE.operation_personne_id END) AS nb_desinscriptions,
  CASE 
    WHEN COUNT(DISTINCT OPE.operation_personne_id) = 0 THEN 0
    ELSE ROUND(
      CAST(COUNT(DISTINCT CASE WHEN ORS_plaintes.operation_personne_id IS NOT NULL THEN OPE.operation_personne_id END) AS FLOAT) 
      * 100.0 / COUNT(DISTINCT OPE.operation_personne_id), 
      2
    )
  END AS pct_plaintes,
  CASE 
    WHEN COUNT(DISTINCT OPE.operation_personne_id) = 0 THEN 0
    ELSE ROUND(
      CAST(COUNT(DISTINCT CASE WHEN ORS_desabo.operation_personne_id IS NOT NULL THEN OPE.operation_personne_id END) AS FLOAT) 
      * 100.0 / COUNT(DISTINCT OPE.operation_personne_id), 
      2
    )
  END AS pct_desinscriptions
FROM tj_operation_personne OPE
INNER JOIN t_operation_prospect OP ON OP.operation_prospect_id = OPE.operation_prospect_id
INNER JOIN t_negociateur N ON OP.negociateur_id = N.negociateur_id
LEFT JOIN t_agence A ON N.agence_id = A.agence_id
LEFT JOIN tj_operation_retour_SMTP ORS_plaintes 
  ON OPE.operation_personne_id = ORS_plaintes.operation_personne_id 
  AND ORS_plaintes.operation_type_retour_SMTP_id = 8
LEFT JOIN tj_operation_retour_SMTP ORS_desabo 
  ON OPE.operation_personne_id = ORS_desabo.operation_personne_id 
  AND ORS_desabo.operation_type_retour_SMTP_id = 9
WHERE
  OPE.op_date_envoi IS NOT NULL
  AND CONVERT(date, OPE.op_date_envoi) BETWEEN DATEADD(YEAR, -17, CAST(GETDATE() AS DATE)) AND CAST(GETDATE() AS DATE)
GROUP BY
  CONVERT(date, OPE.op_date_envoi),
  OP.groupe_id,
  N.negociateur_id,
  N.neg_nom,
  N.neg_prenom,
  A.agence_id,
  A.age_nom
"""

# Actions générales
requete156 = """ 
WITH top_actions AS (
  SELECT
    A.groupe_id,
    AT.at_libelle AS action_type,
    AT.action_type_id,
    A.negociateur_id,
    ROW_NUMBER() OVER (
      PARTITION BY A.groupe_id, A.negociateur_id
      ORDER BY COUNT(DISTINCT A.action_id) DESC
    ) AS rn
  FROM t_action A
  INNER JOIN tr_action_type AT
    ON AT.action_type_id = A.action_type_id
    AND AT.langue_id = 1
  WHERE
    A.act_date_creation BETWEEN DATEADD(YEAR, -17, GETDATE()) AND GETDATE()
    AND A.action_type_id IS NOT NULL
  GROUP BY
    A.groupe_id,
    AT.at_libelle,
    AT.action_type_id,
    A.negociateur_id
),
filtered_actions AS (
  SELECT
    A.groupe_id,
    CAST(A.act_date_creation AS DATE) AS jour,
    A.negociateur_id,
    TA.rn,
    COUNT(DISTINCT A.action_id) AS total_actions
  FROM t_action A
  INNER JOIN top_actions TA
    ON TA.action_type_id = A.action_type_id
    AND TA.groupe_id = A.groupe_id
    AND TA.negociateur_id = A.negociateur_id
    AND TA.rn <= 5
  WHERE
    A.act_date_creation BETWEEN DATEADD(YEAR, -17, GETDATE()) AND GETDATE()
  GROUP BY
    A.groupe_id,
    CAST(A.act_date_creation AS DATE),
    A.negociateur_id,
    TA.rn
)
SELECT
  fa.groupe_id,
  fa.jour,
  fa.negociateur_id,
  LTRIM(RTRIM(N.neg_nom)) + ' ' + LTRIM(RTRIM(N.neg_prenom)) AS negociateur_nom,
  N.agence_id,
  A.age_nom AS agence_nom,
  SUM(CASE WHEN fa.rn = 1 THEN fa.total_actions ELSE 0 END) AS action1,
  SUM(CASE WHEN fa.rn = 2 THEN fa.total_actions ELSE 0 END) AS action2,
  SUM(CASE WHEN fa.rn = 3 THEN fa.total_actions ELSE 0 END) AS action3,
  SUM(CASE WHEN fa.rn = 4 THEN fa.total_actions ELSE 0 END) AS action4,
  SUM(CASE WHEN fa.rn = 5 THEN fa.total_actions ELSE 0 END) AS action5
FROM filtered_actions fa
INNER JOIN t_negociateur N ON fa.negociateur_id = N.negociateur_id
LEFT JOIN t_agence A ON N.agence_id = A.agence_id
GROUP BY
  fa.groupe_id,
  fa.jour,
  fa.negociateur_id,
  N.neg_nom,
  N.neg_prenom,
  N.agence_id,
  A.age_nom
"""

# Evolution nombre de mails par opération
requete157 = """ 
SELECT
  CONVERT(date, OPE.op_date_envoi) AS date_envoi,
  OP.groupe_id,
  N.negociateur_id,
  LTRIM(RTRIM(N.neg_nom)) + ' ' + LTRIM(RTRIM(N.neg_prenom)) AS negociateur_nom,
  A.agence_id,
  A.age_nom AS agence_nom,
  COUNT(DISTINCT OPE.operation_personne_id) AS nb_total_emails,
  COUNT(DISTINCT OPE.operation_prospect_id) AS nb_operations,
  CASE 
    WHEN COUNT(DISTINCT OPE.operation_prospect_id) = 0 THEN 0
    ELSE COUNT(DISTINCT OPE.operation_personne_id) * 1.0 / COUNT(DISTINCT OPE.operation_prospect_id)
  END AS nb_emails_par_operation
FROM tj_operation_personne OPE
INNER JOIN t_operation_prospect OP 
  ON OP.operation_prospect_id = OPE.operation_prospect_id
INNER JOIN t_negociateur N 
  ON OP.negociateur_id = N.negociateur_id
LEFT JOIN t_agence A 
  ON N.agence_id = A.agence_id
WHERE
  OPE.op_date_envoi IS NOT NULL
  AND CONVERT(date, OPE.op_date_envoi) 
      BETWEEN DATEADD(YEAR, -17, CAST(GETDATE() AS DATE)) AND CAST(GETDATE() AS DATE)
GROUP BY
  CONVERT(date, OPE.op_date_envoi),
  OP.groupe_id,
  N.negociateur_id,
  N.neg_nom,
  N.neg_prenom,
  A.agence_id,
  A.age_nom
"""

# Evolution activité globale
requete158 = """ 
WITH offres AS (
  SELECT
    jour_data.jour,
    O.groupe_id,
    N.negociateur_id,
    LTRIM(RTRIM(N.neg_nom)) + ' ' + LTRIM(RTRIM(N.neg_prenom)) AS negociateur_nom,
    A.agence_id,
    A.age_nom AS agence_nom,
    COUNT(DISTINCT O.offre_id) AS nb_offres
  FROM t_offre O
  INNER JOIN tj_offre_negociateur ONEG ON ONEG.offre_id = O.offre_id
  INNER JOIN t_negociateur N ON ONEG.negociateur_id = N.negociateur_id
  LEFT JOIN t_agence A ON N.agence_id = A.agence_id

  CROSS APPLY (
    SELECT CAST(CASE 
                  WHEN O.off_date_creation BETWEEN DATEADD(YEAR, -17, GETDATE()) AND GETDATE()
                    THEN O.off_date_creation
                  ELSE O.off_date_reactivation 
                END AS DATE) AS jour
  ) AS jour_data

  WHERE
    (O.off_date_creation BETWEEN DATEADD(YEAR, -17, GETDATE()) AND GETDATE()
     OR O.off_date_reactivation BETWEEN DATEADD(YEAR, -17, GETDATE()) AND GETDATE())
    
  GROUP BY
    jour_data.jour,
    O.groupe_id,
    N.negociateur_id,
    N.neg_nom,
    N.neg_prenom,
    A.agence_id,
    A.age_nom
),

demandes AS (
  SELECT
    CAST(D.dem_date_creation AS DATE) AS jour,
    D.groupe_id,
    N.negociateur_id,
    LTRIM(RTRIM(N.neg_nom)) + ' ' + LTRIM(RTRIM(N.neg_prenom)) AS negociateur_nom,
    A.agence_id,
    A.age_nom AS agence_nom,
    COUNT(DISTINCT D.demande_id) AS nb_demandes
  FROM t_demande D
  INNER JOIN tj_demande_negociateur DN ON DN.demande_id = D.demande_id
  INNER JOIN t_negociateur N ON DN.negociateur_id = N.negociateur_id
  LEFT JOIN t_agence A ON N.agence_id = A.agence_id
  WHERE D.dem_date_creation BETWEEN DATEADD(YEAR, -17, GETDATE()) AND GETDATE()
  GROUP BY
    CAST(D.dem_date_creation AS DATE),
    D.groupe_id,
    N.negociateur_id,
    N.neg_nom,
    N.neg_prenom,
    A.agence_id,
    A.age_nom
),

mandats AS (
  SELECT
    CAST(M.man_date_creation AS DATE) AS jour,
    A.groupe_id,
    N.negociateur_id,
    LTRIM(RTRIM(N.neg_nom)) + ' ' + LTRIM(RTRIM(N.neg_prenom)) AS negociateur_nom,
    A.agence_id,
    A.age_nom AS agence_nom,
    COUNT(DISTINCT M.mandat_id) AS nb_mandats
  FROM t_mandat M
  INNER JOIN t_negociateur N ON M.negociateur_id = N.negociateur_id
  LEFT JOIN t_agence A ON A.agence_id = M.agence_id
  WHERE M.man_date_creation BETWEEN DATEADD(YEAR, -17, GETDATE()) AND GETDATE()
  GROUP BY
    CAST(M.man_date_creation AS DATE),
    A.groupe_id,
    N.negociateur_id,
    N.neg_nom,
    N.neg_prenom,
    A.agence_id,
    A.age_nom
),

cte_union AS (
  SELECT
    COALESCE(o.jour, d.jour, m.jour) AS jour,
    COALESCE(o.groupe_id, d.groupe_id, m.groupe_id) AS groupe_id,
    COALESCE(o.negociateur_id, d.negociateur_id, m.negociateur_id) AS negociateur_id,
    COALESCE(o.negociateur_nom, d.negociateur_nom, m.negociateur_nom) AS negociateur_nom,
    COALESCE(o.agence_id, d.agence_id, m.agence_id) AS agence_id,
    COALESCE(o.agence_nom, d.agence_nom, m.agence_nom) AS agence_nom,
    ISNULL(o.nb_offres, 0) AS nb_offres,
    ISNULL(d.nb_demandes, 0) AS nb_demandes,
    ISNULL(m.nb_mandats, 0) AS nb_mandats
  FROM offres o
  FULL OUTER JOIN demandes d ON o.jour = d.jour AND o.groupe_id = d.groupe_id AND o.negociateur_id = d.negociateur_id
  FULL OUTER JOIN mandats m ON COALESCE(o.jour, d.jour) = m.jour AND COALESCE(o.groupe_id, d.groupe_id) = m.groupe_id AND COALESCE(o.negociateur_id, d.negociateur_id) = m.negociateur_id
)

SELECT
  jour,
  groupe_id,
  negociateur_id,
  negociateur_nom,
  agence_id,
  agence_nom,
  SUM(nb_offres) AS nb_offres,
  SUM(nb_demandes) AS nb_demandes,
  SUM(nb_mandats) AS nb_mandats
FROM cte_union
WHERE
  groupe_id IN (38)
  AND jour IS NOT NULL
GROUP BY
  jour,
  groupe_id,
  negociateur_id,
  negociateur_nom,
  agence_id,
  agence_nom
"""

# Evolution activité de marché
requete159 = """ 
-- Étape 1 : Prétraitement pour les offres
WITH cte_base_offres AS (
  SELECT
    O.offre_id,
    CAST(CASE 
           WHEN O.off_date_creation BETWEEN DATEADD(YEAR, -17, CAST(GETDATE() AS DATE)) AND CAST(GETDATE() AS DATE)
             THEN O.off_date_creation
           ELSE O.off_date_reactivation
         END AS DATE) AS jour,
    O.groupe_id,
    N.negociateur_id,
    LTRIM(RTRIM(N.neg_nom)) + ' ' + LTRIM(RTRIM(N.neg_prenom)) AS negociateur_nom,
    A.agence_id,
    A.age_nom AS agence_nom
  FROM t_offre O
  INNER JOIN tj_offre_negociateur ONEG ON ONEG.offre_id = O.offre_id
  INNER JOIN t_negociateur N ON ONEG.negociateur_id = N.negociateur_id
  LEFT JOIN t_agence A ON N.agence_id = A.agence_id
  INNER JOIN tr_nature_offre NO ON O.nature_offre_id = NO.nature_offre_id AND NO.langue_id = 1
  WHERE
    (O.off_date_creation BETWEEN DATEADD(YEAR, -17, GETDATE()) AND GETDATE())
    OR (O.off_date_reactivation BETWEEN DATEADD(YEAR, -17, GETDATE()) AND GETDATE())
),

cte_offres AS (
  SELECT
    jour,
    groupe_id,
    negociateur_id,
    negociateur_nom,
    agence_id,
    agence_nom,
    COUNT(DISTINCT offre_id) AS nb_offres
  FROM cte_base_offres
  GROUP BY
    jour,
    groupe_id,
    negociateur_id,
    negociateur_nom,
    agence_id,
    agence_nom
),

cte_demandes AS (
  SELECT
    CAST(D.dem_date_creation AS DATE) AS jour,
    D.groupe_id,
    N.negociateur_id,
    LTRIM(RTRIM(N.neg_nom)) + ' ' + LTRIM(RTRIM(N.neg_prenom)) AS negociateur_nom,
    A.agence_id,
    A.age_nom AS agence_nom,
    COUNT(DISTINCT D.demande_id) AS nb_demandes
  FROM t_demande D
  INNER JOIN tj_demande_negociateur DN ON DN.demande_id = D.demande_id
  INNER JOIN t_negociateur N ON DN.negociateur_id = N.negociateur_id
  LEFT JOIN t_agence A ON N.agence_id = A.agence_id
  WHERE D.dem_date_creation BETWEEN DATEADD(YEAR, -17, GETDATE()) AND GETDATE()
  GROUP BY
    CAST(D.dem_date_creation AS DATE),
    D.groupe_id,
    N.negociateur_id,
    N.neg_nom,
    N.neg_prenom,
    A.agence_id,
    A.age_nom
),

cte_mandats AS (
  SELECT
    CAST(M.man_date_creation AS DATE) AS jour,
    A.groupe_id,
    N.negociateur_id,
    LTRIM(RTRIM(N.neg_nom)) + ' ' + LTRIM(RTRIM(N.neg_prenom)) AS negociateur_nom,
    A.agence_id,
    A.age_nom AS agence_nom,
    COUNT(DISTINCT M.mandat_id) AS nb_mandats
  FROM t_mandat M
  INNER JOIN tj_mandat_offre MO ON MO.mandat_id = M.mandat_id
  INNER JOIN t_offre O ON O.offre_id = MO.offre_id
  INNER JOIN tr_nature_offre NO ON O.nature_offre_id = NO.nature_offre_id AND NO.langue_id = 1
  INNER JOIN t_negociateur N ON M.negociateur_id = N.negociateur_id
  LEFT JOIN t_agence A ON A.agence_id = M.agence_id
  WHERE M.man_date_creation BETWEEN DATEADD(YEAR, -17, GETDATE()) AND GETDATE()
  GROUP BY
    CAST(M.man_date_creation AS DATE),
    A.groupe_id,
    N.negociateur_id,
    N.neg_nom,
    N.neg_prenom,
    A.agence_id,
    A.age_nom
),

activite_marche_journaliere AS (
  SELECT
    COALESCE(o.jour, d.jour, m.jour) AS jour,
    COALESCE(o.groupe_id, d.groupe_id, m.groupe_id) AS groupe_id,
    COALESCE(o.negociateur_id, d.negociateur_id, m.negociateur_id) AS negociateur_id,
    COALESCE(o.negociateur_nom, d.negociateur_nom, m.negociateur_nom) AS negociateur_nom,
    COALESCE(o.agence_id, d.agence_id, m.agence_id) AS agence_id,
    COALESCE(o.agence_nom, d.agence_nom, m.agence_nom) AS agence_nom,
    ISNULL(o.nb_offres, 0) AS nb_offres,
    ISNULL(d.nb_demandes, 0) AS nb_demandes,
    ISNULL(m.nb_mandats, 0) AS nb_mandats
  FROM cte_offres o
  FULL OUTER JOIN cte_demandes d ON o.jour = d.jour AND o.groupe_id = d.groupe_id AND o.negociateur_id = d.negociateur_id
  FULL OUTER JOIN cte_mandats m ON COALESCE(o.jour, d.jour) = m.jour AND COALESCE(o.groupe_id, d.groupe_id) = m.groupe_id AND COALESCE(o.negociateur_id, d.negociateur_id) = m.negociateur_id
)

SELECT
  jour,
  groupe_id,
  negociateur_id,
  negociateur_nom,
  agence_id,
  agence_nom,
  SUM(nb_offres) AS nb_offres,
  SUM(nb_demandes) AS nb_demandes,
  SUM(nb_mandats) AS nb_mandats
FROM activite_marche_journaliere
WHERE jour IS NOT NULL
GROUP BY
  jour,
  groupe_id,
  negociateur_id,
  negociateur_nom,
  agence_id,
  agence_nom
"""

# Analyse des erreurs
requete160 = """ 
WITH erreurs AS (

  SELECT 
    CAST(OPE.op_date_envoi AS DATE) AS jour,
    'Rejeté' AS type_erreur, 
    OP.groupe_id, 
    N.negociateur_id,
    LTRIM(RTRIM(N.neg_nom)) + ' ' + LTRIM(RTRIM(N.neg_prenom)) AS negociateur_nom,
    A.agence_id,
    A.age_nom AS agence_nom,
    COUNT(DISTINCT ORS_rejete.operation_personne_id) AS nb
  FROM tj_operation_personne OPE
  INNER JOIN t_operation_prospect OP ON OP.operation_prospect_id = OPE.operation_prospect_id
  INNER JOIN t_negociateur N ON OP.negociateur_id = N.negociateur_id
  LEFT JOIN t_agence A ON N.agence_id = A.agence_id
  LEFT JOIN tj_operation_retour_SMTP ORS_rejete
    ON OPE.operation_personne_id = ORS_rejete.operation_personne_id
    AND ORS_rejete.operation_type_retour_SMTP_id = 2
  WHERE 
    OPE.op_date_envoi IS NOT NULL
    AND CONVERT(date, OPE.op_date_envoi) BETWEEN DATEADD(YEAR, -17, CAST(GETDATE() AS DATE)) AND CAST(GETDATE() AS DATE)
  GROUP BY 
    CAST(OPE.op_date_envoi AS DATE),
    OP.groupe_id,
    N.negociateur_id,
    N.neg_nom,
    N.neg_prenom,
    A.agence_id,
    A.age_nom

  UNION ALL

  SELECT 
    CAST(OPE.op_date_envoi AS DATE) AS jour,
    'Erreur' AS type_erreur, 
    OP.groupe_id, 
    N.negociateur_id,
    LTRIM(RTRIM(N.neg_nom)) + ' ' + LTRIM(RTRIM(N.neg_prenom)) AS negociateur_nom,
    A.agence_id,
    A.age_nom AS agence_nom,
    COUNT(DISTINCT ORS_erreur.operation_personne_id) AS nb
  FROM tj_operation_personne OPE
  INNER JOIN t_operation_prospect OP ON OP.operation_prospect_id = OPE.operation_prospect_id
  INNER JOIN t_negociateur N ON OP.negociateur_id = N.negociateur_id
  LEFT JOIN t_agence A ON N.agence_id = A.agence_id
  LEFT JOIN tj_operation_retour_SMTP ORS_erreur
    ON OPE.operation_personne_id = ORS_erreur.operation_personne_id
    AND ORS_erreur.operation_type_retour_SMTP_id = 1
  WHERE 
    OPE.op_date_envoi IS NOT NULL
    AND CONVERT(date, OPE.op_date_envoi) BETWEEN DATEADD(YEAR, -17, CAST(GETDATE() AS DATE)) AND CAST(GETDATE() AS DATE)
  GROUP BY 
    CAST(OPE.op_date_envoi AS DATE),
    OP.groupe_id,
    N.negociateur_id,
    N.neg_nom,
    N.neg_prenom,
    A.agence_id,
    A.age_nom

  UNION ALL

  SELECT 
    CAST(OPE.op_date_envoi AS DATE) AS jour,
    'NPAI' AS type_erreur, 
    OP.groupe_id, 
    N.negociateur_id,
    LTRIM(RTRIM(N.neg_nom)) + ' ' + LTRIM(RTRIM(N.neg_prenom)) AS negociateur_nom,
    A.agence_id,
    A.age_nom AS agence_nom,
    COUNT(DISTINCT ORS_hardbounce.operation_personne_id) AS nb
  FROM tj_operation_personne OPE
  INNER JOIN t_operation_prospect OP ON OP.operation_prospect_id = OPE.operation_prospect_id
  INNER JOIN t_negociateur N ON OP.negociateur_id = N.negociateur_id
  LEFT JOIN t_agence A ON N.agence_id = A.agence_id
  LEFT JOIN tj_operation_retour_SMTP ORS_hardbounce
    ON OPE.operation_personne_id = ORS_hardbounce.operation_personne_id
    AND ORS_hardbounce.operation_type_retour_SMTP_id = 3
  WHERE 
    OPE.op_date_envoi IS NOT NULL
    AND CONVERT(date, OPE.op_date_envoi) BETWEEN DATEADD(YEAR, -17, CAST(GETDATE() AS DATE)) AND CAST(GETDATE() AS DATE)
  GROUP BY 
    CAST(OPE.op_date_envoi AS DATE),
    OP.groupe_id,
    N.negociateur_id,
    N.neg_nom,
    N.neg_prenom,
    A.agence_id,
    A.age_nom
)

SELECT 
  jour,
  type_erreur, 
  groupe_id, 
  negociateur_id,
  negociateur_nom,
  agence_id,
  agence_nom,
  nb
FROM erreurs
"""

# Analyse des retours
requete161 = """ 
WITH base AS (
  SELECT
    CONVERT(date, OPE.op_date_envoi) AS jour,
    OP.groupe_id,
    N.negociateur_id,
    LTRIM(RTRIM(N.neg_nom)) + ' ' + LTRIM(RTRIM(N.neg_prenom)) AS negociateur_nom,
    A.agence_id,
    A.age_nom AS agence_nom,
    OPE.operation_personne_id,
    MAX(CASE WHEN ORS.operation_type_retour_SMTP_id = 5 THEN 1 ELSE 0 END) AS delivre,
    MAX(CASE WHEN ORS.operation_type_retour_SMTP_id = 6 THEN 1 ELSE 0 END) AS ouvert,
    MAX(CASE WHEN ORS.operation_type_retour_SMTP_id = 7 THEN 1 ELSE 0 END) AS clique
  FROM tj_operation_personne OPE
  INNER JOIN t_operation_prospect OP ON OP.operation_prospect_id = OPE.operation_prospect_id
  INNER JOIN t_negociateur N ON OP.negociateur_id = N.negociateur_id
  LEFT JOIN t_agence A ON N.agence_id = A.agence_id
  LEFT JOIN tj_operation_retour_SMTP ORS ON OPE.operation_personne_id = ORS.operation_personne_id
  WHERE 
    OPE.op_date_envoi IS NOT NULL
    AND CONVERT(date, OPE.op_date_envoi) 
        BETWEEN DATEADD(YEAR, -17, CAST(GETDATE() AS DATE)) 
        AND CAST(GETDATE() AS DATE)
  GROUP BY
    CONVERT(date, OPE.op_date_envoi),
    OP.groupe_id,
    N.negociateur_id,
    N.neg_nom,
    N.neg_prenom,
    A.agence_id,
    A.age_nom,
    OPE.operation_personne_id
),

catégories AS (
  SELECT
    jour,
    groupe_id,
    negociateur_id,
    negociateur_nom,
    agence_id,
    agence_nom,
    CASE
      WHEN clique = 1 THEN 'Cliqués'
      WHEN ouvert = 1 THEN 'Ouverts'
      WHEN delivre = 1 THEN 'Délivrés'
      ELSE 'Rejetés'
    END AS type_retour
  FROM base
)

SELECT
  jour,
  groupe_id,
  negociateur_id,
  negociateur_nom,
  agence_id,
  agence_nom,
  type_retour,
  COUNT(*) AS nb
FROM catégories
GROUP BY 
  jour,
  groupe_id,
  negociateur_id,
  negociateur_nom,
  agence_id,
  agence_nom,
  type_retour
"""

# Pas très intéressant a priori de prévoir les origines d'offres et de demandes, surtout que par origine, il y en a trop peu

# Stock de mandats actifs
requete164 = """ 
WITH mois_actifs AS (
  -- Génère les mois entre début et fin du filtre; Superset gère cela via le time grain
  SELECT
    DATEADD(MONTH, DATEDIFF(MONTH, 0, CAST(GETDATE() AS DATE)) - n, 0) AS mois
  FROM (
    SELECT TOP (204) ROW_NUMBER() OVER (ORDER BY (SELECT NULL)) - 1 AS n
    FROM master..spt_values
  ) numbers
),

mandats_base AS (
  SELECT
    A.groupe_id,
    N.negociateur_id,
    LTRIM(RTRIM(N.neg_nom)) + ' ' + LTRIM(RTRIM(N.neg_prenom)) AS negociateur_nom,
    A.agence_id,
    A.age_nom AS agence_nom,
    M.mandat_type_id,
    CASE 
      WHEN MT.man_location_vente = 1 THEN MT.man_libelle ELSE 'Demande'
    END AS mandat_type,
    M.man_date_debut,
    M.man_date_fin
  FROM t_mandat M
  JOIN t_negociateur N ON M.negociateur_id = N.negociateur_id
  JOIN t_agence A ON A.agence_id = M.agence_id
  JOIN tr_mandat_type MT 
    ON MT.mandat_type_id = M.mandat_type_id AND MT.langue_id = 1
  WHERE M.man_date_fin >= DATEADD(YEAR, -17, CAST(GETDATE() AS DATE))
),

activite_mandats AS (
  SELECT
    ma.mois,
    mb.groupe_id,
    mb.negociateur_id,
    mb.negociateur_nom,
    mb.agence_id,
    mb.agence_nom,
    mb.mandat_type,
    COUNT(DISTINCT mb.mandat_type_id) AS cpt_mandats
  FROM mois_actifs ma
  JOIN mandats_base mb
    ON mb.man_date_debut <= DATEADD(MONTH, 1, ma.mois)  -- début avant fin du mois
    AND mb.man_date_fin >= ma.mois                      -- fin après début du mois
  GROUP BY
    ma.mois,
    mb.groupe_id,
    mb.negociateur_id,
    mb.negociateur_nom,
    mb.agence_id,
    mb.agence_nom,
    mb.mandat_type
)

SELECT
  mois,
  groupe_id,
  negociateur_id,
  negociateur_nom,
  agence_id,
  agence_nom,
  mandat_type,
  SUM(cpt_mandats) AS total_actifs
FROM activite_mandats
GROUP BY
  mois,
  groupe_id,
  negociateur_id,
  negociateur_nom,
  agence_id,
  agence_nom,
  mandat_type
"""

# Offres actives et Demandes actives ne feront pas l'objet de prévisions pour l'instant, il s'agit d'une vue en t du stock
# d'offres et de demandes
# C'est à dire que les "graphiques" 165 et 166 ne sont pas ici ! (ce sont des "big numbers", pas vraiment des graphiques
# d'alleurs)

# On ne fait remonter que la liste des groupes actifs, pas besoin d'encombrer ce programme déjà long à l'exécution par 
# les données de groupes qui n'utilisent plus LGP
requete_groupes = """select groupe_id from dbo.t_groupe where gro_actif = 1"""

# %%
# On remonte les datasets nécessaires pour faire les prévisions (compter deux minutes d'exécution)

conn_str = (
    "DRIVER={ODBC Driver 17 for SQL Server};"
    "SERVER=172.16.11.34;"
    "DATABASE=LogiProDev;"
    "UID=quentin;"
    "PWD={Barbidur1;SQL}"
)

conn = pyodbc.connect(conn_str)
cursor = conn.cursor()

dataset146 = pd.read_sql_query(requete146, conn) # Action proposition et visite
dataset147 = pd.read_sql_query(requete147, conn) # Nombre de transactions par négociateur
dataset148et149 = pd.read_sql_query(requete148et149, conn) # Stock de demande par négociateur
dataset150et151 = pd.read_sql_query(requete150et151, conn) # Stock d'offre par négociateur
dataset152 = pd.read_sql_query(requete152, conn) # Offres entrées
dataset153 = pd.read_sql_query(requete153, conn) # Demandes entrées
dataset154et155 = pd.read_sql_query(requete154et155, conn) # Nombre de plaintes et de désinscriptions
dataset156 = pd.read_sql_query(requete156, conn) # Actions générales
dataset157 = pd.read_sql_query(requete157, conn) # Evolution nombre de mails par opération
dataset158 = pd.read_sql_query(requete158, conn) # Evolution activité globale
dataset159 = pd.read_sql_query(requete159, conn) # Evolution activité de marché
dataset160 = pd.read_sql_query(requete160, conn) # Analyse des erreurs
dataset161 = pd.read_sql_query(requete161, conn) # Analyse des retours
dataset164 = pd.read_sql_query(requete164, conn) # Stock de mandats actifs

groupes = pd.read_sql_query(requete_groupes,conn) # df contenant tous les id de groupes actifs

conn.commit()
cursor.close()
conn.close()

# On ferme la connexion pyodbc à la BDD parce que le programme est long à exécuter, on n'en aura plus besoin avant dans
# environ une heure et demie
# Out:
# C:\Users\quent\AppData\Local\Temp\ipykernel_25220\1573457.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   dataset146 = pd.read_sql_query(requete146, conn) # Action proposition et visite
# C:\Users\quent\AppData\Local\Temp\ipykernel_25220\1573457.py:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   dataset147 = pd.read_sql_query(requete147, conn) # Nombre de transactions par négociateur
# C:\Users\quent\AppData\Local\Temp\ipykernel_25220\1573457.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   dataset148et149 = pd.read_sql_query(requete148et149, conn) # Stock de demande par négociateur
# C:\Users\quent\AppData\Local\Temp\ipykernel_25220\1573457.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   dataset150et151 = pd.read_sql_query(requete150et151, conn) # Stock d'offre par négociateur
# C:\Users\quent\AppData\Local\Temp\ipykernel_25220\1573457.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   dataset152 = pd.read_sql_query(requete152, conn) # Offres entrées
# C:\Users\quent\AppData\Local\Temp\ipykernel_25220\1573457.py:8: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   dataset153 = pd.read_sql_query(requete153, conn) # Demandes entrées
# C:\Users\quent\AppData\Local\Temp\ipykernel_25220\1573457.py:9: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   dataset154et155 = pd.read_sql_query(requete154et155, conn) # Nombre de plaintes et de désinscriptions
# C:\Users\quent\AppData\Local\Temp\ipykernel_25220\1573457.py:10: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   dataset156 = pd.read_sql_query(requete156, conn) # Actions générales
# C:\Users\quent\AppData\Local\Temp\ipykernel_25220\1573457.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   dataset157 = pd.read_sql_query(requete157, conn) # Evolution nombre de mails par opération
# C:\Users\quent\AppData\Local\Temp\ipykernel_25220\1573457.py:12: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   dataset158 = pd.read_sql_query(requete158, conn) # Evolution activité globale
# C:\Users\quent\AppData\Local\Temp\ipykernel_25220\1573457.py:13: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   dataset159 = pd.read_sql_query(requete159, conn) # Evolution activité de marché
# C:\Users\quent\AppData\Local\Temp\ipykernel_25220\1573457.py:14: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   dataset160 = pd.read_sql_query(requete160, conn) # Analyse des erreurs
# C:\Users\quent\AppData\Local\Temp\ipykernel_25220\1573457.py:15: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   dataset161 = pd.read_sql_query(requete161, conn) # Analyse des retours
# C:\Users\quent\AppData\Local\Temp\ipykernel_25220\1573457.py:16: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   dataset164 = pd.read_sql_query(requete164, conn) # Stock de mandats actifs
# C:\Users\quent\AppData\Local\Temp\ipykernel_25220\1573457.py:18: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   groupes = pd.read_sql_query(requete_groupes,conn) # df contenant tous les id de groupes actifs

# %%
# On trie les groupes par identifiant

groupes = groupes.sort_values(by='groupe_id', ascending=True)
groupes = groupes['groupe_id'].tolist() # on les transforme en liste au cas où on aurait besoin de manipuler cette liste,
# objet un peu plus manipulable

# %%
# On commence par diviser en plusieurs datasets les datasets servant à afficher plusieurs séries temporelles 
# sur un même graphique
# Ca concerne les datasets 146, 156, 158, 159, 160, 161, 164

# Action proposition et visite : on sépare les trois types d'actions 
dataset146visite = dataset146[dataset146['type_action'] == 'Visite']
dataset146rdv = dataset146[dataset146['type_action'] == 'Rdv Présentation']
dataset146proposition = dataset146[dataset146['type_action'] == 'Proposition']

dataset148 = dataset148et149 # Demande en surface
if 'nb_demandes' in dataset148.columns :
    dataset148 = dataset148.drop('nb_demandes', axis=1)

dataset149 = dataset148et149 # Demande en nombre
if 'surface_totale' in dataset149.columns :
    dataset149 = dataset149.drop('surface_totale', axis=1)

dataset150 = dataset150et151 # Offre en surface
if 'nb_offres' in dataset150.columns : 
    dataset150 = dataset150.drop('nb_offres', axis=1)

dataset151 = dataset150et151 # Offre en nombre
if 'surface_totale' in dataset151.columns : 
    dataset151 = dataset151.drop('surface_totale', axis=1)

dataset154 = dataset154et155 # Nombre de plaintes et de désinscriptions : ON AGREGE LES DEUX
dataset154['plaintes_desinscriptions'] = dataset154['nb_plaintes'] + dataset154['nb_desinscriptions']
if 'total_emails' in dataset154.columns : 
    dataset154 = dataset154.drop('total_emails', axis=1)

dataset155 = dataset154et155 # Total emails envoyés
if 'plaintes_desinscriptions' in dataset155.columns : 
    dataset155 = dataset155.drop('plaintes_desinscriptions', axis=1)

# Actions générales
dataset156action1 = dataset156.drop(['action2', 'action3', 'action4', 'action5'], axis=1)
dataset156action2 = dataset156.drop(['action1', 'action3', 'action4', 'action5'], axis=1)
dataset156action3 = dataset156.drop(['action1', 'action2', 'action4', 'action5'], axis=1)
dataset156action4 = dataset156.drop(['action1', 'action2', 'action3', 'action5'], axis=1)
dataset156action5 = dataset156.drop(['action1', 'action2', 'action3', 'action4'], axis=1)

# Evolution activité globale
dataset158offres = dataset158.drop(['nb_demandes', 'nb_mandats'], axis=1)
dataset158demandes = dataset158.drop(['nb_offres', 'nb_mandats'], axis=1)
dataset158mandats = dataset158.drop(['nb_offres', 'nb_demandes'], axis=1)

# Evolution activité de marché
dataset159offres = dataset159.drop(['nb_demandes', 'nb_mandats'], axis=1)
dataset159demandes = dataset159.drop(['nb_offres', 'nb_mandats'], axis=1)
dataset159mandats = dataset159.drop(['nb_offres', 'nb_demandes'], axis=1)

# Analyse des erreurs (erreur tout court est à 0 partout donc on l'oublie)
dataset160rejete = dataset160[dataset160['type_erreur'] == 'Rejeté']
dataset160npai = dataset160[dataset160['type_erreur'] == 'NPAI']

# Analyse des retours
dataset161delivres = dataset161[dataset161['type_retour'] == 'Délivrés']
dataset161cliques = dataset161[dataset161['type_retour'] == 'Cliqués']
dataset161ouverts = dataset161[dataset161['type_retour'] == 'Ouverts']
dataset161rejetes = dataset161[dataset161['type_retour'] == 'Rejetés']

# Nombre de mandats actifs (qui l'ont été à un moment donné du mois)
dataset164simple = dataset164[dataset164['mandat_type'] == 'Simple (O)']
dataset164demande = dataset164[dataset164['mandat_type'] == 'Demande']
dataset164exclusif = dataset164[dataset164['mandat_type'] == 'Exclusif (O)']
dataset164coexclusif = dataset164[dataset164['mandat_type'] == 'Co exclusif (O)']
dataset164triexclusif = dataset164[dataset164['mandat_type'] == 'Tri exclusif (O)']
dataset164preferentiel = dataset164[dataset164['mandat_type'] == 'Préférentiel (O)']
dataset164delegation = dataset164[dataset164['mandat_type'] == 'Délégation (O)']
dataset164quadriexclusif = dataset164[dataset164['mandat_type'] == 'Quadri exclusif (O)']
# Les autres types de mandats représentent bien trop peu de mandats pour faire des prévisions utiles

# %%
# En commentaire le nom du graphique correspondant à ce jeu de données pour les prévisions et son identifiant
# On définira ça au propre à la fin

datasets_noms = [
    'dataset146visite', # 168 Prévisions visite (intervalle de confiance à 80%)
    'dataset146proposition', # 169 Prévisions proposition PAS DE DONNEES
    'dataset146rdv', # 170 Prévisions rendez-vous
    'dataset147', # 171 Prévisions nombre de transactions
    'dataset148', # 172 Prévisions demande en surface
    'dataset149', # 173 Prévisions demande en nombre
    'dataset150', # 174 Prévisions offre en surface
    'dataset151', # 175 Prévisions offre en nombre
    'dataset152', # 176 Prévisions offres entrées
    'dataset153', # 177 Prévisions demandes entrées
    'dataset154', # 178 Prévisions plaintes et désinscriptions PAS DE DONNEES
    'dataset155', # 179 Prévisions total emails envoyés PAS DE DONNEES
    'dataset156action1', # 180 Prévisions action 1
    'dataset156action2', # 181 Prévisions action 2
    'dataset156action3', # 182 Prévisions action 3
    'dataset156action4', # 183 Prévisions action 4
    'dataset156action5', # 184 Prévisions action 5
    'dataset157', # 185 Prévisions nombre de mails par opération PAS DE DONNEES
    'dataset158offres', # 186 Prévisions activité globale offres
    'dataset158demandes', # 187 Prévisions activité globale demandes
    'dataset158mandats', # 188 Prévisions activité globale mandats
    'dataset159offres', # 189 Prévisions activité de marché offres
    'dataset159demandes', # 190 Prévisions activité de marché demandes
    'dataset159mandats', # 191 Prévisions activité de marché mandats
    'dataset160rejete', # 192 Prévisions erreurs : rejeté PAS DE DONNEES
    'dataset160npai', # 193 Prévisions erreurs : NPAI PAS DE DONNEES
    'dataset161delivres', # 194 Prévisions retours : délivrés PAS DE DONNEES
    'dataset161cliques', # 195 Prévisions retours : cliqués PAS DE DONNEES
    'dataset161ouverts', # 196 Prévisions retours : ouverts PAS DE DONNEES
    'dataset161rejetes', # 197 Prévisions retours : rejetés PAS DE DONNEES
    'dataset164simple', # 198 Prévisions mandats simples
    'dataset164demande', # 199 Prévisions mandats demandes
    'dataset164exclusif', # 200 Prévisions mandats exclusifs
    'dataset164coexclusif', # 201 Prévisions mandats coexclusifs
    'dataset164triexclusif', # 202 Prévisions mandats triexclusifs
    'dataset164preferentiel', # 203 Prévisions mandats préférentiels
    'dataset164delegation', # 204 Prévisions mandats délégation
    'dataset164quadriexclusif' # 205 Prévisions mandats quadriexclusifs
]

datasets = [
    dataset146visite,
    dataset146proposition,
    dataset146rdv,
    dataset147,
    dataset148,
    dataset149,
    dataset150,
    dataset151,
    dataset152,
    dataset153,
    dataset154, 
    dataset155,
    dataset156action1,
    dataset156action2,
    dataset156action3,
    dataset156action4,
    dataset156action5,
    dataset157,
    dataset158offres,
    dataset158demandes,
    dataset158mandats,
    dataset159offres,
    dataset159demandes,
    dataset159mandats,
    dataset160rejete,
    dataset160npai,
    dataset161delivres,
    dataset161cliques,
    dataset161ouverts,
    dataset161rejetes,
    dataset164simple,
    dataset164demande,
    dataset164exclusif,
    dataset164coexclusif,
    dataset164triexclusif,
    dataset164preferentiel,
    dataset164delegation,
    dataset164quadriexclusif
]

# On va supprimer de tous les datasets toutes ces colonnes, qui ne sont ni des colonnes date, ni valeur, ni groupe, bref,
# on ne va garder que les données qui nous intéresse, le minimum nécessaire
colonnes_a_abandonner = ['agence_nom', 
                         'agence_id', 
                         'negociateur_nom', 
                         'negociateur_id', 
                         'type_action',
                         'pct_plaintes',
                         'pct_desinscriptions',
                         'nb_plaintes',
                         'nb_desinscriptions',
                         'type_erreur',
                         'type_retour',
                         'mandat_type',
                         'nb_operations',
                         'nb_total_emails'
                         ]

# %%
# Suppression des colonnes inutiles pour la prévision
for i, nom_var in enumerate(datasets_noms):
    df = globals()[nom_var] # Permet de modifier la variable globale, et pas seulement le dataset tel qu'il est dans datasets_noms
    df_clean = df.drop(columns=colonnes_a_abandonner, errors='ignore')
    globals()[nom_var] = df_clean # Permet de modifier la variable globale, et pas seulement le dataset tel qu'il est dans la liste datasets

datasets = [globals()[nom] for nom in datasets_noms] # On modifie aussi le contenu du dictionnaire

# Vérification que tous les datasets sont bien sous la forme suivante : [date, groupe_id, série_temp]
for i in range(len(datasets)) : 
    if len(datasets[i].columns) != 3 :
        print(f'AAAAAHHHHH le dataset {datasets_noms[i]} contient {len(datasets[i].columns)} colonnes :')
        print(datasets[i].columns)
        # Si rien ne s'affiche en sortie de cette cellule, c'est bon signe, ça veut dire que toutes les séries temp
        # sont sous la bonne forme

# %% [markdown]
# **Split par groupe, aggrégation par mois, élimination des datasest avec trop peu de données, complétion par interpolation**

# %%
# On lance un dictionnaire pour stocker les nouveaux datasets créés
# La syntaxe sera la suivante : dataset146visite_grp38

datasets_groupes = {}

for i, df in enumerate(datasets):
    dataset_nom = datasets_noms[i]

    # Vérification la présence de la colonne 'groupe_id', normalement tout est bon ici
    if 'groupe_id' not in df.columns:
        print(f"❌ 'groupe_id' manquant dans {dataset_nom}") # En vrai c'est cool les pictogrammes c'est tape-à-l'oeil
        continue

    # Pour chaque groupe, on crée un nouveau dataset (sous réserve d'existence des données)
    for groupe in groupes:
        df_grp = df[df['groupe_id'] == groupe].copy() # On ne garde que les données qui concernent ce groupe en particulier
        if not df_grp.empty:
            nom_dataset = f"{dataset_nom}_grp{groupe}" # On construit le nom du nouveau dataset groupé
            globals()[nom_dataset] = df_grp  # Création d'une variable globale avec ce nom
            datasets_groupes[nom_dataset] = df_grp  # On met aussi dans le dico
            print(f"✅ Créé : {nom_dataset} ({len(df_grp)} lignes)") # Pictooo
        else:
            print(f"⚠️ {dataset_nom} : aucun enregistrement pour groupe {groupe}") # PICTOOOOO

print(f'Il y a pour l\'instant {len(datasets_groupes)} séries temporelles potentiellement analysables, ce nombre va diminuer quand on regardera le nombre de données disponibles')
# Out:
# ⚠️ dataset146visite : aucun enregistrement pour groupe 0
# ✅ Créé : dataset146visite_grp5 (108 lignes)
# ⚠️ dataset146visite : aucun enregistrement pour groupe 7
# ✅ Créé : dataset146visite_grp13 (4699 lignes)
# ✅ Créé : dataset146visite_grp14 (1222 lignes)
# ✅ Créé : dataset146visite_grp18 (12 lignes)
# ✅ Créé : dataset146visite_grp29 (1167 lignes)
# ✅ Créé : dataset146visite_grp35 (2185 lignes)
# ✅ Créé : dataset146visite_grp38 (29715 lignes)
# ✅ Créé : dataset146visite_grp39 (455 lignes)
# ⚠️ dataset146visite : aucun enregistrement pour groupe 40
# ✅ Créé : dataset146visite_grp43 (1402 lignes)
# ⚠️ dataset146visite : aucun enregistrement pour groupe 149
# ⚠️ dataset146visite : aucun enregistrement pour groupe 151
# ✅ Créé : dataset146visite_grp152 (42 lignes)
# ✅ Créé : dataset146visite_grp153 (1811 lignes)
# ✅ Créé : dataset146visite_grp154 (7 lignes)
# ✅ Créé : dataset146visite_grp156 (7 lignes)
# ⚠️ dataset146visite : aucun enregistrement pour groupe 158
# ⚠️ dataset146visite : aucun enregistrement pour groupe 160
# ⚠️ dataset146visite : aucun enregistrement pour groupe 161
# ✅ Créé : dataset146visite_grp162 (80 lignes)
# ⚠️ dataset146visite : aucun enregistrement pour groupe 163
# ✅ Créé : dataset146visite_grp164 (316 lignes)
# ✅ Créé : dataset146visite_grp165 (1 lignes)
# ⚠️ dataset146visite : aucun enregistrement pour groupe 166
# ⚠️ dataset146visite : aucun enregistrement pour groupe 167
# ⚠️ dataset146visite : aucun enregistrement pour groupe 168
# ✅ Créé : dataset146visite_grp171 (1 lignes)
# ⚠️ dataset146visite : aucun enregistrement pour groupe 172
# ⚠️ dataset146visite : aucun enregistrement pour groupe 173
# ✅ Créé : dataset146visite_grp174 (2 lignes)
# ⚠️ dataset146visite : aucun enregistrement pour groupe 175
# ⚠️ dataset146visite : aucun enregistrement pour groupe 176
# ⚠️ dataset146visite : aucun enregistrement pour groupe 177
# ⚠️ dataset146visite : aucun enregistrement pour groupe 178
# ⚠️ dataset146visite : aucun enregistrement pour groupe 1000
# ⚠️ dataset146proposition : aucun enregistrement pour groupe 0
# ✅ Créé : dataset146proposition_grp5 (6 lignes)
# ⚠️ dataset146proposition : aucun enregistrement pour groupe 7
# ✅ Créé : dataset146proposition_grp13 (2 lignes)
# ⚠️ dataset146proposition : aucun enregistrement pour groupe 14
# ⚠️ dataset146proposition : aucun enregistrement pour groupe 18
# ✅ Créé : dataset146proposition_grp29 (7 lignes)
# ✅ Créé : dataset146proposition_grp35 (47 lignes)
# ✅ Créé : dataset146proposition_grp38 (250 lignes)
# ✅ Créé : dataset146proposition_grp39 (2 lignes)
# ⚠️ dataset146proposition : aucun enregistrement pour groupe 40
# ✅ Créé : dataset146proposition_grp43 (73 lignes)
# ⚠️ dataset146proposition : aucun enregistrement pour groupe 45
# ⚠️ dataset146proposition : aucun enregistrement pour groupe 46
# ✅ Créé : dataset146proposition_grp47 (37 lignes)
# ⚠️ dataset146proposition : aucun enregistrement pour groupe 48
# ✅ Créé : dataset146proposition_grp50 (114 lignes)
# ✅ Créé : dataset146proposition_grp53 (1 lignes)
# ✅ Créé : dataset146proposition_grp54 (1 lignes)
# ⚠️ dataset146proposition : aucun enregistrement pour groupe 55
# ✅ Créé : dataset146proposition_grp56 (6 lignes)
# ✅ Créé : dataset146proposition_grp57 (2 lignes)
# ⚠️ dataset146proposition : aucun enregistrement pour groupe 60
# ⚠️ dataset146proposition : aucun enregistrement pour groupe 61
# ✅ Créé : dataset146proposition_grp64 (3 lignes)
# ⚠️ dataset146proposition : aucun enregistrement pour groupe 67
# ✅ Créé : dataset146proposition_grp68 (1 lignes)
# ⚠️ dataset146proposition : aucun enregistrement pour groupe 72
# ✅ Créé : dataset146proposition_grp75 (11 lignes)
# ✅ Créé : dataset146proposition_grp76 (2 lignes)
# ✅ Créé : dataset146proposition_grp79 (4 lignes)
# ✅ Créé : dataset146proposition_grp80 (3 lignes)
# ✅ Créé : dataset146proposition_grp83 (3 lignes)
# ✅ Créé : dataset146proposition_grp85 (4 lignes)
# ⚠️ dataset146proposition : aucun enregistrement pour groupe 86
# ✅ Créé : dataset146proposition_grp89 (1 lignes)
# ⚠️ dataset146proposition : aucun enregistrement pour groupe 90
# ⚠️ dataset146proposition : aucun enregistrement pour groupe 93
# ⚠️ dataset146proposition : aucun enregistrement pour groupe 96
# ⚠️ dataset146proposition : aucun enregistrement pour groupe 98
# ⚠️ dataset146proposition : aucun enregistrement pour groupe 100
# ✅ Créé : dataset146proposition_grp101 (1 lignes)
# ⚠️ dataset146proposition : aucun enregistrement pour groupe 106
# ⚠️ dataset146proposition : aucun enregistrement pour groupe 107
# ✅ Créé : dataset146proposition_grp108 (221 lignes)
# ⚠️ dataset146proposition : aucun enregistrement pour groupe 109
# ⚠️ dataset146proposition : aucun enregistrement pour groupe 110
# ⚠️ dataset146proposition : aucun enregistrement pour groupe 111
# ⚠️ dataset146proposition : aucun enregistrement pour groupe 112
# ⚠️ dataset146proposition : aucun enregistrement pour groupe 113
# ✅ Créé : dataset146proposition_grp114 (3 lignes)
# ⚠️ dataset146proposition : aucun enregistrement pour groupe 118
# ⚠️ dataset146proposition : aucun enregistrement pour groupe 120
# ⚠️ dataset146proposition : aucun enregistrement pour groupe 121
# ✅ Créé : dataset146proposition_grp124 (2 lignes)
# ⚠️ dataset146proposition : aucun enregistrement pour groupe 127
# ✅ Créé : dataset146proposition_grp128 (4 lignes)
# ✅ Créé : dataset146proposition_grp133 (1 lignes)
# ⚠️ dataset146proposition : aucun enregistrement pour groupe 134
# ⚠️ dataset146proposition : aucun enregistrement pour groupe 135
# ⚠️ dataset146proposition : aucun enregistrement pour groupe 138
# ⚠️ dataset146proposition : aucun enregistrement pour groupe 139
# ⚠️ dataset146proposition : aucun enregistrement pour groupe 144
# ⚠️ dataset146proposition : aucun enregistrement pour groupe 146
# ✅ Créé : dataset146proposition_grp147 (1 lignes)
# ⚠️ dataset146proposition : aucun enregistrement pour groupe 148
# ✅ Créé : dataset146proposition_grp149 (4 lignes)
# ⚠️ dataset146proposition : aucun enregistrement pour groupe 151
# ⚠️ dataset146proposition : aucun enregistrement pour groupe 152
# ✅ Créé : dataset146proposition_grp153 (1 lignes)
# ⚠️ dataset146proposition : aucun enregistrement pour groupe 154
# ⚠️ dataset146proposition : aucun enregistrement pour groupe 156
# ⚠️ dataset146proposition : aucun enregistrement pour groupe 158
# ⚠️ dataset146proposition : aucun enregistrement pour groupe 160
# ⚠️ dataset146proposition : aucun enregistrement pour groupe 161
# ⚠️ dataset146proposition : aucun enregistrement pour groupe 162
# ⚠️ dataset146proposition : aucun enregistrement pour groupe 163
# ✅ Créé : dataset146proposition_grp164 (9 lignes)
# ⚠️ dataset146proposition : aucun enregistrement pour groupe 165
# ⚠️ dataset146proposition : aucun enregistrement pour groupe 166
# ⚠️ dataset146proposition : aucun enregistrement pour groupe 167
# ⚠️ dataset146proposition : aucun enregistrement pour groupe 168
# ⚠️ dataset146proposition : aucun enregistrement pour groupe 171
# ⚠️ dataset146proposition : aucun enregistrement pour groupe 172
# ⚠️ dataset146proposition : aucun enregistrement pour groupe 173
# ⚠️ dataset146proposition : aucun enregistrement pour groupe 174
# ⚠️ dataset146proposition : aucun enregistrement pour groupe 175
# ⚠️ dataset146proposition : aucun enregistrement pour groupe 176
# ⚠️ dataset146proposition : aucun enregistrement pour groupe 177
# ⚠️ dataset146proposition : aucun enregistrement pour groupe 178
# ⚠️ dataset146proposition : aucun enregistrement pour groupe 1000
# ⚠️ dataset146rdv : aucun enregistrement pour groupe 0
# ✅ Créé : dataset146rdv_grp5 (16 lignes)
# ⚠️ dataset146rdv : aucun enregistrement pour groupe 7
# ✅ Créé : dataset146rdv_grp13 (4507 lignes)
# ✅ Créé : dataset146rdv_grp14 (700 lignes)
# ✅ Créé : dataset146rdv_grp18 (11 lignes)
# ✅ Créé : dataset146rdv_grp29 (403 lignes)
# ✅ Créé : dataset146rdv_grp35 (1380 lignes)
# ✅ Créé : dataset146rdv_grp38 (11930 lignes)
# ✅ Créé : dataset146rdv_grp39 (280 lignes)
# ⚠️ dataset146rdv : aucun enregistrement pour groupe 40
# ✅ Créé : dataset146rdv_grp43 (56 lignes)
# ✅ Créé : dataset146rdv_grp45 (211 lignes)
# ⚠️ dataset146rdv : aucun enregistrement pour groupe 46
# ✅ Créé : dataset146rdv_grp47 (243 lignes)
# ⚠️ dataset146rdv : aucun enregistrement pour groupe 48
# ✅ Créé : dataset146rdv_grp50 (2105 lignes)
# ✅ Créé : dataset146rdv_grp53 (20 lignes)
# ✅ Créé : dataset146rdv_grp54 (583 lignes)
# ✅ Créé : dataset146rdv_grp55 (4 lignes)
# ✅ Créé : dataset146rdv_grp56 (353 lignes)
# ✅ Créé : dataset146rdv_grp57 (30 lignes)
# ✅ Créé : dataset146rdv_grp60 (294 lignes)
# ✅ Créé : dataset146rdv_grp61 (844 lignes)
# ✅ Créé : dataset146rdv_grp64 (299 lignes)
# ✅ Créé : dataset146rdv_grp67 (232 lignes)
# ✅ Créé : dataset146rdv_grp68 (547 lignes)
# ✅ Créé : dataset146rdv_grp72 (79 lignes)
# ✅ Créé : dataset146rdv_grp75 (598 lignes)
# ✅ Créé : dataset146rdv_grp76 (146 lignes)
# ✅ Créé : dataset146rdv_grp79 (886 lignes)
# ✅ Créé : dataset146rdv_grp80 (67 lignes)
# ✅ Créé : dataset146rdv_grp83 (416 lignes)
# ✅ Créé : dataset146rdv_grp85 (274 lignes)
# ✅ Créé : dataset146rdv_grp86 (906 lignes)
# ✅ Créé : dataset146rdv_grp89 (13 lignes)
# ✅ Créé : dataset146rdv_grp90 (1 lignes)
# ✅ Créé : dataset146rdv_grp93 (1 lignes)
# ✅ Créé : dataset146rdv_grp96 (204 lignes)
# ⚠️ dataset146rdv : aucun enregistrement pour groupe 98
# ✅ Créé : dataset146rdv_grp100 (433 lignes)
# ✅ Créé : dataset146rdv_grp101 (136 lignes)
# ✅ Créé : dataset146rdv_grp106 (2 lignes)
# ✅ Créé : dataset146rdv_grp107 (263 lignes)
# ✅ Créé : dataset146rdv_grp108 (492 lignes)
# ✅ Créé : dataset146rdv_grp109 (200 lignes)
# ⚠️ dataset146rdv : aucun enregistrement pour groupe 110
# ⚠️ dataset146rdv : aucun enregistrement pour groupe 111
# ⚠️ dataset146rdv : aucun enregistrement pour groupe 112
# ⚠️ dataset146rdv : aucun enregistrement pour groupe 113
# ✅ Créé : dataset146rdv_grp114 (97 lignes)
# ✅ Créé : dataset146rdv_grp118 (243 lignes)
# ✅ Créé : dataset146rdv_grp120 (36 lignes)
# ⚠️ dataset146rdv : aucun enregistrement pour groupe 121
# ✅ Créé : dataset146rdv_grp124 (155 lignes)
# ⚠️ dataset146rdv : aucun enregistrement pour groupe 127
# ✅ Créé : dataset146rdv_grp128 (83 lignes)
# ✅ Créé : dataset146rdv_grp133 (552 lignes)
# ⚠️ dataset146rdv : aucun enregistrement pour groupe 134
# ✅ Créé : dataset146rdv_grp135 (8 lignes)
# ⚠️ dataset146rdv : aucun enregistrement pour groupe 138
# ⚠️ dataset146rdv : aucun enregistrement pour groupe 139
# ⚠️ dataset146rdv : aucun enregistrement pour groupe 144
# ✅ Créé : dataset146rdv_grp146 (2 lignes)
# ✅ Créé : dataset146rdv_grp147 (2 lignes)
# ✅ Créé : dataset146rdv_grp148 (14 lignes)
# ⚠️ dataset146rdv : aucun enregistrement pour groupe 149
# ⚠️ dataset146rdv : aucun enregistrement pour groupe 151
# ✅ Créé : dataset146rdv_grp152 (3 lignes)
# ✅ Créé : dataset146rdv_grp153 (1530 lignes)
# ⚠️ dataset146rdv : aucun enregistrement pour groupe 154
# ✅ Créé : dataset146rdv_grp156 (5 lignes)
# ⚠️ dataset146rdv : aucun enregistrement pour groupe 158
# ⚠️ dataset146rdv : aucun enregistrement pour groupe 160
# ⚠️ dataset146rdv : aucun enregistrement pour groupe 161
# ✅ Créé : dataset146rdv_grp162 (65 lignes)
# ⚠️ dataset146rdv : aucun enregistrement pour groupe 163
# ✅ Créé : dataset146rdv_grp164 (257 lignes)
# ⚠️ dataset146rdv : aucun enregistrement pour groupe 165
# ⚠️ dataset146rdv : aucun enregistrement pour groupe 166
# ⚠️ dataset146rdv : aucun enregistrement pour groupe 167
# ⚠️ dataset146rdv : aucun enregistrement pour groupe 168
# ⚠️ dataset146rdv : aucun enregistrement pour groupe 171
# ⚠️ dataset146rdv : aucun enregistrement pour groupe 172
# ⚠️ dataset146rdv : aucun enregistrement pour groupe 173
# ✅ Créé : dataset146rdv_grp174 (2 lignes)
# ⚠️ dataset146rdv : aucun enregistrement pour groupe 175
# ⚠️ dataset146rdv : aucun enregistrement pour groupe 176
# ⚠️ dataset146rdv : aucun enregistrement pour groupe 177
# ⚠️ dataset146rdv : aucun enregistrement pour groupe 178
# ⚠️ dataset146rdv : aucun enregistrement pour groupe 1000
# ⚠️ dataset147 : aucun enregistrement pour groupe 0
# ✅ Créé : dataset147_grp5 (8 lignes)
# ✅ Créé : dataset147_grp7 (12 lignes)
# ✅ Créé : dataset147_grp13 (6910 lignes)
# ✅ Créé : dataset147_grp14 (4860 lignes)
# ⚠️ dataset147 : aucun enregistrement pour groupe 18
# ✅ Créé : dataset147_grp29 (576 lignes)
# ✅ Créé : dataset147_grp35 (3082 lignes)
# ✅ Créé : dataset147_grp38 (27699 lignes)
# ✅ Créé : dataset147_grp39 (2483 lignes)
# ⚠️ dataset147 : aucun enregistrement pour groupe 40
# ✅ Créé : dataset147_grp43 (397 lignes)
# ✅ Créé : dataset147_grp45 (227 lignes)
# ⚠️ dataset147 : aucun enregistrement pour groupe 46
# ✅ Créé : dataset147_grp47 (2795 lignes)
# ✅ Créé : dataset147_grp48 (4 lignes)
# ✅ Créé : dataset147_grp50 (2314 lignes)
# ✅ Créé : dataset147_grp53 (210 lignes)
# ✅ Créé : dataset147_grp54 (4804 lignes)
# ✅ Créé : dataset147_grp55 (739 lignes)
# ✅ Créé : dataset147_grp56 (1438 lignes)
# ✅ Créé : dataset147_grp57 (1 lignes)
# ⚠️ dataset147 : aucun enregistrement pour groupe 60
# ✅ Créé : dataset147_grp61 (2 lignes)
# ✅ Créé : dataset147_grp64 (579 lignes)
# ✅ Créé : dataset147_grp67 (513 lignes)
# ✅ Créé : dataset147_grp68 (410 lignes)
# ✅ Créé : dataset147_grp72 (354 lignes)
# ✅ Créé : dataset147_grp75 (1053 lignes)
# ✅ Créé : dataset147_grp76 (375 lignes)
# ✅ Créé : dataset147_grp79 (300 lignes)
# ✅ Créé : dataset147_grp80 (128 lignes)
# ✅ Créé : dataset147_grp83 (162 lignes)
# ✅ Créé : dataset147_grp85 (338 lignes)
# ✅ Créé : dataset147_grp86 (842 lignes)
# ✅ Créé : dataset147_grp89 (1033 lignes)
# ⚠️ dataset147 : aucun enregistrement pour groupe 90
# ✅ Créé : dataset147_grp93 (10 lignes)
# ✅ Créé : dataset147_grp96 (24 lignes)
# ✅ Créé : dataset147_grp98 (1 lignes)
# ⚠️ dataset147 : aucun enregistrement pour groupe 100
# ✅ Créé : dataset147_grp101 (356 lignes)
# ✅ Créé : dataset147_grp106 (1 lignes)
# ✅ Créé : dataset147_grp107 (470 lignes)
# ✅ Créé : dataset147_grp108 (437 lignes)
# ✅ Créé : dataset147_grp109 (326 lignes)
# ⚠️ dataset147 : aucun enregistrement pour groupe 110
# ⚠️ dataset147 : aucun enregistrement pour groupe 111
# ⚠️ dataset147 : aucun enregistrement pour groupe 112
# ⚠️ dataset147 : aucun enregistrement pour groupe 113
# ⚠️ dataset147 : aucun enregistrement pour groupe 114
# ✅ Créé : dataset147_grp118 (188 lignes)
# ✅ Créé : dataset147_grp120 (182 lignes)
# ⚠️ dataset147 : aucun enregistrement pour groupe 121
# ✅ Créé : dataset147_grp124 (107 lignes)
# ⚠️ dataset147 : aucun enregistrement pour groupe 127
# ✅ Créé : dataset147_grp128 (135 lignes)
# ✅ Créé : dataset147_grp133 (6632 lignes)
# ✅ Créé : dataset147_grp134 (14 lignes)
# ✅ Créé : dataset147_grp135 (4 lignes)
# ⚠️ dataset147 : aucun enregistrement pour groupe 138
# ⚠️ dataset147 : aucun enregistrement pour groupe 139
# ⚠️ dataset147 : aucun enregistrement pour groupe 144
# ✅ Créé : dataset147_grp146 (2 lignes)
# ✅ Créé : dataset147_grp147 (24 lignes)
# ⚠️ dataset147 : aucun enregistrement pour groupe 148
# ⚠️ dataset147 : aucun enregistrement pour groupe 149
# ⚠️ dataset147 : aucun enregistrement pour groupe 151
# ✅ Créé : dataset147_grp152 (6 lignes)
# ✅ Créé : dataset147_grp153 (5009 lignes)
# ✅ Créé : dataset147_grp154 (4359 lignes)
# ✅ Créé : dataset147_grp156 (15 lignes)
# ⚠️ dataset147 : aucun enregistrement pour groupe 158
# ⚠️ dataset147 : aucun enregistrement pour groupe 160
# ⚠️ dataset147 : aucun enregistrement pour groupe 161
# ✅ Créé : dataset147_grp162 (1652 lignes)
# ⚠️ dataset147 : aucun enregistrement pour groupe 163
# ✅ Créé : dataset147_grp164 (1109 lignes)
# ⚠️ dataset147 : aucun enregistrement pour groupe 165
# ⚠️ dataset147 : aucun enregistrement pour groupe 166
# ⚠️ dataset147 : aucun enregistrement pour groupe 167
# ⚠️ dataset147 : aucun enregistrement pour groupe 168
# ⚠️ dataset147 : aucun enregistrement pour groupe 171
# ✅ Créé : dataset147_grp172 (127 lignes)
# ⚠️ dataset147 : aucun enregistrement pour groupe 173
# ⚠️ dataset147 : aucun enregistrement pour groupe 174
# ⚠️ dataset147 : aucun enregistrement pour groupe 175
# ⚠️ dataset147 : aucun enregistrement pour groupe 176
# ⚠️ dataset147 : aucun enregistrement pour groupe 177
# ⚠️ dataset147 : aucun enregistrement pour groupe 178
# ⚠️ dataset147 : aucun enregistrement pour groupe 1000
# ⚠️ dataset148 : aucun enregistrement pour groupe 0
# ✅ Créé : dataset148_grp5 (2089 lignes)
# ✅ Créé : dataset148_grp7 (5308 lignes)
# ✅ Créé : dataset148_grp13 (7493 lignes)
# ✅ Créé : dataset148_grp14 (3877 lignes)
# ✅ Créé : dataset148_grp18 (1081 lignes)
# ✅ Créé : dataset148_grp29 (1513 lignes)
# ✅ Créé : dataset148_grp35 (3357 lignes)
# ✅ Créé : dataset148_grp38 (87847 lignes)
# ✅ Créé : dataset148_grp39 (1439 lignes)
# ⚠️ dataset148 : aucun enregistrement pour groupe 40
# ✅ Créé : dataset148_grp43 (6428 lignes)
# ✅ Créé : dataset148_grp45 (1235 lignes)
# ⚠️ dataset148 : aucun enregistrement pour groupe 46
# ✅ Créé : dataset148_grp47 (9764 lignes)
# ✅ Créé : dataset148_grp48 (7 lignes)
# ✅ Créé : dataset148_grp50 (13102 lignes)
# ✅ Créé : dataset148_grp53 (1250 lignes)
# ✅ Créé : dataset148_grp54 (8354 lignes)
# ✅ Créé : dataset148_grp55 (109 lignes)
# ✅ Créé : dataset148_grp56 (9516 lignes)
# ✅ Créé : dataset152_grp135 (116 lignes)
# ✅ Créé : dataset152_grp138 (2251 lignes)
# ✅ Créé : dataset152_grp139 (15 lignes)
# ✅ Créé : dataset152_grp144 (1972 lignes)
# ✅ Créé : dataset152_grp146 (23 lignes)
# ✅ Créé : dataset152_grp147 (58 lignes)
# ✅ Créé : dataset152_grp148 (278 lignes)
# ✅ Créé : dataset152_grp149 (133 lignes)
# ✅ Créé : dataset152_grp151 (106 lignes)
# ✅ Créé : dataset152_grp152 (514 lignes)
# ✅ Créé : dataset152_grp153 (2669 lignes)
# ✅ Créé : dataset152_grp154 (2306 lignes)
# ✅ Créé : dataset152_grp156 (50 lignes)
# ✅ Créé : dataset152_grp158 (32 lignes)
# ✅ Créé : dataset152_grp160 (102 lignes)
# ✅ Créé : dataset152_grp161 (228 lignes)
# ✅ Créé : dataset152_grp162 (2460 lignes)
# ✅ Créé : dataset152_grp163 (59 lignes)
# ✅ Créé : dataset152_grp164 (2081 lignes)
# ✅ Créé : dataset152_grp165 (16 lignes)
# ⚠️ dataset152 : aucun enregistrement pour groupe 166
# ✅ Créé : dataset152_grp167 (5 lignes)
# ✅ Créé : dataset152_grp168 (36 lignes)
# ✅ Créé : dataset152_grp171 (52 lignes)
# ✅ Créé : dataset152_grp172 (2895 lignes)
# ✅ Créé : dataset152_grp173 (1692 lignes)
# ✅ Créé : dataset152_grp174 (84 lignes)
# ✅ Créé : dataset152_grp175 (17 lignes)
# ⚠️ dataset152 : aucun enregistrement pour groupe 176
# ⚠️ dataset152 : aucun enregistrement pour groupe 177
# ⚠️ dataset152 : aucun enregistrement pour groupe 178
# ⚠️ dataset152 : aucun enregistrement pour groupe 1000
# ⚠️ dataset153 : aucun enregistrement pour groupe 0
# ✅ Créé : dataset153_grp5 (1811 lignes)
# ✅ Créé : dataset153_grp7 (5015 lignes)
# ✅ Créé : dataset153_grp13 (6228 lignes)
# ✅ Créé : dataset153_grp14 (3475 lignes)
# ✅ Créé : dataset153_grp18 (621 lignes)
# ✅ Créé : dataset153_grp29 (1507 lignes)
# ✅ Créé : dataset153_grp35 (3291 lignes)
# ✅ Créé : dataset153_grp38 (71400 lignes)
# ✅ Créé : dataset153_grp39 (1080 lignes)
# ⚠️ dataset153 : aucun enregistrement pour groupe 40
# ✅ Créé : dataset153_grp43 (6096 lignes)
# ✅ Créé : dataset153_grp45 (1212 lignes)
# ⚠️ dataset153 : aucun enregistrement pour groupe 46
# ✅ Créé : dataset153_grp47 (9742 lignes)
# ✅ Créé : dataset153_grp48 (7 lignes)
# ✅ Créé : dataset153_grp50 (10346 lignes)
# ✅ Créé : dataset153_grp53 (817 lignes)
# ✅ Créé : dataset153_grp54 (5063 lignes)
# ✅ Créé : dataset153_grp55 (109 lignes)
# ✅ Créé : dataset153_grp56 (6262 lignes)
# ✅ Créé : dataset153_grp57 (431 lignes)
# ✅ Créé : dataset153_grp60 (1273 lignes)
# ✅ Créé : dataset153_grp61 (2923 lignes)
# ✅ Créé : dataset153_grp64 (1799 lignes)
# ✅ Créé : dataset153_grp67 (1421 lignes)
# ⚠️ dataset153 : aucun enregistrement pour groupe 173
# ✅ Créé : dataset153_grp174 (37 lignes)
# ✅ Créé : dataset153_grp175 (6 lignes)
# ⚠️ dataset153 : aucun enregistrement pour groupe 176
# ⚠️ dataset153 : aucun enregistrement pour groupe 177
# ⚠️ dataset153 : aucun enregistrement pour groupe 178
# ⚠️ dataset153 : aucun enregistrement pour groupe 1000
# ⚠️ dataset154 : aucun enregistrement pour groupe 0
# ⚠️ dataset154 : aucun enregistrement pour groupe 5
# ⚠️ dataset154 : aucun enregistrement pour groupe 7
# ⚠️ dataset154 : aucun enregistrement pour groupe 13
# ⚠️ dataset154 : aucun enregistrement pour groupe 14
# ⚠️ dataset154 : aucun enregistrement pour groupe 18
# ✅ Créé : dataset154_grp29 (8 lignes)
# ✅ Créé : dataset154_grp35 (1 lignes)
# ✅ Créé : dataset154_grp38 (2691 lignes)
# ⚠️ dataset154 : aucun enregistrement pour groupe 39
# ⚠️ dataset154 : aucun enregistrement pour groupe 40
# ⚠️ dataset154 : aucun enregistrement pour groupe 43
# ⚠️ dataset154 : aucun enregistrement pour groupe 45
# ⚠️ dataset154 : aucun enregistrement pour groupe 46
# ⚠️ dataset154 : aucun enregistrement pour groupe 47
# ⚠️ dataset154 : aucun enregistrement pour groupe 48
# ⚠️ dataset154 : aucun enregistrement pour groupe 50
# ⚠️ dataset154 : aucun enregistrement pour groupe 53
# ⚠️ dataset154 : aucun enregistrement pour groupe 54
# ⚠️ dataset154 : aucun enregistrement pour groupe 55
# ⚠️ dataset154 : aucun enregistrement pour groupe 56
# ⚠️ dataset154 : aucun enregistrement pour groupe 57
# ⚠️ dataset154 : aucun enregistrement pour groupe 60
# ⚠️ dataset154 : aucun enregistrement pour groupe 61
# ⚠️ dataset154 : aucun enregistrement pour groupe 64
# ✅ Créé : dataset154_grp67 (2 lignes)
# ✅ Créé : dataset154_grp68 (1 lignes)
# ⚠️ dataset154 : aucun enregistrement pour groupe 72
# ⚠️ dataset154 : aucun enregistrement pour groupe 75
# ⚠️ dataset154 : aucun enregistrement pour groupe 76
# ⚠️ dataset154 : aucun enregistrement pour groupe 79
# ⚠️ dataset154 : aucun enregistrement pour groupe 80
# ⚠️ dataset154 : aucun enregistrement pour groupe 83
# ⚠️ dataset154 : aucun enregistrement pour groupe 85
# ✅ Créé : dataset154_grp86 (7 lignes)
# ⚠️ dataset154 : aucun enregistrement pour groupe 89
# ⚠️ dataset154 : aucun enregistrement pour groupe 90
# ⚠️ dataset154 : aucun enregistrement pour groupe 93
# ⚠️ dataset154 : aucun enregistrement pour groupe 96
# ⚠️ dataset154 : aucun enregistrement pour groupe 98
# ⚠️ dataset154 : aucun enregistrement pour groupe 100
# ⚠️ dataset154 : aucun enregistrement pour groupe 101
# ⚠️ dataset154 : aucun enregistrement pour groupe 106
# ✅ Créé : dataset154_grp107 (3 lignes)
# ✅ Créé : dataset154_grp108 (62 lignes)
# ⚠️ dataset154 : aucun enregistrement pour groupe 109
# ⚠️ dataset154 : aucun enregistrement pour groupe 110
# ⚠️ dataset154 : aucun enregistrement pour groupe 111
# ⚠️ dataset154 : aucun enregistrement pour groupe 112
# ⚠️ dataset154 : aucun enregistrement pour groupe 113
# ⚠️ dataset154 : aucun enregistrement pour groupe 114
# ⚠️ dataset154 : aucun enregistrement pour groupe 118
# ⚠️ dataset154 : aucun enregistrement pour groupe 120
# ⚠️ dataset154 : aucun enregistrement pour groupe 121
# ⚠️ dataset154 : aucun enregistrement pour groupe 124
# ⚠️ dataset154 : aucun enregistrement pour groupe 127
# ⚠️ dataset154 : aucun enregistrement pour groupe 128
# ✅ Créé : dataset154_grp133 (1 lignes)
# ⚠️ dataset154 : aucun enregistrement pour groupe 134
# ⚠️ dataset154 : aucun enregistrement pour groupe 135
# ⚠️ dataset154 : aucun enregistrement pour groupe 138
# ⚠️ dataset154 : aucun enregistrement pour groupe 139
# ⚠️ dataset154 : aucun enregistrement pour groupe 144
# ✅ Créé : dataset154_grp146 (2 lignes)
# ✅ Créé : dataset154_grp147 (14 lignes)
# ⚠️ dataset154 : aucun enregistrement pour groupe 148
# ⚠️ dataset154 : aucun enregistrement pour groupe 149
# ⚠️ dataset154 : aucun enregistrement pour groupe 151
# ⚠️ dataset154 : aucun enregistrement pour groupe 152
# ⚠️ dataset154 : aucun enregistrement pour groupe 153
# ⚠️ dataset154 : aucun enregistrement pour groupe 154
# ✅ Créé : dataset154_grp156 (6 lignes)
# ⚠️ dataset154 : aucun enregistrement pour groupe 158
# ⚠️ dataset154 : aucun enregistrement pour groupe 160
# ⚠️ dataset154 : aucun enregistrement pour groupe 161
# ✅ Créé : dataset154_grp162 (1 lignes)
# ⚠️ dataset154 : aucun enregistrement pour groupe 163
# ✅ Créé : dataset154_grp164 (112 lignes)
# ⚠️ dataset154 : aucun enregistrement pour groupe 165
# ⚠️ dataset154 : aucun enregistrement pour groupe 166
# ⚠️ dataset154 : aucun enregistrement pour groupe 167
# ⚠️ dataset154 : aucun enregistrement pour groupe 168
# ⚠️ dataset154 : aucun enregistrement pour groupe 171
# ⚠️ dataset154 : aucun enregistrement pour groupe 172
# ⚠️ dataset154 : aucun enregistrement pour groupe 173
# ⚠️ dataset154 : aucun enregistrement pour groupe 174
# ⚠️ dataset154 : aucun enregistrement pour groupe 175
# ⚠️ dataset154 : aucun enregistrement pour groupe 176
# ⚠️ dataset154 : aucun enregistrement pour groupe 177
# ⚠️ dataset154 : aucun enregistrement pour groupe 178
# ⚠️ dataset154 : aucun enregistrement pour groupe 1000
# ⚠️ dataset155 : aucun enregistrement pour groupe 0
# ⚠️ dataset155 : aucun enregistrement pour groupe 5
# ⚠️ dataset155 : aucun enregistrement pour groupe 7
# ⚠️ dataset155 : aucun enregistrement pour groupe 13
# ⚠️ dataset155 : aucun enregistrement pour groupe 14
# ⚠️ dataset155 : aucun enregistrement pour groupe 18
# ✅ Créé : dataset155_grp29 (8 lignes)
# ✅ Créé : dataset155_grp35 (1 lignes)
# ✅ Créé : dataset155_grp38 (2691 lignes)
# ⚠️ dataset155 : aucun enregistrement pour groupe 39
# ⚠️ dataset155 : aucun enregistrement pour groupe 40
# ⚠️ dataset155 : aucun enregistrement pour groupe 43
# ⚠️ dataset155 : aucun enregistrement pour groupe 45
# ⚠️ dataset155 : aucun enregistrement pour groupe 46
# ⚠️ dataset155 : aucun enregistrement pour groupe 47
# ⚠️ dataset155 : aucun enregistrement pour groupe 48
# ⚠️ dataset155 : aucun enregistrement pour groupe 50
# ⚠️ dataset155 : aucun enregistrement pour groupe 53
# ⚠️ dataset155 : aucun enregistrement pour groupe 54
# ⚠️ dataset155 : aucun enregistrement pour groupe 55
# ⚠️ dataset155 : aucun enregistrement pour groupe 56
# ⚠️ dataset155 : aucun enregistrement pour groupe 57
# ⚠️ dataset155 : aucun enregistrement pour groupe 60
# ⚠️ dataset155 : aucun enregistrement pour groupe 61
# ⚠️ dataset155 : aucun enregistrement pour groupe 64
# ✅ Créé : dataset155_grp67 (2 lignes)
# ✅ Créé : dataset155_grp68 (1 lignes)
# ⚠️ dataset155 : aucun enregistrement pour groupe 72
# ⚠️ dataset155 : aucun enregistrement pour groupe 75
# ⚠️ dataset155 : aucun enregistrement pour groupe 76
# ⚠️ dataset155 : aucun enregistrement pour groupe 79
# ⚠️ dataset155 : aucun enregistrement pour groupe 80
# ⚠️ dataset155 : aucun enregistrement pour groupe 83
# ⚠️ dataset155 : aucun enregistrement pour groupe 85
# ✅ Créé : dataset155_grp86 (7 lignes)
# ⚠️ dataset155 : aucun enregistrement pour groupe 89
# ⚠️ dataset155 : aucun enregistrement pour groupe 90
# ⚠️ dataset155 : aucun enregistrement pour groupe 93
# ⚠️ dataset155 : aucun enregistrement pour groupe 96
# ⚠️ dataset155 : aucun enregistrement pour groupe 98
# ⚠️ dataset155 : aucun enregistrement pour groupe 100
# ⚠️ dataset155 : aucun enregistrement pour groupe 101
# ⚠️ dataset155 : aucun enregistrement pour groupe 106
# ✅ Créé : dataset155_grp107 (3 lignes)
# ✅ Créé : dataset155_grp108 (62 lignes)
# ⚠️ dataset155 : aucun enregistrement pour groupe 109
# ⚠️ dataset155 : aucun enregistrement pour groupe 110
# ⚠️ dataset155 : aucun enregistrement pour groupe 111
# ⚠️ dataset155 : aucun enregistrement pour groupe 112
# ⚠️ dataset155 : aucun enregistrement pour groupe 113
# ⚠️ dataset155 : aucun enregistrement pour groupe 114
# ⚠️ dataset155 : aucun enregistrement pour groupe 118
# ⚠️ dataset155 : aucun enregistrement pour groupe 120
# ⚠️ dataset155 : aucun enregistrement pour groupe 121
# ⚠️ dataset155 : aucun enregistrement pour groupe 124
# ⚠️ dataset155 : aucun enregistrement pour groupe 127
# ⚠️ dataset155 : aucun enregistrement pour groupe 128
# ...
# ✅ Créé : dataset164preferentiel_grp35 (365 lignes)
# ✅ Créé : dataset164preferentiel_grp38 (3728 lignes)
# ✅ Créé : dataset164preferentiel_grp39 (189 lignes)
# ⚠️ dataset164preferentiel : aucun enregistrement pour groupe 40
# ⚠️ dataset164preferentiel : aucun enregistrement pour groupe 43
# ⚠️ dataset164preferentiel : aucun enregistrement pour groupe 45
# ⚠️ dataset164preferentiel : aucun enregistrement pour groupe 46
# ⚠️ dataset164preferentiel : aucun enregistrement pour groupe 47
# ⚠️ dataset164preferentiel : aucun enregistrement pour groupe 48
# ✅ Créé : dataset164preferentiel_grp50 (222 lignes)
# ⚠️ dataset164preferentiel : aucun enregistrement pour groupe 53
# ✅ Créé : dataset164preferentiel_grp54 (137 lignes)
# ⚠️ dataset164preferentiel : aucun enregistrement pour groupe 55
# ✅ Créé : dataset164preferentiel_grp56 (1437 lignes)
# ⚠️ dataset164preferentiel : aucun enregistrement pour groupe 57
# ⚠️ dataset164preferentiel : aucun enregistrement pour groupe 60
# ✅ Créé : dataset164preferentiel_grp61 (19 lignes)
# ✅ Créé : dataset164preferentiel_grp64 (366 lignes)
# ✅ Créé : dataset164preferentiel_grp67 (13 lignes)
# ✅ Créé : dataset164preferentiel_grp68 (218 lignes)
# ⚠️ dataset164preferentiel : aucun enregistrement pour groupe 72
# ✅ Créé : dataset164preferentiel_grp75 (283 lignes)
# ⚠️ dataset164preferentiel : aucun enregistrement pour groupe 76
# ✅ Créé : dataset164preferentiel_grp79 (187 lignes)
# ✅ Créé : dataset164preferentiel_grp80 (29 lignes)
# ✅ Créé : dataset164preferentiel_grp83 (40 lignes)
# ✅ Créé : dataset164preferentiel_grp85 (16 lignes)
# ✅ Créé : dataset164preferentiel_grp86 (470 lignes)
# ✅ Créé : dataset164preferentiel_grp89 (25 lignes)
# ⚠️ dataset164preferentiel : aucun enregistrement pour groupe 90
# ⚠️ dataset164preferentiel : aucun enregistrement pour groupe 93
# ⚠️ dataset164preferentiel : aucun enregistrement pour groupe 96
# ⚠️ dataset164preferentiel : aucun enregistrement pour groupe 98
# ✅ Créé : dataset164preferentiel_grp100 (103 lignes)
# ⚠️ dataset164preferentiel : aucun enregistrement pour groupe 101
# ⚠️ dataset164preferentiel : aucun enregistrement pour groupe 106
# ✅ Créé : dataset164preferentiel_grp107 (189 lignes)
# ⚠️ dataset164preferentiel : aucun enregistrement pour groupe 108
# ⚠️ dataset164preferentiel : aucun enregistrement pour groupe 109
# ⚠️ dataset164preferentiel : aucun enregistrement pour groupe 110
# ⚠️ dataset164preferentiel : aucun enregistrement pour groupe 111
# ⚠️ dataset164preferentiel : aucun enregistrement pour groupe 112
# ⚠️ dataset164preferentiel : aucun enregistrement pour groupe 113
# ✅ Créé : dataset164preferentiel_grp114 (19 lignes)
# ✅ Créé : dataset164preferentiel_grp118 (71 lignes)
# ⚠️ dataset164preferentiel : aucun enregistrement pour groupe 120
# ⚠️ dataset164preferentiel : aucun enregistrement pour groupe 121
# ✅ Créé : dataset164preferentiel_grp124 (16 lignes)
# ⚠️ dataset164preferentiel : aucun enregistrement pour groupe 127
# ✅ Créé : dataset164preferentiel_grp128 (19 lignes)
# ✅ Créé : dataset164preferentiel_grp133 (71 lignes)
# ⚠️ dataset164preferentiel : aucun enregistrement pour groupe 134
# ⚠️ dataset164preferentiel : aucun enregistrement pour groupe 135
# ⚠️ dataset164preferentiel : aucun enregistrement pour groupe 138
# ⚠️ dataset164preferentiel : aucun enregistrement pour groupe 139
# ✅ Créé : dataset164preferentiel_grp144 (19 lignes)
# ⚠️ dataset164preferentiel : aucun enregistrement pour groupe 146
# ⚠️ dataset164preferentiel : aucun enregistrement pour groupe 147
# ✅ Créé : dataset164preferentiel_grp148 (55 lignes)
# ⚠️ dataset164preferentiel : aucun enregistrement pour groupe 149
# ⚠️ dataset164preferentiel : aucun enregistrement pour groupe 151
# ⚠️ dataset164preferentiel : aucun enregistrement pour groupe 152
# ✅ Créé : dataset164preferentiel_grp153 (62 lignes)
# ✅ Créé : dataset164preferentiel_grp154 (33 lignes)
# ⚠️ dataset164preferentiel : aucun enregistrement pour groupe 156
# ⚠️ dataset164preferentiel : aucun enregistrement pour groupe 158
# ⚠️ dataset164preferentiel : aucun enregistrement pour groupe 160
# ⚠️ dataset164preferentiel : aucun enregistrement pour groupe 161
# ⚠️ dataset164preferentiel : aucun enregistrement pour groupe 162
# ⚠️ dataset164preferentiel : aucun enregistrement pour groupe 163
# ✅ Créé : dataset164preferentiel_grp164 (22 lignes)
# ⚠️ dataset164preferentiel : aucun enregistrement pour groupe 165
# ⚠️ dataset164preferentiel : aucun enregistrement pour groupe 166
# ⚠️ dataset164preferentiel : aucun enregistrement pour groupe 167
# ⚠️ dataset164preferentiel : aucun enregistrement pour groupe 168
# ⚠️ dataset164preferentiel : aucun enregistrement pour groupe 171
# ⚠️ dataset164preferentiel : aucun enregistrement pour groupe 172
# ⚠️ dataset164preferentiel : aucun enregistrement pour groupe 173
# ⚠️ dataset164preferentiel : aucun enregistrement pour groupe 174
# ⚠️ dataset164preferentiel : aucun enregistrement pour groupe 175
# ⚠️ dataset164preferentiel : aucun enregistrement pour groupe 176
# ⚠️ dataset164preferentiel : aucun enregistrement pour groupe 177
# ⚠️ dataset164preferentiel : aucun enregistrement pour groupe 178
# ⚠️ dataset164preferentiel : aucun enregistrement pour groupe 1000
# ⚠️ dataset164delegation : aucun enregistrement pour groupe 0
# ✅ Créé : dataset164delegation_grp5 (101 lignes)
# ⚠️ dataset164delegation : aucun enregistrement pour groupe 7
# ✅ Créé : dataset164delegation_grp13 (938 lignes)
# ✅ Créé : dataset164delegation_grp14 (226 lignes)
# ✅ Créé : dataset164delegation_grp18 (26 lignes)
# ✅ Créé : dataset164delegation_grp29 (133 lignes)
# ✅ Créé : dataset164delegation_grp35 (29 lignes)
# ✅ Créé : dataset164delegation_grp38 (2660 lignes)
# ✅ Créé : dataset164delegation_grp39 (62 lignes)
# ⚠️ dataset164delegation : aucun enregistrement pour groupe 40
# ✅ Créé : dataset164delegation_grp43 (13 lignes)
# ✅ Créé : dataset164delegation_grp45 (76 lignes)
# ⚠️ dataset164delegation : aucun enregistrement pour groupe 46
# ✅ Créé : dataset164delegation_grp47 (428 lignes)
# ⚠️ dataset164delegation : aucun enregistrement pour groupe 48
# ✅ Créé : dataset164delegation_grp50 (281 lignes)
# ✅ Créé : dataset164delegation_grp53 (30 lignes)
# ✅ Créé : dataset164delegation_grp54 (138 lignes)
# ✅ Créé : dataset164delegation_grp55 (14 lignes)
# ✅ Créé : dataset164delegation_grp56 (280 lignes)
# ⚠️ dataset164delegation : aucun enregistrement pour groupe 57
# ⚠️ dataset164delegation : aucun enregistrement pour groupe 60
# ⚠️ dataset164delegation : aucun enregistrement pour groupe 61
# ✅ Créé : dataset164delegation_grp64 (111 lignes)
# ✅ Créé : dataset164delegation_grp67 (13 lignes)
# ✅ Créé : dataset164delegation_grp68 (25 lignes)
# ✅ Créé : dataset164delegation_grp72 (58 lignes)
# ✅ Créé : dataset164delegation_grp75 (218 lignes)
# ✅ Créé : dataset164delegation_grp76 (113 lignes)
# ✅ Créé : dataset164delegation_grp79 (355 lignes)
# ✅ Créé : dataset164delegation_grp80 (10 lignes)
# ✅ Créé : dataset164delegation_grp83 (134 lignes)
# ✅ Créé : dataset164delegation_grp85 (52 lignes)
# ✅ Créé : dataset164delegation_grp86 (480 lignes)
# ✅ Créé : dataset164delegation_grp89 (73 lignes)
# ⚠️ dataset164delegation : aucun enregistrement pour groupe 90
# ⚠️ dataset164delegation : aucun enregistrement pour groupe 93
# ⚠️ dataset164delegation : aucun enregistrement pour groupe 96
# ⚠️ dataset164delegation : aucun enregistrement pour groupe 98
# ✅ Créé : dataset164delegation_grp100 (52 lignes)
# ✅ Créé : dataset164delegation_grp101 (55 lignes)
# ⚠️ dataset164delegation : aucun enregistrement pour groupe 106
# ✅ Créé : dataset164delegation_grp107 (47 lignes)
# ✅ Créé : dataset164delegation_grp108 (509 lignes)
# ⚠️ dataset164delegation : aucun enregistrement pour groupe 109
# ⚠️ dataset164delegation : aucun enregistrement pour groupe 110
# ⚠️ dataset164delegation : aucun enregistrement pour groupe 111
# ⚠️ dataset164delegation : aucun enregistrement pour groupe 112
# ⚠️ dataset164delegation : aucun enregistrement pour groupe 113
# ✅ Créé : dataset164delegation_grp114 (101 lignes)
# ⚠️ dataset164delegation : aucun enregistrement pour groupe 118
# ⚠️ dataset164delegation : aucun enregistrement pour groupe 120
# ⚠️ dataset164delegation : aucun enregistrement pour groupe 121
# ✅ Créé : dataset164delegation_grp124 (25 lignes)
# ⚠️ dataset164delegation : aucun enregistrement pour groupe 127
# ✅ Créé : dataset164delegation_grp128 (45 lignes)
# ✅ Créé : dataset164delegation_grp133 (65 lignes)
# ⚠️ dataset164delegation : aucun enregistrement pour groupe 134
# ⚠️ dataset164delegation : aucun enregistrement pour groupe 135
# ⚠️ dataset164delegation : aucun enregistrement pour groupe 138
# ⚠️ dataset164delegation : aucun enregistrement pour groupe 139
# ⚠️ dataset164delegation : aucun enregistrement pour groupe 144
# ⚠️ dataset164delegation : aucun enregistrement pour groupe 146
# ⚠️ dataset164delegation : aucun enregistrement pour groupe 147
# ✅ Créé : dataset164delegation_grp148 (59 lignes)
# ⚠️ dataset164delegation : aucun enregistrement pour groupe 149
# ⚠️ dataset164delegation : aucun enregistrement pour groupe 151
# ⚠️ dataset164delegation : aucun enregistrement pour groupe 152
# ✅ Créé : dataset164delegation_grp153 (349 lignes)
# ✅ Créé : dataset164delegation_grp154 (39 lignes)
# ⚠️ dataset164delegation : aucun enregistrement pour groupe 156
# ⚠️ dataset164delegation : aucun enregistrement pour groupe 158
# ⚠️ dataset164delegation : aucun enregistrement pour groupe 160
# ⚠️ dataset164delegation : aucun enregistrement pour groupe 161
# ⚠️ dataset164delegation : aucun enregistrement pour groupe 162
# ⚠️ dataset164delegation : aucun enregistrement pour groupe 163
# ✅ Créé : dataset164delegation_grp164 (19 lignes)
# ⚠️ dataset164delegation : aucun enregistrement pour groupe 165
# ⚠️ dataset164delegation : aucun enregistrement pour groupe 166
# ⚠️ dataset164delegation : aucun enregistrement pour groupe 167
# ⚠️ dataset164delegation : aucun enregistrement pour groupe 168
# ✅ Créé : dataset164delegation_grp171 (3 lignes)
# ✅ Créé : dataset164delegation_grp172 (227 lignes)
# ⚠️ dataset164delegation : aucun enregistrement pour groupe 173
# ⚠️ dataset164delegation : aucun enregistrement pour groupe 174
# ⚠️ dataset164delegation : aucun enregistrement pour groupe 175
# ⚠️ dataset164delegation : aucun enregistrement pour groupe 176
# ⚠️ dataset164delegation : aucun enregistrement pour groupe 177
# ⚠️ dataset164delegation : aucun enregistrement pour groupe 178
# ⚠️ dataset164delegation : aucun enregistrement pour groupe 1000
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 0
# ✅ Créé : dataset164quadriexclusif_grp5 (7 lignes)
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 7
# ✅ Créé : dataset164quadriexclusif_grp13 (1569 lignes)
# ✅ Créé : dataset164quadriexclusif_grp14 (82 lignes)
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 18
# ✅ Créé : dataset164quadriexclusif_grp29 (13 lignes)
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 35
# ✅ Créé : dataset164quadriexclusif_grp38 (1823 lignes)
# ✅ Créé : dataset164quadriexclusif_grp39 (224 lignes)
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 40
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 43
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 45
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 46
# ✅ Créé : dataset164quadriexclusif_grp47 (14 lignes)
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 48
# ✅ Créé : dataset164quadriexclusif_grp50 (488 lignes)
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 53
# ✅ Créé : dataset164quadriexclusif_grp54 (55 lignes)
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 55
# ✅ Créé : dataset164quadriexclusif_grp56 (930 lignes)
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 57
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 60
# ✅ Créé : dataset164quadriexclusif_grp61 (19 lignes)
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 64
# ✅ Créé : dataset164quadriexclusif_grp67 (24 lignes)
# ✅ Créé : dataset164quadriexclusif_grp68 (149 lignes)
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 72
# ✅ Créé : dataset164quadriexclusif_grp75 (140 lignes)
# ✅ Créé : dataset164quadriexclusif_grp76 (12 lignes)
# ✅ Créé : dataset164quadriexclusif_grp79 (223 lignes)
# ✅ Créé : dataset164quadriexclusif_grp80 (25 lignes)
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 83
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 85
# ✅ Créé : dataset164quadriexclusif_grp86 (87 lignes)
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 89
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 90
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 93
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 96
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 98
# ✅ Créé : dataset164quadriexclusif_grp100 (31 lignes)
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 101
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 106
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 107
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 108
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 109
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 110
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 111
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 112
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 113
# ✅ Créé : dataset164quadriexclusif_grp114 (66 lignes)
# ✅ Créé : dataset164quadriexclusif_grp118 (55 lignes)
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 120
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 121
# ✅ Créé : dataset164quadriexclusif_grp124 (15 lignes)
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 127
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 128
# ✅ Créé : dataset164quadriexclusif_grp133 (133 lignes)
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 134
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 135
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 138
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 139
# ✅ Créé : dataset164quadriexclusif_grp144 (32 lignes)
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 146
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 147
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 148
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 149
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 151
# ✅ Créé : dataset164quadriexclusif_grp152 (7 lignes)
# ✅ Créé : dataset164quadriexclusif_grp153 (83 lignes)
# ✅ Créé : dataset164quadriexclusif_grp154 (142 lignes)
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 156
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 158
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 160
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 161
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 162
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 163
# ✅ Créé : dataset164quadriexclusif_grp164 (7 lignes)
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 165
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 166
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 167
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 168
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 171
# ✅ Créé : dataset164quadriexclusif_grp172 (38 lignes)
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 173
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 174
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 175
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 176
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 177
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 178
# ⚠️ dataset164quadriexclusif : aucun enregistrement pour groupe 1000
# Il y a pour l'instant 1809 séries temporelles potentiellement analysables, ce nombre va diminuer quand on regardera le nombre de données disponibles

# %%
# On met les colonnes de dates au format datetime, pour que ce soit analysable par Prophet

for nom_df, df in datasets_groupes.items() :
    colonnes_date_type = df.select_dtypes(include=['datetime64[ns]', 'datetime64[ns, UTC]']).columns.tolist()
    colonnes_date_nom = [col for col in df.columns if 'date' in col.lower() or 'jour' in col.lower() or 'mois' in col.lower()]
    
    colonnes_date = [col for col in df.columns if col in colonnes_date_type or col in colonnes_date_nom]

    if not colonnes_date :
        print(f"❌ Aucune colonne date trouvée dans {nom_df}")
        continue

    colonne_date = colonnes_date[0]  # Choix de la première colonne détectée
    df[colonne_date] = pd.to_datetime(df[colonne_date], errors='coerce')

    if colonne_date != 'date' :
        df.rename(columns={colonne_date: 'date'}, inplace=True)

    datasets_groupes[nom_df] = df
    globals()[nom_df] = df


# On teste que les colonnes soient bien toutes au format datetime
for nom, df in datasets_groupes.items() :
    try:
        if not pd.api.types.is_datetime64_any_dtype(df['date']) :
            print(f"{nom} : ⚠️ colonne 'date' n'est pas de type datetime (type actuel : {df['date'].dtype})")
    except KeyError :
        print(f"{nom} : Pas de colonne date")

# Encore une fois, si rien ne s'affiche après cette cellule c'est bon signe (normalement on a fait tous les traitements
# nécessaires pour que rien ne s'affiche)

# %%
# On agrège par mois

for nom, df in datasets_groupes.items() : # On parcourt le dictionnaire
    if 'date' not in df.columns : # n-ème vérif
        print('Pas de colonne date dans {nom}')
        continue
    df['date'] = df['date'].dt.to_period('M').dt.to_timestamp()
    colonnes_valeurs = [col for col in df.columns if col not in ['date', 'groupe_id']]
    if not colonnes_valeurs:
        print(f"{nom} n'a pas de données autres que groupe_id et date...")
    df_grouped = df.groupby(['date', 'groupe_id'])[colonnes_valeurs].sum().reset_index()
    datasets_groupes[nom] = df_grouped
    globals()[nom] = df_grouped

    print(f"✅ {nom} : groupé par mois ({len(df_grouped)} lignes)")
# Out:
# ✅ dataset146visite_grp5 : groupé par mois (46 lignes)
# ✅ dataset146visite_grp13 : groupé par mois (174 lignes)
# ✅ dataset146visite_grp14 : groupé par mois (165 lignes)
# ✅ dataset146visite_grp18 : groupé par mois (8 lignes)
# ✅ dataset146visite_grp29 : groupé par mois (176 lignes)
# ✅ dataset146visite_grp35 : groupé par mois (180 lignes)
# ✅ dataset146visite_grp38 : groupé par mois (197 lignes)
# ✅ dataset146visite_grp39 : groupé par mois (76 lignes)
# ✅ dataset146visite_grp43 : groupé par mois (110 lignes)
# ✅ dataset146visite_grp45 : groupé par mois (76 lignes)
# ✅ dataset146visite_grp47 : groupé par mois (151 lignes)
# ✅ dataset146visite_grp48 : groupé par mois (1 lignes)
# ✅ dataset146visite_grp50 : groupé par mois (154 lignes)
# ✅ dataset146visite_grp53 : groupé par mois (90 lignes)
# ✅ dataset146visite_grp54 : groupé par mois (110 lignes)
# ✅ dataset146visite_grp55 : groupé par mois (4 lignes)
# ✅ dataset146visite_grp56 : groupé par mois (135 lignes)
# ✅ dataset146visite_grp57 : groupé par mois (85 lignes)
# ✅ dataset146visite_grp60 : groupé par mois (1 lignes)
# ✅ dataset146visite_grp61 : groupé par mois (79 lignes)
# ✅ dataset146visite_grp64 : groupé par mois (96 lignes)
# ✅ dataset146visite_grp67 : groupé par mois (119 lignes)
# ✅ dataset146visite_grp68 : groupé par mois (125 lignes)
# ✅ dataset146visite_grp72 : groupé par mois (101 lignes)
# ✅ dataset146visite_grp75 : groupé par mois (117 lignes)
# ✅ dataset146visite_grp76 : groupé par mois (112 lignes)
# ✅ dataset146visite_grp79 : groupé par mois (113 lignes)
# ✅ dataset146visite_grp80 : groupé par mois (69 lignes)
# ✅ dataset146visite_grp83 : groupé par mois (107 lignes)
# ✅ dataset146visite_grp85 : groupé par mois (104 lignes)
# ✅ dataset146visite_grp86 : groupé par mois (104 lignes)
# ✅ dataset146visite_grp89 : groupé par mois (89 lignes)
# ✅ dataset146visite_grp90 : groupé par mois (1 lignes)
# ✅ dataset146visite_grp93 : groupé par mois (5 lignes)
# ✅ dataset146visite_grp96 : groupé par mois (70 lignes)
# ✅ dataset146visite_grp98 : groupé par mois (15 lignes)
# ✅ dataset146visite_grp100 : groupé par mois (83 lignes)
# ✅ dataset146visite_grp101 : groupé par mois (66 lignes)
# ✅ dataset146visite_grp106 : groupé par mois (6 lignes)
# ✅ dataset146visite_grp107 : groupé par mois (73 lignes)
# ✅ dataset146visite_grp108 : groupé par mois (102 lignes)
# ✅ dataset146visite_grp109 : groupé par mois (55 lignes)
# ✅ dataset146visite_grp112 : groupé par mois (3 lignes)
# ✅ dataset146visite_grp114 : groupé par mois (45 lignes)
# ✅ dataset146visite_grp118 : groupé par mois (62 lignes)
# ✅ dataset156action2_grp50 : groupé par mois (152 lignes)
# ✅ dataset156action2_grp53 : groupé par mois (137 lignes)
# ✅ dataset156action2_grp54 : groupé par mois (142 lignes)
# ✅ dataset156action2_grp55 : groupé par mois (127 lignes)
# ✅ dataset156action2_grp56 : groupé par mois (138 lignes)
# ✅ dataset156action2_grp57 : groupé par mois (121 lignes)
# ✅ dataset156action2_grp60 : groupé par mois (125 lignes)
# ✅ dataset156action2_grp61 : groupé par mois (122 lignes)
# ✅ dataset156action2_grp64 : groupé par mois (129 lignes)
# ✅ dataset156action2_grp67 : groupé par mois (126 lignes)
# ✅ dataset156action2_grp68 : groupé par mois (126 lignes)
# ✅ dataset156action2_grp72 : groupé par mois (120 lignes)
# ✅ dataset156action2_grp75 : groupé par mois (117 lignes)
# ✅ dataset156action2_grp76 : groupé par mois (114 lignes)
# ✅ dataset156action2_grp79 : groupé par mois (113 lignes)
# ✅ dataset156action2_grp80 : groupé par mois (110 lignes)
# ✅ dataset156action2_grp83 : groupé par mois (107 lignes)
# ✅ dataset156action2_grp85 : groupé par mois (105 lignes)
# ✅ dataset156action2_grp86 : groupé par mois (104 lignes)
# ✅ dataset156action2_grp89 : groupé par mois (98 lignes)
# ✅ dataset156action2_grp90 : groupé par mois (96 lignes)
# ✅ dataset156action2_grp93 : groupé par mois (49 lignes)
# ✅ dataset156action2_grp96 : groupé par mois (86 lignes)
# ✅ dataset156action2_grp98 : groupé par mois (88 lignes)
# ✅ dataset156action2_grp100 : groupé par mois (87 lignes)
# ✅ dataset156action2_grp101 : groupé par mois (86 lignes)
# ✅ dataset156action2_grp106 : groupé par mois (62 lignes)
# ✅ dataset156action2_grp107 : groupé par mois (77 lignes)
# ✅ dataset156action2_grp108 : groupé par mois (72 lignes)
# ✅ dataset156action2_grp109 : groupé par mois (73 lignes)
# ✅ dataset156action2_grp110 : groupé par mois (50 lignes)
# ✅ dataset156action2_grp111 : groupé par mois (28 lignes)
# ✅ dataset156action2_grp112 : groupé par mois (23 lignes)
# ✅ dataset156action2_grp113 : groupé par mois (3 lignes)
# ✅ dataset156action2_grp114 : groupé par mois (72 lignes)
# ✅ dataset156action2_grp118 : groupé par mois (63 lignes)
# ✅ dataset156action2_grp120 : groupé par mois (60 lignes)
# ✅ dataset156action2_grp121 : groupé par mois (7 lignes)
# ✅ dataset156action2_grp124 : groupé par mois (56 lignes)
# ✅ dataset156action2_grp127 : groupé par mois (4 lignes)
# ✅ dataset156action2_grp128 : groupé par mois (57 lignes)
# ✅ dataset156action2_grp133 : groupé par mois (54 lignes)
# ✅ dataset156action2_grp134 : groupé par mois (48 lignes)
# ✅ dataset156action2_grp135 : groupé par mois (25 lignes)
# ✅ dataset156action2_grp138 : groupé par mois (57 lignes)
# ✅ dataset156action2_grp139 : groupé par mois (2 lignes)
# ✅ dataset156action2_grp144 : groupé par mois (40 lignes)
# ✅ dataset156action2_grp146 : groupé par mois (13 lignes)
# ✅ dataset156action2_grp147 : groupé par mois (25 lignes)
# ✅ dataset156action2_grp148 : groupé par mois (33 lignes)
# ✅ dataset156action2_grp149 : groupé par mois (18 lignes)
# ✅ dataset156action2_grp151 : groupé par mois (19 lignes)
# ✅ dataset156action2_grp152 : groupé par mois (29 lignes)
# ✅ dataset156action2_grp153 : groupé par mois (177 lignes)
# ✅ dataset156action2_grp154 : groupé par mois (153 lignes)
# ✅ dataset156action2_grp156 : groupé par mois (22 lignes)
# ✅ dataset156action2_grp158 : groupé par mois (11 lignes)
# ✅ dataset156action2_grp160 : groupé par mois (13 lignes)
# ✅ dataset156action2_grp161 : groupé par mois (3 lignes)
# ✅ dataset156action2_grp162 : groupé par mois (9 lignes)
# ✅ dataset156action2_grp163 : groupé par mois (12 lignes)
# ✅ dataset156action2_grp164 : groupé par mois (10 lignes)
# ✅ dataset156action2_grp165 : groupé par mois (4 lignes)
# ✅ dataset156action2_grp167 : groupé par mois (1 lignes)
# ✅ dataset156action2_grp168 : groupé par mois (7 lignes)
# ✅ dataset156action2_grp171 : groupé par mois (5 lignes)
# ✅ dataset156action2_grp172 : groupé par mois (2 lignes)
# ✅ dataset156action2_grp173 : groupé par mois (2 lignes)
# ✅ dataset156action2_grp174 : groupé par mois (3 lignes)
# ✅ dataset156action2_grp175 : groupé par mois (2 lignes)
# ✅ dataset156action3_grp5 : groupé par mois (168 lignes)
# ✅ dataset156action3_grp7 : groupé par mois (176 lignes)
# ✅ dataset156action3_grp13 : groupé par mois (177 lignes)
# ✅ dataset156action3_grp14 : groupé par mois (177 lignes)
# ✅ dataset156action3_grp18 : groupé par mois (177 lignes)
# ✅ dataset156action3_grp29 : groupé par mois (175 lignes)
# ✅ dataset156action3_grp35 : groupé par mois (177 lignes)
# ✅ dataset156action3_grp38 : groupé par mois (175 lignes)
# ✅ dataset156action3_grp39 : groupé par mois (170 lignes)
# ✅ dataset156action3_grp43 : groupé par mois (158 lignes)
# ✅ dataset156action3_grp45 : groupé par mois (135 lignes)
# ✅ dataset156action3_grp47 : groupé par mois (153 lignes)
# ✅ dataset156action3_grp48 : groupé par mois (58 lignes)
# ✅ dataset156action3_grp50 : groupé par mois (152 lignes)
# ✅ dataset156action3_grp53 : groupé par mois (137 lignes)
# ✅ dataset156action3_grp54 : groupé par mois (142 lignes)
# ✅ dataset156action3_grp55 : groupé par mois (127 lignes)
# ✅ dataset156action3_grp56 : groupé par mois (138 lignes)
# ✅ dataset156action3_grp57 : groupé par mois (121 lignes)
# ✅ dataset156action3_grp60 : groupé par mois (125 lignes)
# ✅ dataset156action3_grp61 : groupé par mois (122 lignes)
# ✅ dataset156action3_grp64 : groupé par mois (129 lignes)
# ✅ dataset156action3_grp67 : groupé par mois (126 lignes)
# ✅ dataset156action3_grp68 : groupé par mois (126 lignes)
# ✅ dataset156action3_grp72 : groupé par mois (120 lignes)
# ...
# ✅ dataset164demande_grp79 : groupé par mois (22 lignes)
# ✅ dataset164demande_grp83 : groupé par mois (27 lignes)
# ✅ dataset164demande_grp85 : groupé par mois (15 lignes)
# ✅ dataset164demande_grp86 : groupé par mois (52 lignes)
# ✅ dataset164demande_grp89 : groupé par mois (79 lignes)
# ✅ dataset164demande_grp93 : groupé par mois (36 lignes)
# ✅ dataset164demande_grp100 : groupé par mois (27 lignes)
# ✅ dataset164demande_grp101 : groupé par mois (43 lignes)
# ✅ dataset164demande_grp107 : groupé par mois (45 lignes)
# ✅ dataset164demande_grp108 : groupé par mois (65 lignes)
# ✅ dataset164demande_grp114 : groupé par mois (71 lignes)
# ✅ dataset164demande_grp120 : groupé par mois (13 lignes)
# ✅ dataset164demande_grp124 : groupé par mois (25 lignes)
# ✅ dataset164demande_grp128 : groupé par mois (25 lignes)
# ✅ dataset164demande_grp133 : groupé par mois (54 lignes)
# ✅ dataset164demande_grp144 : groupé par mois (1 lignes)
# ✅ dataset164demande_grp148 : groupé par mois (30 lignes)
# ✅ dataset164demande_grp152 : groupé par mois (8 lignes)
# ✅ dataset164demande_grp153 : groupé par mois (154 lignes)
# ✅ dataset164demande_grp164 : groupé par mois (9 lignes)
# ✅ dataset164exclusif_grp5 : groupé par mois (153 lignes)
# ✅ dataset164exclusif_grp13 : groupé par mois (204 lignes)
# ✅ dataset164exclusif_grp14 : groupé par mois (133 lignes)
# ✅ dataset164exclusif_grp18 : groupé par mois (26 lignes)
# ✅ dataset164exclusif_grp29 : groupé par mois (123 lignes)
# ✅ dataset164exclusif_grp35 : groupé par mois (179 lignes)
# ✅ dataset164exclusif_grp38 : groupé par mois (204 lignes)
# ✅ dataset164exclusif_grp39 : groupé par mois (115 lignes)
# ✅ dataset164exclusif_grp43 : groupé par mois (40 lignes)
# ✅ dataset164exclusif_grp45 : groupé par mois (165 lignes)
# ✅ dataset164exclusif_grp47 : groupé par mois (168 lignes)
# ✅ dataset164exclusif_grp50 : groupé par mois (204 lignes)
# ✅ dataset164exclusif_grp53 : groupé par mois (108 lignes)
# ✅ dataset164exclusif_grp54 : groupé par mois (60 lignes)
# ✅ dataset164exclusif_grp56 : groupé par mois (204 lignes)
# ✅ dataset164exclusif_grp61 : groupé par mois (65 lignes)
# ✅ dataset164exclusif_grp64 : groupé par mois (136 lignes)
# ✅ dataset164exclusif_grp67 : groupé par mois (100 lignes)
# ✅ dataset164exclusif_grp68 : groupé par mois (146 lignes)
# ✅ dataset164exclusif_grp72 : groupé par mois (37 lignes)
# ✅ dataset164exclusif_grp75 : groupé par mois (204 lignes)
# ✅ dataset164exclusif_grp76 : groupé par mois (115 lignes)
# ✅ dataset164exclusif_grp79 : groupé par mois (202 lignes)
# ✅ dataset164exclusif_grp80 : groupé par mois (63 lignes)
# ✅ dataset164exclusif_grp83 : groupé par mois (107 lignes)
# ✅ dataset164exclusif_grp85 : groupé par mois (128 lignes)
# ✅ dataset164exclusif_grp86 : groupé par mois (118 lignes)
# ✅ dataset164exclusif_grp89 : groupé par mois (121 lignes)
# ✅ dataset164exclusif_grp90 : groupé par mois (13 lignes)
# ✅ dataset164exclusif_grp93 : groupé par mois (13 lignes)
# ✅ dataset164exclusif_grp96 : groupé par mois (26 lignes)
# ✅ dataset164exclusif_grp98 : groupé par mois (73 lignes)
# ✅ dataset164delegation_grp172 : groupé par mois (164 lignes)
# ✅ dataset164quadriexclusif_grp5 : groupé par mois (7 lignes)
# ✅ dataset164quadriexclusif_grp13 : groupé par mois (204 lignes)
# ✅ dataset164quadriexclusif_grp14 : groupé par mois (59 lignes)
# ✅ dataset164quadriexclusif_grp29 : groupé par mois (13 lignes)
# ✅ dataset164quadriexclusif_grp38 : groupé par mois (181 lignes)
# ✅ dataset164quadriexclusif_grp39 : groupé par mois (102 lignes)
# ✅ dataset164quadriexclusif_grp47 : groupé par mois (14 lignes)
# ✅ dataset164quadriexclusif_grp50 : groupé par mois (148 lignes)
# ✅ dataset164quadriexclusif_grp54 : groupé par mois (33 lignes)
# ✅ dataset164quadriexclusif_grp56 : groupé par mois (202 lignes)
# ✅ dataset164quadriexclusif_grp61 : groupé par mois (19 lignes)
# ✅ dataset164quadriexclusif_grp67 : groupé par mois (24 lignes)
# ✅ dataset164quadriexclusif_grp68 : groupé par mois (88 lignes)
# ✅ dataset164quadriexclusif_grp75 : groupé par mois (86 lignes)
# ✅ dataset164quadriexclusif_grp76 : groupé par mois (12 lignes)
# ✅ dataset164quadriexclusif_grp79 : groupé par mois (94 lignes)
# ✅ dataset164quadriexclusif_grp80 : groupé par mois (25 lignes)
# ✅ dataset164quadriexclusif_grp86 : groupé par mois (69 lignes)
# ✅ dataset164quadriexclusif_grp100 : groupé par mois (31 lignes)
# ✅ dataset164quadriexclusif_grp114 : groupé par mois (49 lignes)
# ✅ dataset164quadriexclusif_grp118 : groupé par mois (31 lignes)
# ✅ dataset164quadriexclusif_grp124 : groupé par mois (15 lignes)
# ✅ dataset164quadriexclusif_grp133 : groupé par mois (60 lignes)
# ✅ dataset164quadriexclusif_grp144 : groupé par mois (32 lignes)
# ✅ dataset164quadriexclusif_grp152 : groupé par mois (7 lignes)
# ✅ dataset164quadriexclusif_grp153 : groupé par mois (83 lignes)
# ✅ dataset164quadriexclusif_grp154 : groupé par mois (99 lignes)
# ✅ dataset164quadriexclusif_grp164 : groupé par mois (7 lignes)
# ✅ dataset164quadriexclusif_grp172 : groupé par mois (38 lignes)

# %%
# Pour plus de simplicité par la suite, on renomme en 'valeur' la colonne de valeurs de chaque série temp

for nom, df in datasets_groupes.items():
    colonnes_a_renommer = [col for col in df.columns if col not in ['date', 'groupe_id']]
    if len(colonnes_a_renommer) != 1:
        print(f"{nom} : {len(colonnes_a_renommer)} IL Y A PLUS D'UNE COLONNE DE VALEURS !!!") # n-ème vérif
        continue  # On ne renomme que s'il y a une seule colonne à renommer
    df = df.rename(columns={colonnes_a_renommer[0]: 'valeur'})
    datasets_groupes[nom] = df
    globals()[nom] = df

# Si rien ne s'affiche après cette cellule c'est bon signe

# %%
# On supprime les données aberrantes

for nom_groupe, df in datasets_groupes.items():
    # Suppression des NaNs si jamais
    df = df.dropna(subset=['valeur'])

    # Détection des outliers via IQR (interquantile range, bref, on regarde à quel point la distribution est dispersée)
    Q1 = df['valeur'].quantile(0.25)
    Q3 = df['valeur'].quantile(0.75)
    IQR = Q3 - Q1

    borne_basse = Q1 - 3 * IQR # 3 c'est beaucoup mais avec la croissance de certaines séries temp qui partent de bas
    borne_haute = Q3 + 3 * IQR # et les forts effets de saisonnalité, on risque d'avoir régulièrement des valeurs détectées
                               # comme outliers alors qu'elles n'en sont pas si on n'est pas souple

    # Suppression des outliers
    df_sans_outliers = df[(df['valeur'] >= borne_basse) & (df['valeur'] <= borne_haute)]

    datasets_groupes[nom_groupe] = df_sans_outliers

    # Mise à jour de la variable globale si elle existe
    if nom_groupe in globals():
        globals()[nom_groupe] = df_sans_outliers

    if len(df) - len(df_sans_outliers) != 0 :
        print(f"{nom_groupe} : {len(df) - len(df_sans_outliers)} outliers supprimés sur {len(df)} lignes.")
# Out:
# dataset146visite_grp5 : 1 outliers supprimés sur 46 lignes.
# dataset146visite_grp53 : 1 outliers supprimés sur 90 lignes.
# dataset146visite_grp76 : 1 outliers supprimés sur 112 lignes.
# dataset146visite_grp79 : 1 outliers supprimés sur 113 lignes.
# dataset146visite_grp85 : 4 outliers supprimés sur 104 lignes.
# dataset146visite_grp93 : 1 outliers supprimés sur 5 lignes.
# dataset146visite_grp114 : 3 outliers supprimés sur 45 lignes.
# dataset146visite_grp120 : 1 outliers supprimés sur 47 lignes.
# dataset146visite_grp124 : 2 outliers supprimés sur 49 lignes.
# dataset146visite_grp154 : 1 outliers supprimés sur 5 lignes.
# dataset146visite_grp156 : 1 outliers supprimés sur 6 lignes.
# dataset146proposition_grp29 : 1 outliers supprimés sur 6 lignes.
# dataset146proposition_grp47 : 8 outliers supprimés sur 33 lignes.
# dataset146proposition_grp50 : 1 outliers supprimés sur 29 lignes.
# dataset146proposition_grp75 : 1 outliers supprimés sur 8 lignes.
# dataset146rdv_grp54 : 3 outliers supprimés sur 93 lignes.
# dataset146rdv_grp79 : 1 outliers supprimés sur 97 lignes.
# dataset146rdv_grp89 : 2 outliers supprimés sur 10 lignes.
# dataset146rdv_grp114 : 3 outliers supprimés sur 30 lignes.
# dataset146rdv_grp162 : 1 outliers supprimés sur 9 lignes.
# dataset147_grp5 : 1 outliers supprimés sur 8 lignes.
# dataset147_grp67 : 1 outliers supprimés sur 127 lignes.
# dataset147_grp72 : 1 outliers supprimés sur 121 lignes.
# dataset147_grp79 : 3 outliers supprimés sur 66 lignes.
# dataset147_grp89 : 2 outliers supprimés sur 107 lignes.
# dataset147_grp93 : 2 outliers supprimés sur 9 lignes.
# dataset147_grp96 : 1 outliers supprimés sur 17 lignes.
# dataset147_grp107 : 2 outliers supprimés sur 181 lignes.
# dataset147_grp109 : 3 outliers supprimés sur 75 lignes.
# dataset147_grp128 : 2 outliers supprimés sur 46 lignes.
# dataset147_grp134 : 2 outliers supprimés sur 13 lignes.
# dataset147_grp147 : 3 outliers supprimés sur 16 lignes.
# dataset147_grp156 : 4 outliers supprimés sur 10 lignes.
# dataset147_grp172 : 2 outliers supprimés sur 67 lignes.
# dataset148_grp5 : 8 outliers supprimés sur 187 lignes.
# dataset148_grp7 : 9 outliers supprimés sur 203 lignes.
# dataset148_grp13 : 3 outliers supprimés sur 204 lignes.
# dataset148_grp14 : 2 outliers supprimés sur 200 lignes.
# dataset148_grp18 : 3 outliers supprimés sur 153 lignes.
# dataset148_grp29 : 5 outliers supprimés sur 176 lignes.
# dataset148_grp35 : 2 outliers supprimés sur 181 lignes.
# dataset148_grp39 : 4 outliers supprimés sur 116 lignes.
# dataset148_grp45 : 1 outliers supprimés sur 137 lignes.
# dataset148_grp47 : 1 outliers supprimés sur 153 lignes.
# dataset148_grp53 : 6 outliers supprimés sur 122 lignes.
# dataset148_grp54 : 8 outliers supprimés sur 153 lignes.
# dataset148_grp56 : 1 outliers supprimés sur 204 lignes.
# dataset148_grp57 : 2 outliers supprimés sur 104 lignes.
# dataset148_grp60 : 9 outliers supprimés sur 129 lignes.
# dataset148_grp61 : 1 outliers supprimés sur 117 lignes.
# dataset148_grp64 : 3 outliers supprimés sur 123 lignes.
# dataset148_grp67 : 1 outliers supprimés sur 126 lignes.
# dataset148_grp72 : 2 outliers supprimés sur 120 lignes.
# dataset148_grp76 : 1 outliers supprimés sur 113 lignes.
# dataset148_grp79 : 3 outliers supprimés sur 204 lignes.
# dataset148_grp80 : 3 outliers supprimés sur 110 lignes.
# dataset148_grp85 : 4 outliers supprimés sur 105 lignes.
# dataset148_grp86 : 1 outliers supprimés sur 193 lignes.
# dataset148_grp89 : 3 outliers supprimés sur 100 lignes.
# dataset148_grp90 : 1 outliers supprimés sur 24 lignes.
# dataset148_grp96 : 4 outliers supprimés sur 148 lignes.
# dataset148_grp98 : 2 outliers supprimés sur 24 lignes.
# dataset148_grp100 : 1 outliers supprimés sur 87 lignes.
# dataset148_grp107 : 4 outliers supprimés sur 109 lignes.
# dataset148_grp113 : 4 outliers supprimés sur 40 lignes.
# dataset148_grp114 : 4 outliers supprimés sur 71 lignes.
# dataset148_grp118 : 2 outliers supprimés sur 63 lignes.
# dataset148_grp120 : 2 outliers supprimés sur 55 lignes.
# dataset148_grp124 : 1 outliers supprimés sur 52 lignes.
# dataset148_grp127 : 2 outliers supprimés sur 53 lignes.
# dataset148_grp128 : 1 outliers supprimés sur 57 lignes.
# dataset148_grp133 : 6 outliers supprimés sur 185 lignes.
# dataset148_grp134 : 3 outliers supprimés sur 48 lignes.
# dataset148_grp144 : 1 outliers supprimés sur 148 lignes.
# dataset148_grp146 : 2 outliers supprimés sur 9 lignes.
# dataset148_grp148 : 1 outliers supprimés sur 33 lignes.
# dataset148_grp149 : 1 outliers supprimés sur 5 lignes.
# dataset148_grp151 : 2 outliers supprimés sur 14 lignes.
# dataset148_grp152 : 1 outliers supprimés sur 26 lignes.
# dataset148_grp153 : 5 outliers supprimés sur 176 lignes.
# dataset148_grp154 : 1 outliers supprimés sur 41 lignes.
# dataset148_grp156 : 2 outliers supprimés sur 10 lignes.
# dataset148_grp162 : 1 outliers supprimés sur 9 lignes.
# dataset148_grp172 : 8 outliers supprimés sur 175 lignes.
# dataset149_grp5 : 1 outliers supprimés sur 187 lignes.
# dataset149_grp7 : 3 outliers supprimés sur 203 lignes.
# dataset149_grp13 : 1 outliers supprimés sur 204 lignes.
# dataset149_grp14 : 1 outliers supprimés sur 200 lignes.
# dataset149_grp18 : 3 outliers supprimés sur 153 lignes.
# dataset149_grp39 : 3 outliers supprimés sur 116 lignes.
# dataset149_grp50 : 1 outliers supprimés sur 203 lignes.
# dataset149_grp54 : 9 outliers supprimés sur 153 lignes.
# dataset149_grp56 : 1 outliers supprimés sur 204 lignes.
# dataset149_grp57 : 2 outliers supprimés sur 104 lignes.
# dataset149_grp60 : 1 outliers supprimés sur 129 lignes.
# dataset149_grp67 : 2 outliers supprimés sur 126 lignes.
# dataset149_grp76 : 1 outliers supprimés sur 113 lignes.
# dataset149_grp90 : 1 outliers supprimés sur 24 lignes.
# dataset149_grp96 : 2 outliers supprimés sur 148 lignes.
# dataset149_grp98 : 1 outliers supprimés sur 24 lignes.
# dataset149_grp106 : 6 outliers supprimés sur 34 lignes.
# dataset149_grp107 : 2 outliers supprimés sur 109 lignes.
# dataset149_grp113 : 1 outliers supprimés sur 40 lignes.
# dataset149_grp114 : 2 outliers supprimés sur 71 lignes.
# dataset149_grp127 : 3 outliers supprimés sur 53 lignes.
# dataset149_grp133 : 2 outliers supprimés sur 185 lignes.
# dataset149_grp135 : 1 outliers supprimés sur 32 lignes.
# dataset149_grp144 : 11 outliers supprimés sur 148 lignes.
# dataset149_grp146 : 2 outliers supprimés sur 9 lignes.
# dataset149_grp149 : 1 outliers supprimés sur 5 lignes.
# dataset149_grp154 : 1 outliers supprimés sur 41 lignes.
# dataset149_grp156 : 1 outliers supprimés sur 10 lignes.
# dataset150_grp5 : 5 outliers supprimés sur 190 lignes.
# dataset150_grp7 : 2 outliers supprimés sur 204 lignes.
# dataset150_grp13 : 2 outliers supprimés sur 204 lignes.
# dataset150_grp14 : 1 outliers supprimés sur 204 lignes.
# dataset150_grp18 : 2 outliers supprimés sur 187 lignes.
# dataset150_grp29 : 7 outliers supprimés sur 182 lignes.
# dataset150_grp35 : 8 outliers supprimés sur 179 lignes.
# dataset150_grp38 : 5 outliers supprimés sur 204 lignes.
# dataset150_grp39 : 4 outliers supprimés sur 199 lignes.
# dataset150_grp43 : 2 outliers supprimés sur 158 lignes.
# dataset150_grp45 : 17 outliers supprimés sur 150 lignes.
# dataset150_grp47 : 4 outliers supprimés sur 154 lignes.
# dataset150_grp48 : 3 outliers supprimés sur 115 lignes.
# dataset150_grp50 : 4 outliers supprimés sur 204 lignes.
# dataset150_grp53 : 10 outliers supprimés sur 127 lignes.
# dataset150_grp54 : 3 outliers supprimés sur 180 lignes.
# dataset150_grp55 : 2 outliers supprimés sur 131 lignes.
# dataset150_grp56 : 4 outliers supprimés sur 204 lignes.
# dataset150_grp57 : 5 outliers supprimés sur 105 lignes.
# dataset150_grp60 : 4 outliers supprimés sur 129 lignes.
# dataset150_grp61 : 4 outliers supprimés sur 127 lignes.
# dataset150_grp64 : 1 outliers supprimés sur 125 lignes.
# dataset150_grp67 : 3 outliers supprimés sur 202 lignes.
# dataset150_grp68 : 4 outliers supprimés sur 193 lignes.
# dataset150_grp72 : 7 outliers supprimés sur 118 lignes.
# dataset150_grp75 : 5 outliers supprimés sur 205 lignes.
# dataset150_grp76 : 3 outliers supprimés sur 114 lignes.
# dataset150_grp79 : 9 outliers supprimés sur 204 lignes.
# dataset150_grp80 : 2 outliers supprimés sur 111 lignes.
# dataset150_grp83 : 3 outliers supprimés sur 200 lignes.
# dataset150_grp85 : 4 outliers supprimés sur 105 lignes.
# dataset150_grp86 : 4 outliers supprimés sur 105 lignes.
# dataset150_grp89 : 4 outliers supprimés sur 101 lignes.
# dataset150_grp90 : 3 outliers supprimés sur 101 lignes.
# dataset150_grp93 : 2 outliers supprimés sur 54 lignes.
# dataset150_grp96 : 3 outliers supprimés sur 197 lignes.
# dataset150_grp98 : 5 outliers supprimés sur 135 lignes.
# dataset150_grp100 : 1 outliers supprimés sur 87 lignes.
# dataset150_grp101 : 4 outliers supprimés sur 87 lignes.
# dataset150_grp106 : 4 outliers supprimés sur 67 lignes.
# dataset150_grp107 : 3 outliers supprimés sur 101 lignes.
# dataset150_grp108 : 6 outliers supprimés sur 203 lignes.
# dataset150_grp109 : 1 outliers supprimés sur 73 lignes.
# dataset150_grp111 : 1 outliers supprimés sur 30 lignes.
# dataset150_grp112 : 1 outliers supprimés sur 72 lignes.
# dataset150_grp114 : 1 outliers supprimés sur 72 lignes.
# dataset150_grp118 : 2 outliers supprimés sur 105 lignes.
# dataset150_grp120 : 4 outliers supprimés sur 61 lignes.
# dataset150_grp121 : 1 outliers supprimés sur 15 lignes.
# dataset150_grp124 : 4 outliers supprimés sur 55 lignes.
# dataset150_grp127 : 2 outliers supprimés sur 60 lignes.
# dataset150_grp128 : 2 outliers supprimés sur 58 lignes.
# dataset150_grp133 : 15 outliers supprimés sur 205 lignes.
# dataset150_grp134 : 2 outliers supprimés sur 39 lignes.
# dataset150_grp135 : 1 outliers supprimés sur 30 lignes.
# dataset150_grp138 : 1 outliers supprimés sur 72 lignes.
# dataset150_grp144 : 4 outliers supprimés sur 110 lignes.
# dataset150_grp147 : 4 outliers supprimés sur 23 lignes.
# dataset150_grp148 : 1 outliers supprimés sur 33 lignes.
# dataset150_grp149 : 2 outliers supprimés sur 26 lignes.
# dataset150_grp151 : 3 outliers supprimés sur 21 lignes.
# dataset150_grp153 : 5 outliers supprimés sur 192 lignes.
# dataset150_grp154 : 5 outliers supprimés sur 191 lignes.
# dataset150_grp161 : 1 outliers supprimés sur 13 lignes.
# dataset150_grp162 : 7 outliers supprimés sur 164 lignes.
# dataset150_grp163 : 1 outliers supprimés sur 12 lignes.
# dataset150_grp164 : 1 outliers supprimés sur 11 lignes.
# dataset150_grp165 : 2 outliers supprimés sur 10 lignes.
# dataset150_grp172 : 12 outliers supprimés sur 202 lignes.
# dataset150_grp173 : 4 outliers supprimés sur 191 lignes.
# dataset151_grp5 : 2 outliers supprimés sur 190 lignes.
# dataset151_grp13 : 3 outliers supprimés sur 204 lignes.
# dataset151_grp14 : 2 outliers supprimés sur 204 lignes.
# dataset152_grp60 : 2 outliers supprimés sur 128 lignes.
# dataset152_grp61 : 1 outliers supprimés sur 127 lignes.
# dataset152_grp72 : 1 outliers supprimés sur 117 lignes.
# dataset152_grp76 : 3 outliers supprimés sur 114 lignes.
# dataset152_grp80 : 2 outliers supprimés sur 111 lignes.
# dataset152_grp83 : 2 outliers supprimés sur 200 lignes.
# dataset152_grp85 : 2 outliers supprimés sur 105 lignes.
# dataset152_grp86 : 3 outliers supprimés sur 105 lignes.
# dataset152_grp89 : 3 outliers supprimés sur 101 lignes.
# dataset152_grp93 : 5 outliers supprimés sur 54 lignes.
# dataset152_grp96 : 1 outliers supprimés sur 197 lignes.
# dataset152_grp98 : 2 outliers supprimés sur 134 lignes.
# dataset152_grp107 : 2 outliers supprimés sur 101 lignes.
# dataset152_grp111 : 1 outliers supprimés sur 30 lignes.
# dataset152_grp112 : 1 outliers supprimés sur 72 lignes.
# dataset152_grp120 : 1 outliers supprimés sur 61 lignes.
# dataset152_grp121 : 1 outliers supprimés sur 15 lignes.
# dataset152_grp124 : 1 outliers supprimés sur 55 lignes.
# dataset152_grp133 : 8 outliers supprimés sur 205 lignes.
# dataset152_grp134 : 1 outliers supprimés sur 39 lignes.
# dataset152_grp144 : 1 outliers supprimés sur 110 lignes.
# dataset152_grp147 : 1 outliers supprimés sur 23 lignes.
# dataset152_grp149 : 1 outliers supprimés sur 26 lignes.
# dataset152_grp154 : 5 outliers supprimés sur 191 lignes.
# dataset152_grp158 : 1 outliers supprimés sur 12 lignes.
# dataset152_grp160 : 1 outliers supprimés sur 13 lignes.
# dataset152_grp162 : 20 outliers supprimés sur 164 lignes.
# dataset152_grp165 : 1 outliers supprimés sur 10 lignes.
# dataset152_grp171 : 1 outliers supprimés sur 6 lignes.
# dataset152_grp173 : 2 outliers supprimés sur 191 lignes.
# dataset153_grp5 : 1 outliers supprimés sur 186 lignes.
# dataset153_grp7 : 7 outliers supprimés sur 203 lignes.
# dataset153_grp13 : 1 outliers supprimés sur 204 lignes.
# dataset153_grp14 : 1 outliers supprimés sur 200 lignes.
# dataset153_grp18 : 5 outliers supprimés sur 151 lignes.
# dataset153_grp39 : 2 outliers supprimés sur 76 lignes.
# dataset153_grp50 : 1 outliers supprimés sur 203 lignes.
# dataset153_grp53 : 1 outliers supprimés sur 108 lignes.
# dataset153_grp54 : 8 outliers supprimés sur 151 lignes.
# dataset153_grp56 : 1 outliers supprimés sur 204 lignes.
# dataset153_grp57 : 2 outliers supprimés sur 104 lignes.
# dataset153_grp60 : 1 outliers supprimés sur 129 lignes.
# dataset153_grp67 : 2 outliers supprimés sur 126 lignes.
# dataset153_grp76 : 1 outliers supprimés sur 113 lignes.
# dataset153_grp90 : 1 outliers supprimés sur 20 lignes.
# dataset153_grp96 : 2 outliers supprimés sur 148 lignes.
# dataset153_grp98 : 1 outliers supprimés sur 6 lignes.
# dataset153_grp106 : 6 outliers supprimés sur 34 lignes.
# dataset153_grp107 : 2 outliers supprimés sur 109 lignes.
# dataset153_grp113 : 1 outliers supprimés sur 40 lignes.
# dataset153_grp114 : 2 outliers supprimés sur 71 lignes.
# dataset153_grp127 : 3 outliers supprimés sur 53 lignes.
# dataset153_grp133 : 1 outliers supprimés sur 139 lignes.
# dataset153_grp135 : 1 outliers supprimés sur 32 lignes.
# dataset153_grp144 : 11 outliers supprimés sur 148 lignes.
# dataset153_grp146 : 2 outliers supprimés sur 9 lignes.
# dataset153_grp149 : 1 outliers supprimés sur 5 lignes.
# dataset153_grp154 : 1 outliers supprimés sur 41 lignes.
# dataset153_grp156 : 1 outliers supprimés sur 10 lignes.
# dataset156action1_grp5 : 4 outliers supprimés sur 168 lignes.
# dataset156action1_grp13 : 3 outliers supprimés sur 177 lignes.
# dataset156action1_grp14 : 3 outliers supprimés sur 177 lignes.
# dataset156action1_grp18 : 4 outliers supprimés sur 177 lignes.
# dataset156action1_grp35 : 1 outliers supprimés sur 177 lignes.
# dataset156action1_grp38 : 14 outliers supprimés sur 175 lignes.
# dataset156action1_grp43 : 8 outliers supprimés sur 158 lignes.
# dataset156action1_grp45 : 1 outliers supprimés sur 135 lignes.
# dataset156action1_grp48 : 1 outliers supprimés sur 58 lignes.
# dataset156action1_grp50 : 1 outliers supprimés sur 152 lignes.
# dataset156action1_grp53 : 6 outliers supprimés sur 137 lignes.
# dataset156action1_grp54 : 2 outliers supprimés sur 142 lignes.
# dataset156action1_grp57 : 3 outliers supprimés sur 121 lignes.
# dataset156action1_grp67 : 1 outliers supprimés sur 126 lignes.
# dataset156action1_grp76 : 1 outliers supprimés sur 114 lignes.
# dataset156action1_grp80 : 2 outliers supprimés sur 110 lignes.
# dataset156action1_grp83 : 3 outliers supprimés sur 107 lignes.
# dataset156action1_grp89 : 4 outliers supprimés sur 98 lignes.
# dataset156action1_grp93 : 3 outliers supprimés sur 49 lignes.
# dataset156action1_grp98 : 2 outliers supprimés sur 88 lignes.
# dataset156action1_grp107 : 1 outliers supprimés sur 77 lignes.
# dataset156action1_grp108 : 2 outliers supprimés sur 72 lignes.
# dataset156action1_grp111 : 1 outliers supprimés sur 28 lignes.
# dataset156action1_grp118 : 1 outliers supprimés sur 63 lignes.
# dataset156action1_grp120 : 2 outliers supprimés sur 60 lignes.
# dataset156action1_grp133 : 1 outliers supprimés sur 54 lignes.
# dataset156action1_grp138 : 1 outliers supprimés sur 57 lignes.
# dataset156action1_grp146 : 1 outliers supprimés sur 13 lignes.
# dataset156action1_grp147 : 2 outliers supprimés sur 25 lignes.
# dataset156action1_grp148 : 1 outliers supprimés sur 33 lignes.
# dataset156action1_grp149 : 2 outliers supprimés sur 18 lignes.
# dataset156action1_grp152 : 1 outliers supprimés sur 29 lignes.
# dataset156action1_grp160 : 1 outliers supprimés sur 13 lignes.
# dataset156action2_grp5 : 3 outliers supprimés sur 168 lignes.
# dataset156action2_grp7 : 3 outliers supprimés sur 176 lignes.
# dataset156action2_grp14 : 2 outliers supprimés sur 177 lignes.
# dataset156action2_grp18 : 7 outliers supprimés sur 177 lignes.
# dataset156action2_grp29 : 1 outliers supprimés sur 175 lignes.
# dataset156action2_grp38 : 8 outliers supprimés sur 175 lignes.
# dataset156action2_grp39 : 1 outliers supprimés sur 170 lignes.
# dataset156action2_grp43 : 17 outliers supprimés sur 158 lignes.
# dataset156action2_grp47 : 1 outliers supprimés sur 153 lignes.
# dataset156action2_grp48 : 9 outliers supprimés sur 58 lignes.
# dataset156action2_grp50 : 2 outliers supprimés sur 152 lignes.
# dataset156action2_grp53 : 1 outliers supprimés sur 137 lignes.
# dataset156action2_grp55 : 22 outliers supprimés sur 127 lignes.
# dataset156action2_grp56 : 1 outliers supprimés sur 138 lignes.
# dataset156action2_grp57 : 10 outliers supprimés sur 121 lignes.
# dataset156action2_grp60 : 2 outliers supprimés sur 125 lignes.
# dataset156action2_grp72 : 2 outliers supprimés sur 120 lignes.
# dataset156action2_grp75 : 2 outliers supprimés sur 117 lignes.
# dataset156action2_grp79 : 2 outliers supprimés sur 113 lignes.
# dataset156action2_grp80 : 2 outliers supprimés sur 110 lignes.
# dataset156action2_grp93 : 3 outliers supprimés sur 49 lignes.
# dataset156action2_grp96 : 1 outliers supprimés sur 86 lignes.
# dataset156action2_grp98 : 6 outliers supprimés sur 88 lignes.
# dataset156action2_grp106 : 2 outliers supprimés sur 62 lignes.
# dataset156action2_grp108 : 2 outliers supprimés sur 72 lignes.
# dataset156action2_grp110 : 10 outliers supprimés sur 50 lignes.
# dataset156action2_grp111 : 3 outliers supprimés sur 28 lignes.
# dataset156action2_grp112 : 2 outliers supprimés sur 23 lignes.
# dataset156action2_grp114 : 1 outliers supprimés sur 72 lignes.
# dataset156action2_grp118 : 2 outliers supprimés sur 63 lignes.
# dataset156action2_grp133 : 1 outliers supprimés sur 54 lignes.
# dataset156action2_grp134 : 2 outliers supprimés sur 48 lignes.
# dataset156action2_grp138 : 9 outliers supprimés sur 57 lignes.
# dataset156action2_grp144 : 2 outliers supprimés sur 40 lignes.
# dataset156action2_grp147 : 1 outliers supprimés sur 25 lignes.
# dataset156action2_grp148 : 2 outliers supprimés sur 33 lignes.
# dataset156action2_grp153 : 3 outliers supprimés sur 177 lignes.
# dataset156action2_grp154 : 1 outliers supprimés sur 153 lignes.
# dataset156action2_grp156 : 1 outliers supprimés sur 22 lignes.
# dataset156action2_grp160 : 1 outliers supprimés sur 13 lignes.
# dataset156action2_grp163 : 1 outliers supprimés sur 12 lignes.
# dataset156action3_grp5 : 1 outliers supprimés sur 168 lignes.
# dataset156action3_grp7 : 3 outliers supprimés sur 176 lignes.
# dataset156action3_grp18 : 4 outliers supprimés sur 177 lignes.
# dataset156action3_grp29 : 3 outliers supprimés sur 175 lignes.
# dataset156action3_grp38 : 1 outliers supprimés sur 175 lignes.
# dataset156action3_grp39 : 7 outliers supprimés sur 170 lignes.
# dataset156action3_grp43 : 2 outliers supprimés sur 158 lignes.
# dataset156action3_grp45 : 3 outliers supprimés sur 135 lignes.
# dataset156action3_grp47 : 2 outliers supprimés sur 153 lignes.
# dataset156action3_grp48 : 1 outliers supprimés sur 58 lignes.
# dataset156action3_grp53 : 6 outliers supprimés sur 137 lignes.
# dataset156action3_grp54 : 2 outliers supprimés sur 142 lignes.
# dataset156action3_grp55 : 14 outliers supprimés sur 127 lignes.
# dataset156action3_grp56 : 2 outliers supprimés sur 138 lignes.
# dataset156action3_grp57 : 6 outliers supprimés sur 121 lignes.
# dataset156action3_grp60 : 6 outliers supprimés sur 125 lignes.
# dataset156action3_grp64 : 1 outliers supprimés sur 129 lignes.
# dataset156action3_grp67 : 2 outliers supprimés sur 126 lignes.
# dataset156action3_grp83 : 1 outliers supprimés sur 107 lignes.
# dataset156action3_grp85 : 2 outliers supprimés sur 105 lignes.
# dataset156action3_grp86 : 3 outliers supprimés sur 104 lignes.
# dataset156action3_grp89 : 1 outliers supprimés sur 98 lignes.
# dataset156action3_grp90 : 11 outliers supprimés sur 96 lignes.
# dataset156action3_grp93 : 4 outliers supprimés sur 49 lignes.
# dataset156action3_grp96 : 1 outliers supprimés sur 86 lignes.
# dataset156action3_grp98 : 3 outliers supprimés sur 88 lignes.
# dataset156action3_grp106 : 1 outliers supprimés sur 62 lignes.
# dataset156action3_grp108 : 2 outliers supprimés sur 72 lignes.
# dataset156action3_grp109 : 2 outliers supprimés sur 73 lignes.
# dataset156action3_grp110 : 1 outliers supprimés sur 50 lignes.
# dataset156action3_grp111 : 1 outliers supprimés sur 28 lignes.
# dataset156action3_grp112 : 1 outliers supprimés sur 23 lignes.
# dataset156action3_grp114 : 1 outliers supprimés sur 72 lignes.
# dataset156action3_grp120 : 10 outliers supprimés sur 60 lignes.
# dataset156action3_grp121 : 1 outliers supprimés sur 7 lignes.
# dataset156action3_grp128 : 1 outliers supprimés sur 57 lignes.
# dataset156action3_grp133 : 3 outliers supprimés sur 54 lignes.
# dataset156action3_grp134 : 8 outliers supprimés sur 48 lignes.
# dataset156action3_grp135 : 2 outliers supprimés sur 25 lignes.
# dataset156action3_grp138 : 2 outliers supprimés sur 57 lignes.
# dataset156action3_grp144 : 2 outliers supprimés sur 40 lignes.
# dataset156action3_grp146 : 3 outliers supprimés sur 13 lignes.
# dataset156action3_grp147 : 1 outliers supprimés sur 25 lignes.
# dataset156action3_grp149 : 3 outliers supprimés sur 18 lignes.
# dataset156action3_grp151 : 2 outliers supprimés sur 19 lignes.
# dataset156action3_grp154 : 2 outliers supprimés sur 153 lignes.
# dataset156action3_grp156 : 2 outliers supprimés sur 22 lignes.
# dataset156action3_grp158 : 1 outliers supprimés sur 11 lignes.
# dataset156action3_grp168 : 1 outliers supprimés sur 7 lignes.
# dataset156action3_grp171 : 1 outliers supprimés sur 5 lignes.
# dataset156action4_grp5 : 21 outliers supprimés sur 168 lignes.
# dataset156action4_grp7 : 23 outliers supprimés sur 176 lignes.
# dataset156action4_grp13 : 2 outliers supprimés sur 177 lignes.
# dataset156action4_grp14 : 1 outliers supprimés sur 177 lignes.
# dataset156action4_grp18 : 35 outliers supprimés sur 177 lignes.
# dataset156action4_grp29 : 2 outliers supprimés sur 175 lignes.
# dataset156action4_grp38 : 2 outliers supprimés sur 175 lignes.
# dataset156action4_grp39 : 21 outliers supprimés sur 170 lignes.
# dataset156action4_grp43 : 7 outliers supprimés sur 158 lignes.
# dataset156action4_grp45 : 2 outliers supprimés sur 135 lignes.
# dataset156action4_grp47 : 5 outliers supprimés sur 153 lignes.
# dataset156action4_grp48 : 1 outliers supprimés sur 58 lignes.
# dataset156action4_grp50 : 1 outliers supprimés sur 152 lignes.
# dataset156action4_grp56 : 1 outliers supprimés sur 138 lignes.
# dataset156action4_grp60 : 1 outliers supprimés sur 125 lignes.
# dataset156action4_grp64 : 4 outliers supprimés sur 129 lignes.
# dataset156action4_grp67 : 3 outliers supprimés sur 126 lignes.
# dataset156action4_grp76 : 7 outliers supprimés sur 114 lignes.
# dataset156action4_grp79 : 2 outliers supprimés sur 113 lignes.
# dataset156action4_grp85 : 1 outliers supprimés sur 105 lignes.
# dataset156action4_grp89 : 8 outliers supprimés sur 98 lignes.
# dataset156action4_grp90 : 7 outliers supprimés sur 96 lignes.
# dataset156action4_grp93 : 2 outliers supprimés sur 49 lignes.
# dataset156action4_grp98 : 16 outliers supprimés sur 88 lignes.
# dataset156action4_grp106 : 7 outliers supprimés sur 62 lignes.
# dataset156action4_grp107 : 5 outliers supprimés sur 77 lignes.
# dataset156action4_grp111 : 1 outliers supprimés sur 28 lignes.
# dataset156action4_grp124 : 3 outliers supprimés sur 56 lignes.
# dataset156action4_grp134 : 6 outliers supprimés sur 48 lignes.
# dataset156action4_grp135 : 1 outliers supprimés sur 25 lignes.
# dataset156action4_grp138 : 1 outliers supprimés sur 57 lignes.
# dataset156action4_grp144 : 1 outliers supprimés sur 40 lignes.
# dataset156action4_grp146 : 2 outliers supprimés sur 13 lignes.
# dataset156action4_grp147 : 1 outliers supprimés sur 25 lignes.
# dataset156action4_grp149 : 1 outliers supprimés sur 18 lignes.
# dataset156action4_grp153 : 1 outliers supprimés sur 177 lignes.
# dataset156action4_grp154 : 11 outliers supprimés sur 153 lignes.
# dataset156action4_grp156 : 3 outliers supprimés sur 22 lignes.
# dataset156action4_grp168 : 1 outliers supprimés sur 7 lignes.
# dataset156action4_grp171 : 1 outliers supprimés sur 5 lignes.
# dataset156action5_grp5 : 10 outliers supprimés sur 168 lignes.
# dataset156action5_grp7 : 1 outliers supprimés sur 176 lignes.
# dataset156action5_grp13 : 1 outliers supprimés sur 177 lignes.
# dataset156action5_grp18 : 18 outliers supprimés sur 177 lignes.
# dataset156action5_grp29 : 4 outliers supprimés sur 175 lignes.
# dataset156action5_grp38 : 1 outliers supprimés sur 175 lignes.
# dataset156action5_grp39 : 25 outliers supprimés sur 170 lignes.
# dataset156action5_grp43 : 4 outliers supprimés sur 158 lignes.
# dataset156action5_grp47 : 6 outliers supprimés sur 153 lignes.
# dataset156action5_grp48 : 1 outliers supprimés sur 58 lignes.
# dataset156action5_grp50 : 1 outliers supprimés sur 152 lignes.
# dataset156action5_grp53 : 25 outliers supprimés sur 137 lignes.
# dataset156action5_grp55 : 6 outliers supprimés sur 127 lignes.
# dataset156action5_grp56 : 2 outliers supprimés sur 138 lignes.
# dataset156action5_grp57 : 21 outliers supprimés sur 121 lignes.
# dataset156action5_grp60 : 12 outliers supprimés sur 125 lignes.
# dataset156action5_grp64 : 5 outliers supprimés sur 129 lignes.
# dataset156action5_grp67 : 12 outliers supprimés sur 126 lignes.
# dataset156action5_grp68 : 1 outliers supprimés sur 126 lignes.
# dataset156action5_grp72 : 4 outliers supprimés sur 120 lignes.
# dataset156action5_grp85 : 3 outliers supprimés sur 105 lignes.
# dataset156action5_grp89 : 3 outliers supprimés sur 98 lignes.
# dataset156action5_grp90 : 2 outliers supprimés sur 96 lignes.
# dataset156action5_grp93 : 1 outliers supprimés sur 49 lignes.
# dataset156action5_grp96 : 1 outliers supprimés sur 86 lignes.
# dataset156action5_grp98 : 12 outliers supprimés sur 88 lignes.
# dataset156action5_grp106 : 7 outliers supprimés sur 62 lignes.
# dataset156action5_grp111 : 2 outliers supprimés sur 28 lignes.
# dataset156action5_grp114 : 3 outliers supprimés sur 72 lignes.
# dataset156action5_grp128 : 2 outliers supprimés sur 57 lignes.
# dataset156action5_grp133 : 1 outliers supprimés sur 54 lignes.
# dataset156action5_grp134 : 6 outliers supprimés sur 48 lignes.
# dataset156action5_grp135 : 3 outliers supprimés sur 25 lignes.
# dataset156action5_grp138 : 1 outliers supprimés sur 57 lignes.
# dataset156action5_grp146 : 2 outliers supprimés sur 13 lignes.
# dataset156action5_grp147 : 5 outliers supprimés sur 25 lignes.
# dataset156action5_grp149 : 1 outliers supprimés sur 18 lignes.
# dataset156action5_grp153 : 2 outliers supprimés sur 177 lignes.
# dataset156action5_grp154 : 33 outliers supprimés sur 153 lignes.
# dataset156action5_grp156 : 1 outliers supprimés sur 22 lignes.
# dataset156action5_grp162 : 1 outliers supprimés sur 9 lignes.
# dataset156action5_grp168 : 1 outliers supprimés sur 7 lignes.
# dataset156action5_grp171 : 1 outliers supprimés sur 5 lignes.
# dataset158offres_grp38 : 1 outliers supprimés sur 204 lignes.
# dataset159offres_grp5 : 1 outliers supprimés sur 200 lignes.
# dataset159offres_grp13 : 3 outliers supprimés sur 204 lignes.
# dataset159offres_grp14 : 2 outliers supprimés sur 204 lignes.
# dataset159offres_grp29 : 4 outliers supprimés sur 185 lignes.
# dataset159offres_grp35 : 1 outliers supprimés sur 181 lignes.
# dataset159offres_grp38 : 1 outliers supprimés sur 204 lignes.
# dataset159offres_grp39 : 1 outliers supprimés sur 199 lignes.
# dataset159offres_grp43 : 1 outliers supprimés sur 158 lignes.
# dataset159offres_grp45 : 3 outliers supprimés sur 155 lignes.
# dataset159offres_grp47 : 1 outliers supprimés sur 154 lignes.
# dataset159offres_grp48 : 5 outliers supprimés sur 115 lignes.
# dataset159offres_grp55 : 1 outliers supprimés sur 131 lignes.
# dataset159offres_grp60 : 2 outliers supprimés sur 133 lignes.
# dataset159offres_grp61 : 1 outliers supprimés sur 129 lignes.
# dataset159offres_grp72 : 1 outliers supprimés sur 120 lignes.
# dataset159offres_grp76 : 3 outliers supprimés sur 114 lignes.
# dataset159offres_grp80 : 2 outliers supprimés sur 111 lignes.
# dataset159demandes_grp110 : 3 outliers supprimés sur 47 lignes.
# dataset159demandes_grp113 : 1 outliers supprimés sur 40 lignes.
# dataset159demandes_grp114 : 2 outliers supprimés sur 72 lignes.
# dataset159demandes_grp121 : 2 outliers supprimés sur 15 lignes.
# dataset159demandes_grp127 : 3 outliers supprimés sur 60 lignes.
# dataset159demandes_grp133 : 2 outliers supprimés sur 205 lignes.
# dataset159demandes_grp144 : 13 outliers supprimés sur 169 lignes.
# dataset159demandes_grp147 : 1 outliers supprimés sur 27 lignes.
# dataset159demandes_grp149 : 5 outliers supprimés sur 26 lignes.
# dataset159demandes_grp154 : 41 outliers supprimés sur 191 lignes.
# dataset159demandes_grp156 : 1 outliers supprimés sur 18 lignes.
# dataset159demandes_grp162 : 9 outliers supprimés sur 164 lignes.
# dataset159demandes_grp163 : 2 outliers supprimés sur 12 lignes.
# dataset159demandes_grp165 : 2 outliers supprimés sur 10 lignes.
# dataset159mandats_grp5 : 2 outliers supprimés sur 200 lignes.
# dataset159mandats_grp13 : 1 outliers supprimés sur 204 lignes.
# dataset159mandats_grp14 : 1 outliers supprimés sur 204 lignes.
# dataset159mandats_grp18 : 6 outliers supprimés sur 192 lignes.
# dataset159mandats_grp29 : 1 outliers supprimés sur 185 lignes.
# dataset159mandats_grp35 : 2 outliers supprimés sur 181 lignes.
# dataset159mandats_grp39 : 1 outliers supprimés sur 199 lignes.
# dataset159mandats_grp43 : 32 outliers supprimés sur 158 lignes.
# dataset159mandats_grp45 : 1 outliers supprimés sur 155 lignes.
# dataset159mandats_grp47 : 1 outliers supprimés sur 154 lignes.
# dataset159mandats_grp50 : 1 outliers supprimés sur 204 lignes.
# dataset159mandats_grp53 : 2 outliers supprimés sur 137 lignes.
# dataset159mandats_grp54 : 33 outliers supprimés sur 180 lignes.
# dataset159mandats_grp55 : 13 outliers supprimés sur 131 lignes.
# dataset159mandats_grp61 : 6 outliers supprimés sur 129 lignes.
# dataset159mandats_grp67 : 5 outliers supprimés sur 202 lignes.
# dataset159mandats_grp68 : 14 outliers supprimés sur 199 lignes.
# dataset159mandats_grp76 : 1 outliers supprimés sur 114 lignes.
# dataset159mandats_grp80 : 3 outliers supprimés sur 111 lignes.
# dataset159mandats_grp85 : 2 outliers supprimés sur 105 lignes.
# dataset159mandats_grp86 : 1 outliers supprimés sur 194 lignes.
# dataset159mandats_grp89 : 3 outliers supprimés sur 101 lignes.
# dataset159mandats_grp90 : 11 outliers supprimés sur 101 lignes.
# dataset159mandats_grp93 : 4 outliers supprimés sur 58 lignes.
# dataset159mandats_grp96 : 20 outliers supprimés sur 199 lignes.
# dataset159mandats_grp98 : 2 outliers supprimés sur 135 lignes.
# dataset159mandats_grp101 : 1 outliers supprimés sur 87 lignes.
# dataset159mandats_grp106 : 3 outliers supprimés sur 70 lignes.
# dataset159mandats_grp107 : 2 outliers supprimés sur 193 lignes.
# dataset159mandats_grp108 : 1 outliers supprimés sur 203 lignes.
# dataset159mandats_grp109 : 1 outliers supprimés sur 74 lignes.
# dataset159mandats_grp110 : 3 outliers supprimés sur 47 lignes.
# dataset159mandats_grp111 : 1 outliers supprimés sur 30 lignes.
# dataset159mandats_grp118 : 1 outliers supprimés sur 105 lignes.
# dataset159mandats_grp127 : 2 outliers supprimés sur 60 lignes.
# dataset159mandats_grp133 : 41 outliers supprimés sur 205 lignes.
# dataset159mandats_grp135 : 1 outliers supprimés sur 33 lignes.
# dataset159mandats_grp144 : 2 outliers supprimés sur 169 lignes.
# dataset159mandats_grp146 : 4 outliers supprimés sur 18 lignes.
# dataset159mandats_grp147 : 1 outliers supprimés sur 27 lignes.
# dataset159mandats_grp152 : 2 outliers supprimés sur 29 lignes.
# dataset159mandats_grp153 : 2 outliers supprimés sur 194 lignes.
# dataset159mandats_grp154 : 2 outliers supprimés sur 191 lignes.
# dataset159mandats_grp156 : 4 outliers supprimés sur 18 lignes.
# dataset159mandats_grp160 : 1 outliers supprimés sur 13 lignes.
# dataset159mandats_grp172 : 1 outliers supprimés sur 203 lignes.
# dataset160rejete_grp108 : 2 outliers supprimés sur 20 lignes.
# dataset160rejete_grp147 : 1 outliers supprimés sur 11 lignes.
# dataset160rejete_grp164 : 1 outliers supprimés sur 7 lignes.
# dataset160npai_grp147 : 1 outliers supprimés sur 11 lignes.
# dataset160npai_grp164 : 1 outliers supprimés sur 7 lignes.
# dataset161rejetes_grp38 : 6 outliers supprimés sur 27 lignes.
# dataset164simple_grp90 : 24 outliers supprimés sur 50 lignes.
# dataset164simple_grp93 : 6 outliers supprimés sur 36 lignes.
# dataset164simple_grp128 : 5 outliers supprimés sur 59 lignes.
# dataset164simple_grp148 : 1 outliers supprimés sur 34 lignes.
# dataset164simple_grp174 : 1 outliers supprimés sur 6 lignes.
# dataset164demande_grp68 : 11 outliers supprimés sur 65 lignes.
# dataset164demande_grp101 : 7 outliers supprimés sur 43 lignes.
# dataset164exclusif_grp43 : 5 outliers supprimés sur 40 lignes.
# dataset164exclusif_grp53 : 18 outliers supprimés sur 108 lignes.
# dataset164exclusif_grp72 : 8 outliers supprimés sur 37 lignes.
# dataset164exclusif_grp83 : 16 outliers supprimés sur 107 lignes.
# dataset164coexclusif_grp45 : 10 outliers supprimés sur 62 lignes.
# dataset164coexclusif_grp75 : 6 outliers supprimés sur 202 lignes.
# dataset164coexclusif_grp101 : 2 outliers supprimés sur 44 lignes.
# dataset164coexclusif_grp107 : 13 outliers supprimés sur 86 lignes.
# dataset164coexclusif_grp118 : 25 outliers supprimés sur 67 lignes.
# dataset164coexclusif_grp172 : 11 outliers supprimés sur 99 lignes.
# dataset164triexclusif_grp29 : 21 outliers supprimés sur 156 lignes.
# dataset164triexclusif_grp85 : 2 outliers supprimés sur 10 lignes.
# dataset164triexclusif_grp100 : 9 outliers supprimés sur 48 lignes.
# dataset164triexclusif_grp144 : 7 outliers supprimés sur 37 lignes.
# dataset164preferentiel_grp14 : 19 outliers supprimés sur 82 lignes.
# dataset164preferentiel_grp107 : 35 outliers supprimés sur 154 lignes.
# dataset164preferentiel_grp124 : 2 outliers supprimés sur 14 lignes.
# dataset164preferentiel_grp153 : 4 outliers supprimés sur 58 lignes.
# dataset164delegation_grp35 : 1 outliers supprimés sur 28 lignes.
# dataset164delegation_grp39 : 11 outliers supprimés sur 47 lignes.
# dataset164delegation_grp72 : 8 outliers supprimés sur 50 lignes.
# dataset164delegation_grp75 : 41 outliers supprimés sur 116 lignes.
# dataset164delegation_grp83 : 24 outliers supprimés sur 110 lignes.
# dataset164delegation_grp100 : 8 outliers supprimés sur 44 lignes.
# dataset164delegation_grp107 : 9 outliers supprimés sur 38 lignes.
# dataset164delegation_grp148 : 3 outliers supprimés sur 31 lignes.
# dataset164quadriexclusif_grp86 : 13 outliers supprimés sur 69 lignes.

# %%
# On vire les datasets qui contiennent trop peu de données, les prévisions ne seront pas fiables

a_supprimer = []

print(f'Avant les traitements qui viennent, pour rappel, on a {len(datasets_groupes)} séries temporelles à analyser')

for nom, df in datasets_groupes.items() : 
    if df.shape[0] < 36 : # 0 et pas 1, sinon on supprime toutes les données !!!
        a_supprimer.append(nom) # On ajoute dans la liste des datasets non exploitables les datasets qui ont moins de 36 points
# Out:
# Avant les traitements qui viennent, pour rappel, on a 1809 séries temporelles à analyser

# %%
# On vire aussi les datasets qui ont trop de trous

mois_courant = pd.Timestamp(datetime.today().replace(day=1))
seuil_trous = 0.07 # Plus de 7% de trous c'est chaud

for nom, df in datasets_groupes.items():
    # Génère une série complète de dates mensuelles entre les bornes
    date_range_complet = pd.date_range(start=df['date'].min(), end=mois_courant, freq='MS')

    # Dates présentes dans le DataFrame
    dates_presentes = pd.to_datetime(df['date'].unique())

    nb_total = len(date_range_complet)
    nb_manquantes = len(set(date_range_complet) - set(dates_presentes))
    proportion_trous = nb_manquantes / nb_total
    if proportion_trous > seuil_trous :
        a_supprimer.append(nom)

for nom in set(a_supprimer) : 
    del datasets_groupes[nom]
    del globals()[nom] # On supprime aussi la variable globale pour libérer un peu de mémoire
    print(f"SUPPRIME : {nom}")

print(f'{len(a_supprimer)} datasets supprimés : il ne reste plus que {len(datasets_groupes)} datasets')
# Là normalement avec ça et les datasets trop courts ca aura pas mal baissé
# Out:
# SUPPRIME : dataset164exclusif_grp89
# SUPPRIME : dataset156action1_grp139
# SUPPRIME : dataset160rejete_grp162
# SUPPRIME : dataset164preferentiel_grp89
# SUPPRIME : dataset156action1_grp174
# SUPPRIME : dataset149_grp108
# SUPPRIME : dataset153_grp124
# SUPPRIME : dataset150_grp175
# SUPPRIME : dataset156action4_grp175
# SUPPRIME : dataset149_grp18
# SUPPRIME : dataset151_grp149
# SUPPRIME : dataset153_grp158
# SUPPRIME : dataset156action2_grp110
# SUPPRIME : dataset164simple_grp110
# SUPPRIME : dataset159demandes_grp161
# SUPPRIME : dataset152_grp161
# SUPPRIME : dataset151_grp93
# SUPPRIME : dataset160npai_grp156
# SUPPRIME : dataset156action4_grp7
# SUPPRIME : dataset151_grp139
# SUPPRIME : dataset150_grp106
# SUPPRIME : dataset151_grp162
# SUPPRIME : dataset164coexclusif_grp53
# SUPPRIME : dataset164delegation_grp148
# SUPPRIME : dataset160npai_grp38
# SUPPRIME : dataset156action5_grp146
# SUPPRIME : dataset155_grp156
# SUPPRIME : dataset159offres_grp139
# SUPPRIME : dataset164quadriexclusif_grp47
# SUPPRIME : dataset156action3_grp161
# SUPPRIME : dataset160rejete_grp38
# SUPPRIME : dataset146visite_grp61
# SUPPRIME : dataset151_grp57
# SUPPRIME : dataset159demandes_grp174
# SUPPRIME : dataset147_grp79
# SUPPRIME : dataset156action3_grp154
# SUPPRIME : dataset156action2_grp113
# SUPPRIME : dataset156action2_grp127
# SUPPRIME : dataset160npai_grp29
# SUPPRIME : dataset149_grp113
# SUPPRIME : dataset164quadriexclusif_grp172
# SUPPRIME : dataset159offres_grp110
# SUPPRIME : dataset154_grp156
# SUPPRIME : dataset149_grp5
# SUPPRIME : dataset146rdv_grp72
# SUPPRIME : dataset164preferentiel_grp133
# SUPPRIME : dataset164exclusif_grp61
# SUPPRIME : dataset160rejete_grp67
# SUPPRIME : dataset153_grp148
# SUPPRIME : dataset147_grp118
# SUPPRIME : dataset151_grp156
# SUPPRIME : dataset147_grp120
# SUPPRIME : dataset159mandats_grp106
# SUPPRIME : dataset156action5_grp110
# SUPPRIME : dataset156action1_grp113
# SUPPRIME : dataset156action4_grp158
# SUPPRIME : dataset147_grp108
# SUPPRIME : dataset159demandes_grp163
# SUPPRIME : dataset164delegation_grp35
# SUPPRIME : dataset147_grp43
# SUPPRIME : dataset146visite_grp93
# SUPPRIME : dataset159offres_grp175
# SUPPRIME : dataset164exclusif_grp96
# SUPPRIME : dataset154_grp164
# SUPPRIME : dataset164exclusif_grp144
# SUPPRIME : dataset156action3_grp167
# SUPPRIME : dataset160npai_grp68
# SUPPRIME : dataset156action3_grp146
# SUPPRIME : dataset154_grp86
# SUPPRIME : dataset159mandats_grp160
# SUPPRIME : dataset156action5_grp151
# SUPPRIME : dataset164triexclusif_grp100
# SUPPRIME : dataset156action4_grp134
# SUPPRIME : dataset148_grp124
# SUPPRIME : dataset156action3_grp148
# SUPPRIME : dataset150_grp147
# SUPPRIME : dataset149_grp53
# SUPPRIME : dataset153_grp18
# SUPPRIME : dataset164exclusif_grp5
# SUPPRIME : dataset156action4_grp160
# SUPPRIME : dataset146visite_grp80
# SUPPRIME : dataset164coexclusif_grp61
# SUPPRIME : dataset159demandes_grp48
# SUPPRIME : dataset159demandes_grp54
# SUPPRIME : dataset156action3_grp151
# SUPPRIME : dataset159demandes_grp111
# SUPPRIME : dataset148_grp98
# SUPPRIME : dataset147_grp85
# SUPPRIME : dataset156action2_grp57
# SUPPRIME : dataset164exclusif_grp54
# SUPPRIME : dataset159offres_grp48
# SUPPRIME : dataset149_grp55
# SUPPRIME : dataset149_grp148
# SUPPRIME : dataset156action1_grp167
# SUPPRIME : dataset147_grp135
# SUPPRIME : dataset160npai_grp108
# SUPPRIME : dataset147_grp172
# SUPPRIME : dataset156action2_grp61
# SUPPRIME : dataset159demandes_grp18
# SUPPRIME : dataset164triexclusif_grp5
# SUPPRIME : dataset151_grp174
# SUPPRIME : dataset164coexclusif_grp175
# SUPPRIME : dataset156action1_grp120
# SUPPRIME : dataset150_grp156
# SUPPRIME : dataset164coexclusif_grp35
# SUPPRIME : dataset156action2_grp138
# SUPPRIME : dataset159demandes_grp40
# SUPPRIME : dataset156action5_grp48
# SUPPRIME : dataset149_grp111
# SUPPRIME : dataset149_grp98
# SUPPRIME : dataset150_grp121
# SUPPRIME : dataset151_grp40
# SUPPRIME : dataset157_grp162
# SUPPRIME : dataset164triexclusif_grp128
# SUPPRIME : dataset146visite_grp64
# SUPPRIME : dataset147_grp89
# SUPPRIME : dataset164preferentiel_grp114
# SUPPRIME : dataset150_grp61
# SUPPRIME : dataset150_grp173
# SUPPRIME : dataset152_grp18
# SUPPRIME : dataset164preferentiel_grp18
# SUPPRIME : dataset164demande_grp68
# SUPPRIME : dataset164coexclusif_grp54
# SUPPRIME : dataset156action3_grp112
# SUPPRIME : dataset164simple_grp152
# SUPPRIME : dataset146visite_grp121
# SUPPRIME : dataset159demandes_grp124
# SUPPRIME : dataset147_grp53
# SUPPRIME : dataset157_grp86
# SUPPRIME : dataset159offres_grp167
# SUPPRIME : dataset159mandats_grp148
# SUPPRIME : dataset151_grp164
# SUPPRIME : dataset159offres_grp106
# SUPPRIME : dataset154_grp107
# SUPPRIME : dataset151_grp163
# SUPPRIME : dataset156action3_grp175
# SUPPRIME : dataset147_grp72
# SUPPRIME : dataset146rdv_grp148
# SUPPRIME : dataset156action1_grp53
# SUPPRIME : dataset159mandats_grp54
# SUPPRIME : dataset164preferentiel_grp54
# SUPPRIME : dataset164delegation_grp83
# SUPPRIME : dataset148_grp164
# SUPPRIME : dataset150_grp144
# SUPPRIME : dataset164demande_grp89
# SUPPRIME : dataset156action2_grp139
# SUPPRIME : dataset159offres_grp135
# SUPPRIME : dataset153_grp111
# SUPPRIME : dataset147_grp76
# SUPPRIME : dataset160npai_grp164
# SUPPRIME : dataset156action3_grp111
# SUPPRIME : dataset146proposition_grp47
# SUPPRIME : dataset146visite_grp18
# SUPPRIME : dataset156action5_grp121
# SUPPRIME : dataset149_grp39
# SUPPRIME : dataset153_grp156
# SUPPRIME : dataset156action1_grp135
# SUPPRIME : dataset151_grp134
# SUPPRIME : dataset159mandats_grp18
# SUPPRIME : dataset164preferentiel_grp29
# SUPPRIME : dataset147_grp83
# SUPPRIME : dataset146proposition_grp128
# SUPPRIME : dataset164delegation_grp67
# SUPPRIME : dataset153_grp5
# SUPPRIME : dataset161rejetes_grp35
# SUPPRIME : dataset156action2_grp55
# SUPPRIME : dataset156action2_grp124
# SUPPRIME : dataset147_grp57
# SUPPRIME : dataset164triexclusif_grp85
# SUPPRIME : dataset157_grp68
# SUPPRIME : dataset164demande_grp79
# SUPPRIME : dataset147_grp86
# SUPPRIME : dataset150_grp158
# SUPPRIME : dataset164coexclusif_grp152
# SUPPRIME : dataset159mandats_grp93
# SUPPRIME : dataset159demandes_grp168
# SUPPRIME : dataset156action5_grp55
# SUPPRIME : dataset150_grp146
# SUPPRIME : dataset156action2_grp106
# SUPPRIME : dataset151_grp167
# SUPPRIME : dataset161ouverts_grp147
# SUPPRIME : dataset156action5_grp163
# SUPPRIME : dataset152_grp57
# SUPPRIME : dataset159mandats_grp124
# SUPPRIME : dataset146visite_grp48
# SUPPRIME : dataset146rdv_grp135
# SUPPRIME : dataset156action2_grp163
# SUPPRIME : dataset159mandats_grp151
# SUPPRIME : dataset161rejetes_grp156
# SUPPRIME : dataset147_grp96
# SUPPRIME : dataset164delegation_grp43
# SUPPRIME : dataset151_grp106
# SUPPRIME : dataset150_grp57
# SUPPRIME : dataset147_grp64
# SUPPRIME : dataset148_grp112
# SUPPRIME : dataset159offres_grp146
# SUPPRIME : dataset153_grp53
# SUPPRIME : dataset156action4_grp5
# SUPPRIME : dataset153_grp164
# SUPPRIME : dataset146rdv_grp128
# SUPPRIME : dataset164demande_grp100
# SUPPRIME : dataset151_grp55
# SUPPRIME : dataset164coexclusif_grp154
# SUPPRIME : dataset159offres_grp57
# SUPPRIME : dataset159demandes_grp149
# SUPPRIME : dataset156action3_grp135
# SUPPRIME : dataset149_grp124
# SUPPRIME : dataset156action4_grp151
# SUPPRIME : dataset164exclusif_grp107
# SUPPRIME : dataset164delegation_grp64
# SUPPRIME : dataset156action3_grp160
# SUPPRIME : dataset159mandats_grp111
# SUPPRIME : dataset148_grp135
# SUPPRIME : dataset164exclusif_grp53
# SUPPRIME : dataset149_grp96
# SUPPRIME : dataset159mandats_grp133
# SUPPRIME : dataset150_grp148
# SUPPRIME : dataset164demande_grp148
# SUPPRIME : dataset146visite_grp162
# SUPPRIME : dataset156action4_grp163
# SUPPRIME : dataset164simple_grp107
# SUPPRIME : dataset164delegation_grp107
# SUPPRIME : dataset156action3_grp106
# SUPPRIME : dataset164delegation_grp76
# SUPPRIME : dataset156action4_grp152
# SUPPRIME : dataset161rejetes_grp133
# SUPPRIME : dataset156action4_grp161
# SUPPRIME : dataset156action5_grp167
# SUPPRIME : dataset164delegation_grp154
# SUPPRIME : dataset146proposition_grp79
# SUPPRIME : dataset159mandats_grp40
# SUPPRIME : dataset159mandats_grp139
# SUPPRIME : dataset147_grp162
# SUPPRIME : dataset148_grp113
# SUPPRIME : dataset156action3_grp163
# SUPPRIME : dataset161rejetes_grp67
# SUPPRIME : dataset156action1_grp138
# SUPPRIME : dataset152_grp53
# SUPPRIME : dataset156action2_grp144
# SUPPRIME : dataset164demande_grp54
# SUPPRIME : dataset146proposition_grp38
# SUPPRIME : dataset156action4_grp113
# SUPPRIME : dataset159demandes_grp164
# SUPPRIME : dataset146visite_grp57
# SUPPRIME : dataset153_grp57
# SUPPRIME : dataset156action5_grp154
# SUPPRIME : dataset146visite_grp55
# SUPPRIME : dataset146visite_grp109
# SUPPRIME : dataset161ouverts_grp164
# SUPPRIME : dataset146rdv_grp61
# SUPPRIME : dataset153_grp96
# SUPPRIME : dataset156action3_grp139
# SUPPRIME : dataset149_grp120
# SUPPRIME : dataset156action4_grp89
# SUPPRIME : dataset153_grp135
# SUPPRIME : dataset146rdv_grp93
# SUPPRIME : dataset164coexclusif_grp80
# SUPPRIME : dataset164triexclusif_grp53
# SUPPRIME : dataset147_grp156
# SUPPRIME : dataset153_grp98
# SUPPRIME : dataset150_grp128
# SUPPRIME : dataset164coexclusif_grp101
# SUPPRIME : dataset156action2_grp152
# SUPPRIME : dataset154_grp133
# SUPPRIME : dataset150_grp167
# SUPPRIME : dataset146rdv_grp64
# SUPPRIME : dataset156action1_grp106
# SUPPRIME : dataset156action3_grp113
# SUPPRIME : dataset148_grp154
# SUPPRIME : dataset146visite_grp135
# SUPPRIME : dataset155_grp147
# SUPPRIME : dataset156action1_grp148
# SUPPRIME : dataset152_grp151
# SUPPRIME : dataset164demande_grp75
# SUPPRIME : dataset147_grp164
# SUPPRIME : dataset156action1_grp158
# SUPPRIME : dataset164delegation_grp101
# SUPPRIME : dataset156action2_grp43
# SUPPRIME : dataset159demandes_grp57
# SUPPRIME : dataset146rdv_grp14
# SUPPRIME : dataset155_grp67
# SUPPRIME : dataset156action3_grp164
# SUPPRIME : dataset164preferentiel_grp100
# SUPPRIME : dataset153_grp106
# SUPPRIME : dataset159demandes_grp167
# SUPPRIME : dataset156action2_grp134
# SUPPRIME : dataset159mandats_grp154
# SUPPRIME : dataset159mandats_grp165
# SUPPRIME : dataset156action1_grp154
# SUPPRIME : dataset148_grp68
# SUPPRIME : dataset159mandats_grp121
# SUPPRIME : dataset164coexclusif_grp76
# SUPPRIME : dataset146rdv_grp106
# SUPPRIME : dataset152_grp174
# SUPPRIME : dataset156action4_grp121
# SUPPRIME : dataset159demandes_grp165
# SUPPRIME : dataset159mandats_grp113
# SUPPRIME : dataset153_grp110
# SUPPRIME : dataset150_grp171
# SUPPRIME : dataset156action5_grp139
# SUPPRIME : dataset164simple_grp174
# SUPPRIME : dataset146rdv_grp156
# SUPPRIME : dataset164triexclusif_grp55
# SUPPRIME : dataset156action1_grp149
# SUPPRIME : dataset159mandats_grp96
# SUPPRIME : dataset160rejete_grp133
# SUPPRIME : dataset148_grp175
# SUPPRIME : dataset161rejetes_grp107
# SUPPRIME : dataset146visite_grp45
# SUPPRIME : dataset146rdv_grp53
# SUPPRIME : dataset155_grp164
# SUPPRIME : dataset154_grp35
# SUPPRIME : dataset152_grp175
# SUPPRIME : dataset159mandats_grp149
# SUPPRIME : dataset159offres_grp162
# SUPPRIME : dataset156action5_grp168
# SUPPRIME : dataset146visite_grp53
# SUPPRIME : dataset164coexclusif_grp172
# SUPPRIME : dataset164simple_grp55
# SUPPRIME : dataset164triexclusif_grp152
# SUPPRIME : dataset156action3_grp45
# SUPPRIME : dataset164coexclusif_grp144
# SUPPRIME : dataset164delegation_grp79
# SUPPRIME : dataset152_grp147
# SUPPRIME : dataset146proposition_grp35
# SUPPRIME : dataset160rejete_grp29
# SUPPRIME : dataset151_grp151
# SUPPRIME : dataset164delegation_grp100
# SUPPRIME : dataset164quadriexclusif_grp67
# SUPPRIME : dataset161delivres_grp108
# SUPPRIME : dataset156action1_grp152
# SUPPRIME : dataset153_grp168
# SUPPRIME : dataset157_grp108
# SUPPRIME : dataset160rejete_grp107
# SUPPRIME : dataset156action5_grp98
# SUPPRIME : dataset156action1_grp173
# SUPPRIME : dataset156action4_grp39
# SUPPRIME : dataset156action3_grp55
# SUPPRIME : dataset146proposition_grp76
# SUPPRIME : dataset146proposition_grp133
# SUPPRIME : dataset164triexclusif_grp64
# SUPPRIME : dataset164preferentiel_grp83
# SUPPRIME : dataset156action4_grp172
# SUPPRIME : dataset156action4_grp167
# SUPPRIME : dataset159demandes_grp156
# SUPPRIME : dataset164demande_grp5
# SUPPRIME : dataset159demandes_grp162
# SUPPRIME : dataset164demande_grp128
# SUPPRIME : dataset164quadriexclusif_grp100
# SUPPRIME : dataset146proposition_grp53
# SUPPRIME : dataset156action4_grp162
# SUPPRIME : dataset147_grp109
# SUPPRIME : dataset159demandes_grp39
# SUPPRIME : dataset159offres_grp111
# SUPPRIME : dataset146proposition_grp80
# SUPPRIME : dataset152_grp39
# SUPPRIME : dataset155_grp38
# SUPPRIME : dataset153_grp139
# SUPPRIME : dataset153_grp175
# SUPPRIME : dataset154_grp147
# SUPPRIME : dataset146proposition_grp39
# SUPPRIME : dataset148_grp93
# SUPPRIME : dataset150_grp161
# SUPPRIME : dataset147_grp7
# SUPPRIME : dataset156action4_grp127
# SUPPRIME : dataset164simple_grp175
# SUPPRIME : dataset159demandes_grp90
# SUPPRIME : dataset151_grp113
# SUPPRIME : dataset156action5_grp171
# SUPPRIME : dataset164delegation_grp172
# SUPPRIME : dataset146visite_grp54
# SUPPRIME : dataset149_grp127
# SUPPRIME : dataset159mandats_grp158
# SUPPRIME : dataset156action2_grp173
# SUPPRIME : dataset149_grp45
# SUPPRIME : dataset146visite_grp127
# SUPPRIME : dataset148_grp57
# SUPPRIME : dataset148_grp18
# SUPPRIME : dataset150_grp55
# SUPPRIME : dataset164delegation_grp50
# SUPPRIME : dataset161rejetes_grp29
# SUPPRIME : dataset150_grp165
# SUPPRIME : dataset159demandes_grp147
# SUPPRIME : dataset164quadriexclusif_grp76
# SUPPRIME : dataset164exclusif_grp120
# SUPPRIME : dataset146visite_grp90
# SUPPRIME : dataset153_grp48
# SUPPRIME : dataset150_grp60
# SUPPRIME : dataset156action5_grp112
# SUPPRIME : dataset164coexclusif_grp118
# SUPPRIME : dataset159mandats_grp110
# SUPPRIME : dataset155_grp108
# SUPPRIME : dataset164triexclusif_grp160
# SUPPRIME : dataset146visite_grp164
# SUPPRIME : dataset150_grp53
# SUPPRIME : dataset148_grp60
# SUPPRIME : dataset159mandats_grp55
# SUPPRIME : dataset156action1_grp161
# SUPPRIME : dataset154_grp38
# SUPPRIME : dataset150_grp163
# SUPPRIME : dataset153_grp146
# SUPPRIME : dataset159mandats_grp90
# SUPPRIME : dataset156action5_grp149
# SUPPRIME : dataset161rejetes_grp68
# SUPPRIME : dataset160rejete_grp156
# SUPPRIME : dataset156action5_grp147
# SUPPRIME : dataset164preferentiel_grp128
# SUPPRIME : dataset146rdv_grp120
# SUPPRIME : dataset146visite_grp128
# SUPPRIME : dataset146rdv_grp47
# SUPPRIME : dataset156action2_grp93
# SUPPRIME : dataset156action1_grp160
# SUPPRIME : dataset164exclusif_grp43
# SUPPRIME : dataset150_grp174
# SUPPRIME : dataset164delegation_grp164
# SUPPRIME : dataset156action5_grp124
# SUPPRIME : dataset164exclusif_grp83
# SUPPRIME : dataset154_grp67
# SUPPRIME : dataset164simple_grp139
# SUPPRIME : dataset164delegation_grp68
# SUPPRIME : dataset164demande_grp83
# SUPPRIME : dataset146visite_grp101
# SUPPRIME : dataset147_grp128
# SUPPRIME : dataset164simple_grp93
# SUPPRIME : dataset153_grp108
# SUPPRIME : dataset151_grp152
# SUPPRIME : dataset156action4_grp171
# SUPPRIME : dataset146proposition_grp5
# SUPPRIME : dataset164exclusif_grp127
# SUPPRIME : dataset146visite_grp124
# SUPPRIME : dataset153_grp133
# SUPPRIME : dataset164delegation_grp39
# SUPPRIME : dataset159demandes_grp146
# SUPPRIME : dataset148_grp156
# SUPPRIME : dataset164simple_grp144
# SUPPRIME : dataset159demandes_grp144
# SUPPRIME : dataset146proposition_grp164
# SUPPRIME : dataset161rejetes_grp146
# SUPPRIME : dataset164simple_grp111
# SUPPRIME : dataset147_grp152
# SUPPRIME : dataset150_grp164
# SUPPRIME : dataset146visite_grp60
# SUPPRIME : dataset147_grp48
# SUPPRIME : dataset156action5_grp172
# SUPPRIME : dataset156action3_grp171
# SUPPRIME : dataset149_grp90
# SUPPRIME : dataset164simple_grp148
# SUPPRIME : dataset156action3_grp93
# SUPPRIME : dataset160rejete_grp68
# SUPPRIME : dataset147_grp61
# SUPPRIME : dataset148_grp111
# SUPPRIME : dataset164coexclusif_grp47
# SUPPRIME : dataset148_grp151
# SUPPRIME : dataset147_grp54
# SUPPRIME : dataset160npai_grp146
# SUPPRIME : dataset146rdv_grp43
# SUPPRIME : dataset154_grp108
# SUPPRIME : dataset161rejetes_grp147
# SUPPRIME : dataset156action5_grp45
# SUPPRIME : dataset150_grp48
# SUPPRIME : dataset156action3_grp60
# SUPPRIME : dataset156action1_grp156
# SUPPRIME : dataset146proposition_grp68
# SUPPRIME : dataset157_grp133
# SUPPRIME : dataset164triexclusif_grp118
# SUPPRIME : dataset155_grp107
# SUPPRIME : dataset164coexclusif_grp18
# SUPPRIME : dataset156action3_grp110
# SUPPRIME : dataset156action3_grp127
# SUPPRIME : dataset146visite_grp14
# SUPPRIME : dataset153_grp165
# SUPPRIME : dataset156action4_grp165
# SUPPRIME : dataset164exclusif_grp147
# SUPPRIME : dataset146rdv_grp174
# SUPPRIME : dataset156action3_grp162
# SUPPRIME : dataset148_grp152
# SUPPRIME : dataset148_grp163
# SUPPRIME : dataset146visite_grp120
# SUPPRIME : dataset150_grp110
# SUPPRIME : dataset159demandes_grp139
# SUPPRIME : dataset156action1_grp163
# SUPPRIME : dataset151_grp111
# SUPPRIME : dataset153_grp93
# SUPPRIME : dataset155_grp29
# SUPPRIME : dataset157_grp107
# SUPPRIME : dataset146visite_grp43
# SUPPRIME : dataset152_grp154
# SUPPRIME : dataset159mandats_grp162
# SUPPRIME : dataset164demande_grp14
# SUPPRIME : dataset160npai_grp133
# SUPPRIME : dataset149_grp158
# SUPPRIME : dataset156action1_grp45
# SUPPRIME : dataset147_grp124
# SUPPRIME : dataset156action2_grp162
# SUPPRIME : dataset152_grp158
# SUPPRIME : dataset159offres_grp161
# SUPPRIME : dataset159mandats_grp168
# SUPPRIME : dataset156action2_grp175
# SUPPRIME : dataset164simple_grp90
# SUPPRIME : dataset146rdv_grp56
# SUPPRIME : dataset152_grp146
# SUPPRIME : dataset146rdv_grp68
# SUPPRIME : dataset156action2_grp121
# SUPPRIME : dataset156action4_grp55
# SUPPRIME : dataset156action4_grp18
# SUPPRIME : dataset159offres_grp120
# SUPPRIME : dataset164coexclusif_grp86
# SUPPRIME : dataset153_grp55
# SUPPRIME : dataset159mandats_grp48
# SUPPRIME : dataset146proposition_grp101
# SUPPRIME : dataset146visite_grp148
# SUPPRIME : dataset147_grp98
# SUPPRIME : dataset164quadriexclusif_grp79
# SUPPRIME : dataset156action4_grp147
# SUPPRIME : dataset146rdv_grp76
# SUPPRIME : dataset164exclusif_grp18
# SUPPRIME : dataset148_grp45
# SUPPRIME : dataset148_grp133
# SUPPRIME : dataset146proposition_grp54
# SUPPRIME : dataset156action4_grp107
# SUPPRIME : dataset152_grp107
# SUPPRIME : dataset159offres_grp164
# SUPPRIME : dataset159demandes_grp152
# SUPPRIME : dataset146rdv_grp5
# SUPPRIME : dataset146visite_grp138
# SUPPRIME : dataset164demande_grp45
# SUPPRIME : dataset164triexclusif_grp172
# SUPPRIME : dataset156action1_grp146
# SUPPRIME : dataset159offres_grp40
# SUPPRIME : dataset159demandes_grp158
# SUPPRIME : dataset159demandes_grp151
# SUPPRIME : dataset156action5_grp135
# SUPPRIME : dataset146rdv_grp146
# SUPPRIME : dataset164coexclusif_grp5
# SUPPRIME : dataset146visite_grp146
# SUPPRIME : dataset146rdv_grp162
# SUPPRIME : dataset156action2_grp174
# SUPPRIME : dataset160npai_grp107
# SUPPRIME : dataset148_grp5
# SUPPRIME : dataset148_grp146
# SUPPRIME : dataset153_grp45
# SUPPRIME : dataset160npai_grp35
# SUPPRIME : dataset152_grp160
# SUPPRIME : dataset159offres_grp148
# SUPPRIME : dataset159demandes_grp121
# SUPPRIME : dataset156action5_grp120
# SUPPRIME : dataset156action3_grp174
# SUPPRIME : dataset164quadriexclusif_grp61
# SUPPRIME : dataset164preferentiel_grp80
# SUPPRIME : dataset146proposition_grp56
# SUPPRIME : dataset152_grp148
# SUPPRIME : dataset156action1_grp165
# SUPPRIME : dataset156action5_grp127
# SUPPRIME : dataset146rdv_grp85
# SUPPRIME : dataset149_grp154
# SUPPRIME : dataset146visite_grp147
# SUPPRIME : dataset149_grp174
# SUPPRIME : dataset156action4_grp148
# SUPPRIME : dataset155_grp133
# SUPPRIME : dataset164exclusif_grp93
# SUPPRIME : dataset149_grp133
# SUPPRIME : dataset153_grp127
# SUPPRIME : dataset150_grp162
# SUPPRIME : dataset148_grp148
# SUPPRIME : dataset156action3_grp121
# SUPPRIME : dataset159demandes_grp135
# SUPPRIME : dataset159mandats_grp135
# SUPPRIME : dataset164quadriexclusif_grp118
# SUPPRIME : dataset164coexclusif_grp68
# SUPPRIME : dataset147_grp5
# SUPPRIME : dataset151_grp165
# SUPPRIME : dataset152_grp121
# SUPPRIME : dataset146visite_grp5
# SUPPRIME : dataset146rdv_grp75
# SUPPRIME : dataset156action3_grp147
# SUPPRIME : dataset159offres_grp144
# SUPPRIME : dataset164quadriexclusif_grp54
# SUPPRIME : dataset148_grp162
# SUPPRIME : dataset156action3_grp149
# SUPPRIME : dataset147_grp67
# SUPPRIME : dataset156action4_grp110
# SUPPRIME : dataset164triexclusif_grp154
# SUPPRIME : dataset156action1_grp124
# SUPPRIME : dataset164preferentiel_grp14
# SUPPRIME : dataset164coexclusif_grp164
# SUPPRIME : dataset156action2_grp98
# SUPPRIME : dataset146rdv_grp107
# SUPPRIME : dataset157_grp29
# SUPPRIME : dataset156action5_grp57
# SUPPRIME : dataset149_grp156
# SUPPRIME : dataset156action4_grp149
# SUPPRIME : dataset148_grp53
# SUPPRIME : dataset156action1_grp48
# SUPPRIME : dataset164delegation_grp53
# SUPPRIME : dataset153_grp171
# SUPPRIME : dataset149_grp167
# SUPPRIME : dataset146visite_grp39
# SUPPRIME : dataset159offres_grp151
# SUPPRIME : dataset148_grp48
# SUPPRIME : dataset148_grp158
# SUPPRIME : dataset157_grp156
# SUPPRIME : dataset159offres_grp121
# SUPPRIME : dataset156action2_grp111
# SUPPRIME : dataset153_grp147
# SUPPRIME : dataset164delegation_grp171
# SUPPRIME : dataset146rdv_grp39
# SUPPRIME : dataset164demande_grp93
# SUPPRIME : dataset164quadriexclusif_grp68
# SUPPRIME : dataset148_grp147
# SUPPRIME : dataset164coexclusif_grp108
# SUPPRIME : dataset164preferentiel_grp13
# SUPPRIME : dataset146proposition_grp13
# SUPPRIME : dataset157_grp35
# SUPPRIME : dataset148_grp134
# SUPPRIME : dataset156action1_grp110
# SUPPRIME : dataset156action2_grp45
# SUPPRIME : dataset159demandes_grp127
# SUPPRIME : dataset156action1_grp147
# SUPPRIME : dataset146proposition_grp114
# SUPPRIME : dataset149_grp48
# SUPPRIME : dataset164delegation_grp18
# SUPPRIME : dataset164delegation_grp72
# SUPPRIME : dataset164triexclusif_grp43
# SUPPRIME : dataset150_grp18
# SUPPRIME : dataset147_grp45
# SUPPRIME : dataset149_grp162
# SUPPRIME : dataset156action1_grp151
# SUPPRIME : dataset164exclusif_grp85
# SUPPRIME : dataset156action5_grp164
# SUPPRIME : dataset146visite_grp156
# SUPPRIME : dataset148_grp167
# SUPPRIME : dataset156action2_grp112
# SUPPRIME : dataset156action3_grp152
# SUPPRIME : dataset156action1_grp38
# SUPPRIME : dataset152_grp165
# SUPPRIME : dataset152_grp111
# SUPPRIME : dataset149_grp106
# SUPPRIME : dataset164delegation_grp45
# SUPPRIME : dataset147_grp146
# SUPPRIME : dataset149_grp139
# SUPPRIME : dataset156action3_grp134
# SUPPRIME : dataset150_grp160
# SUPPRIME : dataset156action5_grp148
# SUPPRIME : dataset160rejete_grp146
# SUPPRIME : dataset148_grp144
# SUPPRIME : dataset154_grp146
# SUPPRIME : dataset156action4_grp106
# SUPPRIME : dataset156action4_grp120
# SUPPRIME : dataset159offres_grp113
# SUPPRIME : dataset164triexclusif_grp101
# SUPPRIME : dataset164preferentiel_grp85
# SUPPRIME : dataset164delegation_grp128
# SUPPRIME : dataset164preferentiel_grp124
# SUPPRIME : dataset146rdv_grp18
# SUPPRIME : dataset164demande_grp39
# SUPPRIME : dataset159demandes_grp110
# SUPPRIME : dataset164quadriexclusif_grp124
# SUPPRIME : dataset164quadriexclusif_grp29
# SUPPRIME : dataset149_grp144
# SUPPRIME : dataset146visite_grp171
# SUPPRIME : dataset164delegation_grp5
# SUPPRIME : dataset164coexclusif_grp96
# SUPPRIME : dataset146rdv_grp164
# SUPPRIME : dataset156action5_grp93
# SUPPRIME : dataset147_grp134
# SUPPRIME : dataset151_grp171
# SUPPRIME : dataset151_grp160
# SUPPRIME : dataset164triexclusif_grp144
# SUPPRIME : dataset164quadriexclusif_grp80
# SUPPRIME : dataset156action4_grp154
# SUPPRIME : dataset148_grp121
# SUPPRIME : dataset156action1_grp111
# SUPPRIME : dataset156action2_grp167
# SUPPRIME : dataset164preferentiel_grp61
# SUPPRIME : dataset164simple_grp18
# SUPPRIME : dataset149_grp121
# SUPPRIME : dataset164delegation_grp85
# SUPPRIME : dataset164exclusif_grp98
# SUPPRIME : dataset156action5_grp111
# SUPPRIME : dataset146proposition_grp147
# SUPPRIME : dataset159offres_grp171
# SUPPRIME : dataset152_grp120
# SUPPRIME : dataset146proposition_grp149
# SUPPRIME : dataset161rejetes_grp108
# SUPPRIME : dataset148_grp127
# SUPPRIME : dataset159offres_grp149
# SUPPRIME : dataset156action3_grp120
# SUPPRIME : dataset151_grp110
# SUPPRIME : dataset152_grp124
# SUPPRIME : dataset146rdv_grp89
# SUPPRIME : dataset146rdv_grp90
# SUPPRIME : dataset146rdv_grp60
# SUPPRIME : dataset164coexclusif_grp107
# SUPPRIME : dataset156action2_grp161
# SUPPRIME : dataset146rdv_grp114
# SUPPRIME : dataset157_grp38
# SUPPRIME : dataset156action5_grp158
# SUPPRIME : dataset159demandes_grp171
# SUPPRIME : dataset146rdv_grp45
# SUPPRIME : dataset156action3_grp53
# SUPPRIME : dataset161rejetes_grp86
# SUPPRIME : dataset164triexclusif_grp96
# SUPPRIME : dataset157_grp67
# SUPPRIME : dataset146rdv_grp54
# SUPPRIME : dataset153_grp154
# SUPPRIME : dataset159demandes_grp106
# SUPPRIME : dataset150_grp153
# SUPPRIME : dataset164coexclusif_grp45
# SUPPRIME : dataset164triexclusif_grp72
# SUPPRIME : dataset156action3_grp57
# SUPPRIME : dataset164exclusif_grp80
# SUPPRIME : dataset156action3_grp172
# SUPPRIME : dataset146rdv_grp38
# SUPPRIME : dataset156action5_grp162
# SUPPRIME : dataset146proposition_grp43
# SUPPRIME : dataset149_grp171
# SUPPRIME : dataset159offres_grp152
# SUPPRIME : dataset147_grp29
# SUPPRIME : dataset153_grp120
# SUPPRIME : dataset156action1_grp55
# SUPPRIME : dataset146visite_grp112
# SUPPRIME : dataset146rdv_grp109
# SUPPRIME : dataset150_grp151
# SUPPRIME : dataset147_grp68
# SUPPRIME : dataset150_grp93
# SUPPRIME : dataset164simple_grp164
# SUPPRIME : dataset164exclusif_grp153
# SUPPRIME : dataset164preferentiel_grp118
# SUPPRIME : dataset164delegation_grp54
# SUPPRIME : dataset149_grp164
# SUPPRIME : dataset146visite_grp89
# SUPPRIME : dataset147_grp47
# SUPPRIME : dataset146rdv_grp147
# SUPPRIME : dataset146rdv_grp80
# SUPPRIME : dataset151_grp135
# SUPPRIME : dataset153_grp167
# SUPPRIME : dataset159mandats_grp174
# SUPPRIME : dataset159offres_grp174
# SUPPRIME : dataset164exclusif_grp72
# SUPPRIME : dataset146rdv_grp50
# SUPPRIME : dataset156action3_grp61
# SUPPRIME : dataset149_grp110
# SUPPRIME : dataset159demandes_grp98
# SUPPRIME : dataset164exclusif_grp39
# SUPPRIME : dataset164demande_grp124
# SUPPRIME : dataset159offres_grp158
# SUPPRIME : dataset153_grp162
# SUPPRIME : dataset159demandes_grp148
# SUPPRIME : dataset146visite_grp134
# SUPPRIME : dataset150_grp120
# SUPPRIME : dataset152_grp93
# SUPPRIME : dataset150_grp152
# SUPPRIME : dataset146rdv_grp29
# SUPPRIME : dataset154_grp68
# SUPPRIME : dataset156action5_grp173
# SUPPRIME : dataset155_grp35
# SUPPRIME : dataset156action1_grp127
# SUPPRIME : dataset156action5_grp152
# SUPPRIME : dataset156action4_grp168
# SUPPRIME : dataset156action2_grp146
# SUPPRIME : dataset153_grp149
# SUPPRIME : dataset151_grp158
# SUPPRIME : dataset159offres_grp165
# SUPPRIME : dataset164exclusif_grp108
# SUPPRIME : dataset146visite_grp152
# SUPPRIME : dataset164quadriexclusif_grp86
# SUPPRIME : dataset156action5_grp175
# SUPPRIME : dataset156action3_grp165
# SUPPRIME : dataset152_grp106
# SUPPRIME : dataset149_grp135
# SUPPRIME : dataset150_grp111
# SUPPRIME : dataset152_grp40
# SUPPRIME : dataset161ouverts_grp108
# SUPPRIME : dataset164triexclusif_grp54
# SUPPRIME : dataset157_grp147
# SUPPRIME : dataset146proposition_grp153
# SUPPRIME : dataset164preferentiel_grp67
# SUPPRIME : dataset152_grp48
# SUPPRIME : dataset152_grp168
# SUPPRIME : dataset148_grp171
# SUPPRIME : dataset161rejetes_grp164
# SUPPRIME : dataset164preferentiel_grp75
# SUPPRIME : dataset164exclusif_grp29
# SUPPRIME : dataset148_grp120
# SUPPRIME : dataset151_grp146
# SUPPRIME : dataset152_grp149
# SUPPRIME : dataset148_grp149
# SUPPRIME : dataset150_grp124
# SUPPRIME : dataset153_grp121
# SUPPRIME : dataset148_grp90
# SUPPRIME : dataset164preferentiel_grp50
# SUPPRIME : dataset164quadriexclusif_grp5
# SUPPRIME : dataset146proposition_grp124
# SUPPRIME : dataset164demande_grp101
# SUPPRIME : dataset164coexclusif_grp64
# SUPPRIME : dataset152_grp163
# SUPPRIME : dataset146proposition_grp108
# SUPPRIME : dataset156action4_grp174
# SUPPRIME : dataset159mandats_grp164
# SUPPRIME : dataset161rejetes_grp162
# SUPPRIME : dataset150_grp134
# SUPPRIME : dataset159mandats_grp43
# SUPPRIME : dataset159mandats_grp61
# SUPPRIME : dataset156action5_grp5
# SUPPRIME : dataset159offres_grp163
# SUPPRIME : dataset151_grp175
# SUPPRIME : dataset164exclusif_grp164
# SUPPRIME : dataset164exclusif_grp67
# SUPPRIME : dataset156action4_grp93
# SUPPRIME : dataset156action5_grp138
# SUPPRIME : dataset156action1_grp171
# SUPPRIME : dataset156action1_grp175
# SUPPRIME : dataset159mandats_grp147
# SUPPRIME : dataset149_grp57
# SUPPRIME : dataset150_grp45
# SUPPRIME : dataset156action2_grp160
# SUPPRIME : dataset146visite_grp96
# SUPPRIME : dataset148_grp61
# SUPPRIME : dataset164preferentiel_grp144
# SUPPRIME : dataset156action5_grp60
# SUPPRIME : dataset146visite_grp165
# SUPPRIME : dataset148_grp110
# SUPPRIME : dataset164preferentiel_grp153
# SUPPRIME : dataset151_grp154
# SUPPRIME : dataset164coexclusif_grp29
# SUPPRIME : dataset160npai_grp147
# SUPPRIME : dataset164preferentiel_grp148
# SUPPRIME : dataset156action1_grp162
# SUPPRIME : dataset164demande_grp35
# SUPPRIME : dataset159offres_grp168
# SUPPRIME : dataset164delegation_grp108
# SUPPRIME : dataset152_grp134
# SUPPRIME : dataset156action4_grp111
# SUPPRIME : dataset160rejete_grp147
# SUPPRIME : dataset164exclusif_grp148
# SUPPRIME : dataset156action5_grp156
# SUPPRIME : dataset164delegation_grp55
# SUPPRIME : dataset146visite_grp174
# SUPPRIME : dataset156action4_grp124
# SUPPRIME : dataset150_grp139
# SUPPRIME : dataset156action2_grp168
# SUPPRIME : dataset156action2_grp172
# SUPPRIME : dataset156action1_grp57
# SUPPRIME : dataset156action2_grp164
# SUPPRIME : dataset156action3_grp144
# SUPPRIME : dataset156action2_grp149
# SUPPRIME : dataset147_grp147
# SUPPRIME : dataset156action3_grp138
# SUPPRIME : dataset156action4_grp139
# SUPPRIME : dataset164quadriexclusif_grp152
# SUPPRIME : dataset147_grp56
# SUPPRIME : dataset149_grp68
# SUPPRIME : dataset146rdv_grp55
# SUPPRIME : dataset151_grp5
# SUPPRIME : dataset164coexclusif_grp83
# SUPPRIME : dataset159demandes_grp160
# SUPPRIME : dataset161cliques_grp147
# SUPPRIME : dataset153_grp174
# SUPPRIME : dataset147_grp106
# SUPPRIME : dataset159mandats_grp175
# SUPPRIME : dataset161ouverts_grp38
# SUPPRIME : dataset149_grp112
# SUPPRIME : dataset146rdv_grp57
# SUPPRIME : dataset159mandats_grp156
# SUPPRIME : dataset151_grp18
# SUPPRIME : dataset154_grp162
# SUPPRIME : dataset152_grp110
# SUPPRIME : dataset150_grp107
# SUPPRIME : dataset146rdv_grp108
# SUPPRIME : dataset156action2_grp171
# SUPPRIME : dataset151_grp53
# SUPPRIME : dataset152_grp167
# SUPPRIME : dataset159offres_grp93
# SUPPRIME : dataset161delivres_grp147
# SUPPRIME : dataset164delegation_grp133
# SUPPRIME : dataset164delegation_grp29
# SUPPRIME : dataset159mandats_grp163
# SUPPRIME : dataset164demande_grp153
# SUPPRIME : dataset161delivres_grp38
# SUPPRIME : dataset156action5_grp106
# SUPPRIME : dataset164delegation_grp124
# SUPPRIME : dataset156action1_grp121
# SUPPRIME : dataset156action3_grp124
# SUPPRIME : dataset156action4_grp173
# SUPPRIME : dataset164triexclusif_grp148
# SUPPRIME : dataset164demande_grp164
# SUPPRIME : dataset151_grp48
# SUPPRIME : dataset149_grp168
# SUPPRIME : dataset157_grp146
# SUPPRIME : dataset156action5_grp53
# SUPPRIME : dataset159demandes_grp154
# SUPPRIME : dataset153_grp163
# SUPPRIME : dataset164simple_grp54
# SUPPRIME : dataset148_grp96
# SUPPRIME : dataset159mandats_grp146
# SUPPRIME : dataset156action2_grp156
# SUPPRIME : dataset164delegation_grp80
# SUPPRIME : dataset149_grp165
# SUPPRIME : dataset150_grp68
# SUPPRIME : dataset164demande_grp152
# SUPPRIME : dataset151_grp107
# SUPPRIME : dataset164triexclusif_grp29
# SUPPRIME : dataset156action2_grp165
# SUPPRIME : dataset146proposition_grp89
# SUPPRIME : dataset156action4_grp156
# SUPPRIME : dataset148_grp29
# SUPPRIME : dataset150_grp40
# SUPPRIME : dataset151_grp161
# SUPPRIME : dataset164triexclusif_grp80
# SUPPRIME : dataset156action2_grp148
# SUPPRIME : dataset156action4_grp135
# SUPPRIME : dataset146visite_grp106
# SUPPRIME : dataset149_grp93
# SUPPRIME : dataset164quadriexclusif_grp144
# SUPPRIME : dataset147_grp80
# SUPPRIME : dataset164triexclusif_grp61
# SUPPRIME : dataset164quadriexclusif_grp154
# SUPPRIME : dataset160npai_grp67
# SUPPRIME : dataset151_grp120
# SUPPRIME : dataset153_grp113
# SUPPRIME : dataset146rdv_grp86
# SUPPRIME : dataset146proposition_grp75
# SUPPRIME : dataset146proposition_grp64
# SUPPRIME : dataset159mandats_grp167
# SUPPRIME : dataset161cliques_grp38
# SUPPRIME : dataset156action3_grp156
# SUPPRIME : dataset164preferentiel_grp154
# SUPPRIME : dataset150_grp5
# SUPPRIME : dataset156action1_grp93
# SUPPRIME : dataset153_grp68
# SUPPRIME : dataset149_grp175
# SUPPRIME : dataset157_grp164
# SUPPRIME : dataset159offres_grp55
# SUPPRIME : dataset164simple_grp80
# SUPPRIME : dataset164triexclusif_grp107
# SUPPRIME : dataset156action4_grp164
# SUPPRIME : dataset160rejete_grp35
# SUPPRIME : dataset151_grp147
# SUPPRIME : dataset156action2_grp48
# SUPPRIME : dataset164coexclusif_grp39
# SUPPRIME : dataset161rejetes_grp38
# SUPPRIME : dataset151_grp124
# SUPPRIME : dataset156action3_grp133
# SUPPRIME : dataset159demandes_grp55
# SUPPRIME : dataset156action5_grp161
# SUPPRIME : dataset153_grp152
# SUPPRIME : dataset164exclusif_grp156
# SUPPRIME : dataset150_grp133
# SUPPRIME : dataset153_grp61
# SUPPRIME : dataset159offres_grp154
# SUPPRIME : dataset164delegation_grp75
# SUPPRIME : dataset149_grp146
# SUPPRIME : dataset164coexclusif_grp43
# SUPPRIME : dataset151_grp168
# SUPPRIME : dataset146visite_grp114
# SUPPRIME : dataset146proposition_grp85
# SUPPRIME : dataset156action5_grp61
# SUPPRIME : dataset156action4_grp90
# SUPPRIME : dataset156action1_grp89
# SUPPRIME : dataset146rdv_grp152
# SUPPRIME : dataset149_grp152
# SUPPRIME : dataset161delivres_grp164
# SUPPRIME : dataset164demande_grp144
# SUPPRIME : dataset159offres_grp124
# SUPPRIME : dataset156action5_grp18
# SUPPRIME : dataset156action3_grp168
# SUPPRIME : dataset164demande_grp13
# SUPPRIME : dataset154_grp29
# SUPPRIME : dataset149_grp149
# SUPPRIME : dataset164exclusif_grp90
# SUPPRIME : dataset150_grp154
# SUPPRIME : dataset152_grp162
# SUPPRIME : dataset164exclusif_grp152
# SUPPRIME : dataset147_grp55
# SUPPRIME : dataset164preferentiel_grp39
# SUPPRIME : dataset156action4_grp138
# SUPPRIME : dataset164exclusif_grp175
# SUPPRIME : dataset155_grp162
# SUPPRIME : dataset146rdv_grp100
# SUPPRIME : dataset156action4_grp98
# SUPPRIME : dataset148_grp139
# SUPPRIME : dataset164quadriexclusif_grp164
# SUPPRIME : dataset147_grp154
# SUPPRIME : dataset146proposition_grp29
# SUPPRIME : dataset146rdv_grp67
# SUPPRIME : dataset156action3_grp173
# SUPPRIME : dataset148_grp174
# SUPPRIME : dataset160rejete_grp108
# SUPPRIME : dataset148_grp55
# SUPPRIME : dataset149_grp61
# SUPPRIME : dataset159mandats_grp144
# SUPPRIME : dataset146rdv_grp124
# SUPPRIME : dataset164demande_grp120
# SUPPRIME : dataset156action4_grp112
# SUPPRIME : dataset160npai_grp162
# SUPPRIME : dataset152_grp171
# SUPPRIME : dataset159mandats_grp152
# SUPPRIME : dataset156action5_grp67
# SUPPRIME : dataset152_grp152
# SUPPRIME : dataset146visite_grp98
# SUPPRIME : dataset152_grp135
# SUPPRIME : dataset150_grp113
# SUPPRIME : dataset159offres_grp156
# SUPPRIME : dataset164exclusif_grp154
# SUPPRIME : dataset164delegation_grp14
# SUPPRIME : dataset164simple_grp171
# SUPPRIME : dataset146visite_grp13
# SUPPRIME : dataset156action5_grp174
# SUPPRIME : dataset164preferentiel_grp107
# SUPPRIME : dataset156action4_grp45
# SUPPRIME : dataset156action1_grp61
# SUPPRIME : dataset151_grp121
# SUPPRIME : dataset151_grp148
# SUPPRIME : dataset160rejete_grp164
# SUPPRIME : dataset164quadriexclusif_grp75
# SUPPRIME : dataset146proposition_grp83
# SUPPRIME : dataset164preferentiel_grp164
# SUPPRIME : dataset153_grp39
# SUPPRIME : dataset146rdv_grp79
# SUPPRIME : dataset156action4_grp61
# SUPPRIME : dataset156action1_grp164
# SUPPRIME : dataset148_grp165
# SUPPRIME : dataset150_grp172
# SUPPRIME : dataset156action2_grp135
# SUPPRIME : dataset160npai_grp86
# SUPPRIME : dataset156action2_grp154
# SUPPRIME : dataset159mandats_grp68
# SUPPRIME : dataset156action5_grp160
# SUPPRIME : dataset152_grp113
# SUPPRIME : dataset156action2_grp147
# SUPPRIME : dataset147_grp101
# SUPPRIME : dataset155_grp146
# SUPPRIME : dataset156action5_grp39
# SUPPRIME : dataset155_grp86
# SUPPRIME : dataset146visite_grp85
# SUPPRIME : dataset164delegation_grp89
# SUPPRIME : dataset148_grp39
# SUPPRIME : dataset159offres_grp160
# SUPPRIME : dataset155_grp68
# SUPPRIME : dataset164demande_grp85
# SUPPRIME : dataset156action4_grp146
# SUPPRIME : dataset149_grp151
# SUPPRIME : dataset152_grp164
# SUPPRIME : dataset156action1_grp112
# SUPPRIME : dataset147_grp75
# SUPPRIME : dataset150_grp168
# SUPPRIME : dataset153_grp112
# SUPPRIME : dataset159mandats_grp57
# SUPPRIME : dataset164quadriexclusif_grp153
# SUPPRIME : dataset148_grp106
# SUPPRIME : dataset150_grp149
# SUPPRIME : dataset159offres_grp147
# SUPPRIME : dataset146visite_grp72
# SUPPRIME : dataset152_grp55
# SUPPRIME : dataset156action2_grp151
# SUPPRIME : dataset156action3_grp90
# SUPPRIME : dataset159demandes_grp93
# SUPPRIME : dataset156action3_grp48
# SUPPRIME : dataset164demande_grp56
# SUPPRIME : dataset147_grp107
# SUPPRIME : dataset150_grp135
# SUPPRIME : dataset148_grp168
# SUPPRIME : dataset164demande_grp61
# SUPPRIME : dataset156action2_grp120
# SUPPRIME : dataset153_grp90
# SUPPRIME : dataset159demandes_grp175
# SUPPRIME : dataset146proposition_grp57
# SUPPRIME : dataset164triexclusif_grp164
# SUPPRIME : dataset146rdv_grp96
# SUPPRIME : dataset164coexclusif_grp85
# SUPPRIME : dataset156action1_grp172
# SUPPRIME : dataset156action2_grp158
# SUPPRIME : dataset156action5_grp134
# SUPPRIME : dataset147_grp93
# SUPPRIME : dataset156action5_grp165
# SUPPRIME : dataset146rdv_grp101
# SUPPRIME : dataset153_grp144
# SUPPRIME : dataset148_grp108
# SUPPRIME : dataset156action5_grp113
# SUPPRIME : dataset152_grp139
# SUPPRIME : dataset156action4_grp48
# SUPPRIME : dataset164exclusif_grp135
# SUPPRIME : dataset164coexclusif_grp128
# SUPPRIME : dataset153_grp151
# SUPPRIME : dataset156action3_grp158
# SUPPRIME : dataset164demande_grp107
# SUPPRIME : dataset164exclusif_grp172
# SUPPRIME : dataset160rejete_grp86
# SUPPRIME : dataset146proposition_grp50
# SUPPRIME : dataset159mandats_grp161
# SUPPRIME : dataset164demande_grp43
# SUPPRIME : dataset146visite_grp154
# SUPPRIME : dataset152_grp156
# SUPPRIME : dataset156action1_grp168
# SUPPRIME : dataset149_grp163
# SUPPRIME : dataset159mandats_grp171
# SUPPRIME : dataset159demandes_grp113
# SUPPRIME : dataset149_grp54
# SUPPRIME : dataset164simple_grp106
# SUPPRIME : dataset156action4_grp57
# SUPPRIME : dataset149_grp147
# SUPPRIME : dataset161cliques_grp164
# 1710 datasets supprimés : il ne reste plus que 707 datasets

# %%
# Maintenant on supprime aussi les datasets qui ont trop de trous d'affilée, ca ne devrait pas en faire bcp

def mois_vides_consecutifs(dates):
    periods = dates.dt.to_period('M').sort_values().unique()
    full_range = pd.period_range(start=periods.min(), end=mois_courant.to_period('M'), freq='M')
    mois_sans_donnees = [p for p in full_range if p not in periods]

    count, seq_max = 0, 0
    for i in range(1, len(mois_sans_donnees)):
        if mois_sans_donnees[i] - mois_sans_donnees[i - 1] == 1:
            count += 1
            seq_max = max(seq_max, count)
        else:
            count = 0
    return seq_max + 1 >= 3  # +1 car une séquence de 2 gaps = 3 mois consécutifs

# Détection
datasets_trop_de_trous = [
    nom for nom, df in datasets_groupes.items()
    if 'date' in df.columns and mois_vides_consecutifs(df['date'])
]

for nom in datasets_trop_de_trous : 
    del datasets_groupes[nom]
    del globals()[nom]
    print(f"SUPPRIME : {nom}")

print(f'{len(datasets_trop_de_trous)} datasets supprimés : il ne reste plus que {len(datasets_groupes)} datasets')
# Out:
# 0 datasets supprimés : il ne reste plus que 707 datasets

# %%
# ATTENTION !! Nombre de mois manquants à la fin de la série à modifier en fonction du temps depuis laquel la base dev n'a 
# pas été actualisée... Si ca fait longtemps on risque de supprimer tous les datasets en étant trop strict sur le nombre 
# maximal de mois manquants à la fin

# Les prévisions Propeht dépendant plus fortement des derniers mois, ça pose problème si il manque les deux derniers mois
# ou plus. On supprime donc les datasets qui n'ont pas de données récentes.

# Liste des clés à supprimer
cles_a_supprimer = []

# Détermination des 4 derniers mois
mois_actuel = pd.to_datetime(datetime.today().strftime('%Y-%m-01'))
mois_precedent = mois_actuel - pd.DateOffset(months=1)
mois_moins_2 = mois_actuel - pd.DateOffset(months=2)
mois_moins_3 = mois_actuel - pd.DateOffset(months=3)

# On veut garder seulement les datasets ayant AU MOINS UNE donnée dans ces 4 mois
mois_recents = [
    mois_moins_3.to_period('M'),
    mois_moins_2.to_period('M'),
    mois_precedent.to_period('M'),
    mois_actuel.to_period('M')
]

# Vérification pour chaque dataset
for nom, df in datasets_groupes.items():
    dates_disponibles = pd.to_datetime(df['date']).dt.to_period('M')

    # Si aucun des 4 derniers mois n'est présent → suppression
    if all(mois not in dates_disponibles.values for mois in mois_recents):
        print(f"{nom} : les 4 derniers mois sont absents")
        cles_a_supprimer.append(nom)

# Suppression des datasets
for cle in cles_a_supprimer:
    datasets_groupes.pop(cle, None)
    if cle in globals():
        del globals()[cle]

print(f"{len(cles_a_supprimer)} datasets supprimés.")
# Out:
# dataset164triexclusif_grp89 : les 4 derniers mois sont absents
# 1 datasets supprimés.

# %%
# On supprime aussi les datasets qui ont trop de fois la même valeur, sinon prophet ne saura pas fit de modele

seuil_valeurs_identiques = 0.90
cles_a_supprimer = []

for nom, df in datasets_groupes.items():
    valeurs_uniques = df['valeur'].value_counts(normalize=True)
    if any(valeurs_uniques > seuil_valeurs_identiques):
        # print(f"Suppression de {nom} : une valeur apparaît dans plus de 1/3 des cas")
        cles_a_supprimer.append(nom)

print(f'{len(cles_a_supprimer)} datasets ont été supprimés car trop de valeurs identiques')

for cle in cles_a_supprimer:
    datasets_groupes.pop(cle, None)
    if cle in globals():
        del globals()[cle]
# Out:
# 17 datasets ont été supprimés car trop de valeurs identiques

# %%
# Petite vérif avant d'interpoler les valeurs manquantes

for nom, df in datasets_groupes.items():
    if len(df) < 36 :
        print(f"❗ {nom} contient seulement {len(df)} lignes avant interpolation")

# %%
# Interpolation des valeurs manquantes

for nom, df in datasets_groupes.items():
    mois_complets = pd.date_range(start=df['date'].min(), end=df['date'].max(), freq='MS')
    groupe = df['groupe_id'].iloc[0]
    df_toutes_dates = pd.DataFrame({'date': mois_complets})
    df_toutes_dates['groupe_id'] = groupe
    df_fusionne = df_toutes_dates.merge(df, on=['date', 'groupe_id'], how='left')
    df_fusionne['valeur'] = df_fusionne['valeur'].interpolate(method='linear')
    datasets_groupes[nom] = df_fusionne
    globals()[nom] = df_fusionne
    print(f"✅ {nom} complété ({len(df_fusionne)} mois)")
# Out:
# ✅ dataset146visite_grp29 complété (188 mois)
# ✅ dataset146visite_grp35 complété (181 mois)
# ✅ dataset146visite_grp38 complété (204 mois)
# ✅ dataset146visite_grp47 complété (152 mois)
# ✅ dataset146visite_grp50 complété (156 mois)
# ✅ dataset146visite_grp56 complété (138 mois)
# ✅ dataset146visite_grp67 complété (125 mois)
# ✅ dataset146visite_grp68 complété (125 mois)
# ✅ dataset146visite_grp75 complété (117 mois)
# ✅ dataset146visite_grp76 complété (113 mois)
# ✅ dataset146visite_grp79 complété (114 mois)
# ✅ dataset146visite_grp83 complété (108 mois)
# ✅ dataset146visite_grp86 complété (104 mois)
# ✅ dataset146visite_grp100 complété (86 mois)
# ✅ dataset146visite_grp107 complété (76 mois)
# ✅ dataset146visite_grp108 complété (107 mois)
# ✅ dataset146visite_grp118 complété (62 mois)
# ✅ dataset146visite_grp133 complété (59 mois)
# ✅ dataset146visite_grp153 complété (187 mois)
# ✅ dataset146rdv_grp13 complété (204 mois)
# ✅ dataset146rdv_grp35 complété (180 mois)
# ✅ dataset146rdv_grp83 complété (60 mois)
# ✅ dataset146rdv_grp118 complété (60 mois)
# ✅ dataset146rdv_grp133 complété (53 mois)
# ✅ dataset146rdv_grp153 complété (177 mois)
# ✅ dataset147_grp13 complété (204 mois)
# ✅ dataset147_grp14 complété (204 mois)
# ✅ dataset147_grp35 complété (203 mois)
# ✅ dataset147_grp38 complété (205 mois)
# ✅ dataset147_grp39 complété (203 mois)
# ✅ dataset147_grp50 complété (164 mois)
# ✅ dataset147_grp133 complété (205 mois)
# ✅ dataset147_grp153 complété (204 mois)
# ✅ dataset148_grp7 complété (204 mois)
# ✅ dataset148_grp13 complété (204 mois)
# ✅ dataset148_grp14 complété (204 mois)
# ✅ dataset148_grp35 complété (181 mois)
# ✅ dataset148_grp38 complété (204 mois)
# ✅ dataset148_grp43 complété (158 mois)
# ✅ dataset148_grp47 complété (153 mois)
# ✅ dataset148_grp50 complété (204 mois)
# ✅ dataset148_grp54 complété (154 mois)
# ✅ dataset148_grp56 complété (204 mois)
# ✅ dataset148_grp64 complété (126 mois)
# ✅ dataset148_grp67 complété (126 mois)
# ✅ dataset150_grp75 complété (205 mois)
# ✅ dataset150_grp76 complété (112 mois)
# ✅ dataset150_grp79 complété (204 mois)
# ✅ dataset150_grp80 complété (111 mois)
# ✅ dataset150_grp83 complété (204 mois)
# ✅ dataset150_grp85 complété (105 mois)
# ✅ dataset150_grp86 complété (105 mois)
# ✅ dataset150_grp89 complété (101 mois)
# ✅ dataset150_grp90 complété (101 mois)
# ✅ dataset150_grp96 complété (204 mois)
# ✅ dataset150_grp98 complété (137 mois)
# ✅ dataset150_grp100 complété (87 mois)
# ✅ dataset150_grp101 complété (87 mois)
# ✅ dataset150_grp108 complété (204 mois)
# ✅ dataset150_grp109 complété (74 mois)
# ✅ dataset150_grp112 complété (72 mois)
# ✅ dataset150_grp114 complété (72 mois)
# ✅ dataset150_grp118 complété (106 mois)
# ✅ dataset150_grp127 complété (61 mois)
# ✅ dataset150_grp138 complété (72 mois)
# ✅ dataset151_grp7 complété (204 mois)
# ✅ dataset151_grp13 complété (204 mois)
# ✅ dataset151_grp14 complété (204 mois)
# ✅ dataset151_grp29 complété (185 mois)
# ✅ dataset151_grp35 complété (181 mois)
# ✅ dataset151_grp38 complété (204 mois)
# ✅ dataset151_grp39 complété (204 mois)
# ✅ dataset151_grp43 complété (158 mois)
# ✅ dataset151_grp45 complété (157 mois)
# ✅ dataset151_grp47 complété (154 mois)
# ✅ dataset151_grp50 complété (204 mois)
# ✅ dataset151_grp54 complété (183 mois)
# ✅ dataset151_grp56 complété (204 mois)
# ✅ dataset151_grp60 complété (134 mois)
# ✅ dataset151_grp61 complété (132 mois)
# ✅ dataset151_grp64 complété (129 mois)
# ✅ dataset151_grp67 complété (204 mois)
# ✅ dataset151_grp68 complété (203 mois)
# ✅ dataset151_grp72 complété (120 mois)
# ✅ dataset151_grp75 complété (205 mois)
# ✅ dataset151_grp76 complété (112 mois)
# ✅ dataset151_grp79 complété (204 mois)
# ✅ dataset151_grp80 complété (111 mois)
# ✅ dataset151_grp83 complété (204 mois)
# ✅ dataset151_grp85 complété (105 mois)
# ✅ dataset151_grp86 complété (105 mois)
# ✅ dataset151_grp89 complété (101 mois)
# ✅ dataset151_grp90 complété (101 mois)
# ✅ dataset151_grp96 complété (204 mois)
# ✅ dataset151_grp98 complété (137 mois)
# ✅ dataset151_grp100 complété (87 mois)
# ✅ dataset151_grp101 complété (87 mois)
# ✅ dataset151_grp108 complété (204 mois)
# ✅ dataset151_grp109 complété (74 mois)
# ✅ dataset151_grp112 complété (72 mois)
# ✅ dataset151_grp114 complété (72 mois)
# ✅ dataset151_grp118 complété (106 mois)
# ✅ dataset151_grp127 complété (61 mois)
# ✅ dataset151_grp128 complété (60 mois)
# ✅ dataset151_grp133 complété (205 mois)
# ✅ dataset151_grp138 complété (72 mois)
# ✅ dataset151_grp144 complété (114 mois)
# ✅ dataset151_grp153 complété (203 mois)
# ✅ dataset151_grp172 complété (204 mois)
# ✅ dataset151_grp173 complété (201 mois)
# ✅ dataset152_grp5 complété (204 mois)
# ✅ dataset152_grp7 complété (204 mois)
# ✅ dataset152_grp13 complété (204 mois)
# ✅ dataset152_grp14 complété (204 mois)
# ✅ dataset152_grp29 complété (185 mois)
# ✅ dataset152_grp35 complété (181 mois)
# ✅ dataset152_grp38 complété (204 mois)
# ✅ dataset152_grp43 complété (158 mois)
# ✅ dataset152_grp45 complété (157 mois)
# ✅ dataset152_grp47 complété (154 mois)
# ✅ dataset152_grp50 complété (204 mois)
# ✅ dataset152_grp54 complété (179 mois)
# ✅ dataset152_grp56 complété (204 mois)
# ✅ dataset152_grp60 complété (132 mois)
# ✅ dataset152_grp61 complété (132 mois)
# ✅ dataset152_grp64 complété (129 mois)
# ✅ dataset152_grp67 complété (204 mois)
# ✅ dataset152_grp68 complété (203 mois)
# ✅ dataset152_grp72 complété (120 mois)
# ✅ dataset152_grp75 complété (205 mois)
# ✅ dataset152_grp76 complété (112 mois)
# ✅ dataset152_grp79 complété (204 mois)
# ✅ dataset152_grp80 complété (111 mois)
# ✅ dataset152_grp83 complété (204 mois)
# ✅ dataset152_grp85 complété (105 mois)
# ✅ dataset152_grp86 complété (105 mois)
# ✅ dataset152_grp89 complété (101 mois)
# ✅ dataset152_grp90 complété (101 mois)
# ✅ dataset152_grp96 complété (204 mois)
# ✅ dataset152_grp98 complété (137 mois)
# ✅ dataset152_grp100 complété (87 mois)
# ✅ dataset152_grp101 complété (87 mois)
# ✅ dataset152_grp108 complété (204 mois)
# ✅ dataset152_grp109 complété (74 mois)
# ✅ dataset152_grp112 complété (72 mois)
# ✅ dataset152_grp114 complété (72 mois)
# ✅ dataset152_grp118 complété (106 mois)
# ✅ dataset152_grp127 complété (61 mois)
# ✅ dataset152_grp128 complété (60 mois)
# ✅ dataset152_grp133 complété (205 mois)
# ✅ dataset152_grp138 complété (72 mois)
# ✅ dataset152_grp144 complété (114 mois)
# ✅ dataset152_grp153 complété (203 mois)
# ✅ dataset152_grp172 complété (204 mois)
# ✅ dataset152_grp173 complété (201 mois)
# ✅ dataset153_grp7 complété (204 mois)
# ✅ dataset153_grp13 complété (204 mois)
# ✅ dataset153_grp14 complété (204 mois)
# ✅ dataset153_grp29 complété (185 mois)
# ✅ dataset153_grp35 complété (181 mois)
# ✅ dataset153_grp38 complété (204 mois)
# ✅ dataset153_grp43 complété (158 mois)
# ✅ dataset153_grp47 complété (153 mois)
# ✅ dataset153_grp50 complété (204 mois)
# ✅ dataset153_grp54 complété (145 mois)
# ✅ dataset153_grp56 complété (204 mois)
# ✅ dataset153_grp60 complété (131 mois)
# ✅ dataset153_grp64 complété (126 mois)
# ✅ dataset153_grp67 complété (126 mois)
# ✅ dataset153_grp72 complété (120 mois)
# ✅ dataset153_grp75 complété (204 mois)
# ✅ dataset153_grp76 complété (112 mois)
# ✅ dataset153_grp79 complété (204 mois)
# ✅ dataset153_grp80 complété (110 mois)
# ✅ dataset153_grp83 complété (204 mois)
# ✅ dataset153_grp85 complété (105 mois)
# ✅ dataset153_grp86 complété (204 mois)
# ✅ dataset153_grp89 complété (101 mois)
# ✅ dataset153_grp100 complété (87 mois)
# ✅ dataset153_grp101 complété (82 mois)
# ✅ dataset153_grp107 complété (110 mois)
# ✅ dataset153_grp109 complété (73 mois)
# ✅ dataset153_grp114 complété (71 mois)
# ✅ dataset153_grp118 complété (63 mois)
# ✅ dataset153_grp128 complété (57 mois)
# ✅ dataset153_grp134 complété (50 mois)
# ✅ dataset153_grp138 complété (72 mois)
# ✅ dataset153_grp153 complété (177 mois)
# ✅ dataset153_grp172 complété (176 mois)
# ✅ dataset156action1_grp5 complété (175 mois)
# ✅ dataset156action1_grp7 complété (177 mois)
# ✅ dataset156action1_grp13 complété (177 mois)
# ✅ dataset156action1_grp14 complété (177 mois)
# ✅ dataset156action1_grp18 complété (176 mois)
# ✅ dataset156action1_grp29 complété (177 mois)
# ✅ dataset156action1_grp35 complété (177 mois)
# ✅ dataset156action1_grp39 complété (170 mois)
# ✅ dataset156action1_grp43 complété (158 mois)
# ✅ dataset156action1_grp47 complété (153 mois)
# ✅ dataset156action1_grp50 complété (152 mois)
# ✅ dataset156action1_grp54 complété (142 mois)
# ✅ dataset156action1_grp56 complété (138 mois)
# ✅ dataset156action1_grp60 complété (131 mois)
# ✅ dataset156action1_grp64 complété (129 mois)
# ✅ dataset156action1_grp67 complété (126 mois)
# ✅ dataset156action1_grp68 complété (126 mois)
# ✅ dataset156action1_grp72 complété (120 mois)
# ✅ dataset156action1_grp75 complété (117 mois)
# ✅ dataset156action1_grp76 complété (114 mois)
# ✅ dataset156action1_grp79 complété (113 mois)
# ✅ dataset156action1_grp80 complété (110 mois)
# ✅ dataset156action1_grp83 complété (107 mois)
# ✅ dataset156action1_grp85 complété (105 mois)
# ✅ dataset156action1_grp86 complété (104 mois)
# ✅ dataset156action1_grp90 complété (98 mois)
# ✅ dataset156action1_grp96 complété (88 mois)
# ✅ dataset156action1_grp98 complété (90 mois)
# ✅ dataset156action1_grp100 complété (87 mois)
# ✅ dataset156action1_grp101 complété (86 mois)
# ✅ dataset156action1_grp107 complété (77 mois)
# ✅ dataset156action1_grp108 complété (74 mois)
# ✅ dataset156action1_grp109 complété (74 mois)
# ✅ dataset156action1_grp114 complété (72 mois)
# ✅ dataset156action1_grp118 complété (62 mois)
# ✅ dataset156action1_grp128 complété (57 mois)
# ✅ dataset156action1_grp133 complété (54 mois)
# ✅ dataset156action1_grp134 complété (50 mois)
# ✅ dataset156action1_grp144 complété (40 mois)
# ✅ dataset156action1_grp153 complété (177 mois)
# ✅ dataset156action2_grp5 complété (175 mois)
# ✅ dataset156action2_grp7 complété (177 mois)
# ✅ dataset156action2_grp13 complété (177 mois)
# ✅ dataset156action2_grp14 complété (177 mois)
# ✅ dataset156action2_grp18 complété (177 mois)
# ✅ dataset156action2_grp29 complété (177 mois)
# ✅ dataset156action2_grp35 complété (177 mois)
# ✅ dataset156action2_grp38 complété (174 mois)
# ✅ dataset156action2_grp39 complété (170 mois)
# ✅ dataset156action2_grp47 complété (153 mois)
# ✅ dataset156action2_grp50 complété (152 mois)
# ✅ dataset156action2_grp53 complété (144 mois)
# ✅ dataset156action2_grp54 complété (142 mois)
# ✅ dataset156action2_grp56 complété (138 mois)
# ✅ dataset156action2_grp60 complété (131 mois)
# ✅ dataset156action2_grp64 complété (129 mois)
# ✅ dataset156action2_grp67 complété (126 mois)
# ✅ dataset156action2_grp68 complété (126 mois)
# ✅ dataset156action2_grp72 complété (120 mois)
# ✅ dataset156action2_grp75 complété (117 mois)
# ✅ dataset156action2_grp76 complété (114 mois)
# ✅ dataset156action2_grp79 complété (113 mois)
# ✅ dataset156action2_grp80 complété (110 mois)
# ✅ dataset156action2_grp83 complété (107 mois)
# ✅ dataset156action2_grp85 complété (105 mois)
# ✅ dataset156action2_grp86 complété (104 mois)
# ✅ dataset156action2_grp89 complété (101 mois)
# ✅ dataset156action2_grp90 complété (98 mois)
# ✅ dataset156action2_grp96 complété (88 mois)
# ✅ dataset156action2_grp100 complété (87 mois)
# ✅ dataset156action2_grp101 complété (86 mois)
# ✅ dataset156action2_grp107 complété (77 mois)
# ✅ dataset156action2_grp108 complété (74 mois)
# ✅ dataset156action2_grp109 complété (74 mois)
# ✅ dataset156action2_grp114 complété (72 mois)
# ✅ dataset156action2_grp118 complété (62 mois)
# ✅ dataset156action2_grp128 complété (57 mois)
# ✅ dataset156action2_grp133 complété (54 mois)
# ✅ dataset156action2_grp153 complété (177 mois)
# ✅ dataset156action3_grp5 complété (175 mois)
# ✅ dataset156action3_grp7 complété (177 mois)
# ✅ dataset156action3_grp13 complété (177 mois)
# ✅ dataset156action3_grp14 complété (177 mois)
# ✅ dataset156action3_grp18 complété (177 mois)
# ✅ dataset156action3_grp29 complété (177 mois)
# ✅ dataset156action3_grp35 complété (177 mois)
# ✅ dataset156action3_grp38 complété (174 mois)
# ✅ dataset156action3_grp39 complété (170 mois)
# ✅ dataset156action3_grp43 complété (158 mois)
# ✅ dataset156action3_grp47 complété (153 mois)
# ✅ dataset156action3_grp50 complété (152 mois)
# ✅ dataset156action3_grp54 complété (142 mois)
# ✅ dataset156action3_grp56 complété (138 mois)
# ✅ dataset156action3_grp64 complété (129 mois)
# ✅ dataset156action3_grp67 complété (126 mois)
# ✅ dataset156action3_grp68 complété (126 mois)
# ✅ dataset156action3_grp72 complété (120 mois)
# ✅ dataset156action3_grp75 complété (117 mois)
# ✅ dataset156action3_grp76 complété (114 mois)
# ✅ dataset156action3_grp79 complété (113 mois)
# ✅ dataset156action3_grp80 complété (110 mois)
# ✅ dataset156action3_grp83 complété (107 mois)
# ✅ dataset156action3_grp85 complété (105 mois)
# ✅ dataset156action3_grp86 complété (104 mois)
# ✅ dataset156action3_grp89 complété (101 mois)
# ✅ dataset156action3_grp96 complété (87 mois)
# ✅ dataset156action3_grp98 complété (90 mois)
# ✅ dataset156action3_grp100 complété (87 mois)
# ✅ dataset156action3_grp101 complété (86 mois)
# ✅ dataset156action3_grp107 complété (77 mois)
# ✅ dataset156action3_grp108 complété (74 mois)
# ✅ dataset156action3_grp109 complété (74 mois)
# ✅ dataset156action3_grp114 complété (72 mois)
# ✅ dataset156action3_grp118 complété (63 mois)
# ✅ dataset156action3_grp128 complété (57 mois)
# ✅ dataset156action3_grp153 complété (177 mois)
# ✅ dataset156action4_grp13 complété (177 mois)
# ✅ dataset156action4_grp14 complété (177 mois)
# ✅ dataset156action4_grp29 complété (177 mois)
# ✅ dataset156action4_grp35 complété (177 mois)
# ✅ dataset156action4_grp38 complété (174 mois)
# ✅ dataset156action4_grp43 complété (158 mois)
# ✅ dataset156action4_grp47 complété (153 mois)
# ✅ dataset156action4_grp50 complété (152 mois)
# ✅ dataset156action4_grp53 complété (144 mois)
# ✅ dataset156action4_grp54 complété (142 mois)
# ✅ dataset156action4_grp56 complété (138 mois)
# ✅ dataset156action4_grp60 complété (131 mois)
# ✅ dataset156action4_grp64 complété (129 mois)
# ✅ dataset156action4_grp67 complété (126 mois)
# ✅ dataset156action4_grp68 complété (126 mois)
# ✅ dataset156action4_grp72 complété (120 mois)
# ✅ dataset156action4_grp75 complété (117 mois)
# ✅ dataset156action4_grp76 complété (114 mois)
# ✅ dataset156action4_grp79 complété (113 mois)
# ✅ dataset156action4_grp80 complété (110 mois)
# ✅ dataset156action4_grp83 complété (107 mois)
# ✅ dataset156action4_grp85 complété (105 mois)
# ✅ dataset156action4_grp86 complété (104 mois)
# ✅ dataset156action4_grp96 complété (88 mois)
# ✅ dataset156action4_grp100 complété (87 mois)
# ✅ dataset156action4_grp101 complété (86 mois)
# ✅ dataset156action4_grp108 complété (74 mois)
# ✅ dataset156action4_grp109 complété (74 mois)
# ✅ dataset156action4_grp114 complété (72 mois)
# ✅ dataset156action4_grp118 complété (63 mois)
# ✅ dataset156action4_grp128 complété (57 mois)
# ✅ dataset156action4_grp133 complété (54 mois)
# ✅ dataset156action4_grp153 complété (177 mois)
# ✅ dataset156action5_grp13 complété (177 mois)
# ✅ dataset156action5_grp14 complété (177 mois)
# ✅ dataset156action5_grp29 complété (177 mois)
# ✅ dataset156action5_grp35 complété (177 mois)
# ✅ dataset156action5_grp38 complété (174 mois)
# ✅ dataset156action5_grp43 complété (158 mois)
# ✅ dataset156action5_grp47 complété (153 mois)
# ✅ dataset156action5_grp50 complété (152 mois)
# ✅ dataset156action5_grp54 complété (142 mois)
# ✅ dataset156action5_grp56 complété (137 mois)
# ✅ dataset156action5_grp64 complété (129 mois)
# ✅ dataset156action5_grp68 complété (126 mois)
# ✅ dataset156action5_grp72 complété (120 mois)
# ✅ dataset156action5_grp75 complété (117 mois)
# ✅ dataset156action5_grp76 complété (114 mois)
# ✅ dataset156action5_grp79 complété (113 mois)
# ✅ dataset156action5_grp80 complété (110 mois)
# ✅ dataset156action5_grp83 complété (107 mois)
# ✅ dataset156action5_grp85 complété (105 mois)
# ✅ dataset156action5_grp86 complété (104 mois)
# ✅ dataset156action5_grp89 complété (101 mois)
# ✅ dataset156action5_grp96 complété (88 mois)
# ✅ dataset156action5_grp100 complété (87 mois)
# ✅ dataset156action5_grp101 complété (86 mois)
# ✅ dataset156action5_grp107 complété (77 mois)
# ✅ dataset156action5_grp108 complété (74 mois)
# ✅ dataset156action5_grp109 complété (74 mois)
# ✅ dataset159demandes_grp29 complété (186 mois)
# ✅ dataset159demandes_grp35 complété (181 mois)
# ✅ dataset159demandes_grp38 complété (204 mois)
# ✅ dataset159demandes_grp43 complété (158 mois)
# ✅ dataset159demandes_grp45 complété (157 mois)
# ✅ dataset159demandes_grp47 complété (154 mois)
# ✅ dataset159demandes_grp50 complété (204 mois)
# ✅ dataset159demandes_grp53 complété (144 mois)
# ✅ dataset159demandes_grp56 complété (204 mois)
# ✅ dataset159demandes_grp60 complété (134 mois)
# ✅ dataset159demandes_grp61 complété (132 mois)
# ✅ dataset159demandes_grp64 complété (129 mois)
# ✅ dataset159demandes_grp67 complété (204 mois)
# ✅ dataset159demandes_grp68 complété (204 mois)
# ✅ dataset159demandes_grp72 complété (120 mois)
# ✅ dataset159demandes_grp75 complété (205 mois)
# ✅ dataset159demandes_grp76 complété (114 mois)
# ✅ dataset159demandes_grp79 complété (204 mois)
# ✅ dataset159demandes_grp80 complété (111 mois)
# ✅ dataset159demandes_grp83 complété (204 mois)
# ✅ dataset159demandes_grp85 complété (105 mois)
# ✅ dataset159demandes_grp86 complété (205 mois)
# ✅ dataset159demandes_grp89 complété (101 mois)
# ✅ dataset159demandes_grp96 complété (204 mois)
# ✅ dataset159demandes_grp100 complété (87 mois)
# ✅ dataset159demandes_grp101 complété (87 mois)
# ✅ dataset159demandes_grp107 complété (203 mois)
# ✅ dataset159demandes_grp108 complété (204 mois)
# ✅ dataset159demandes_grp109 complété (74 mois)
# ✅ dataset159demandes_grp112 complété (72 mois)
# ✅ dataset159demandes_grp114 complété (72 mois)
# ✅ dataset159demandes_grp118 complété (106 mois)
# ✅ dataset159demandes_grp120 complété (67 mois)
# ✅ dataset159demandes_grp128 complété (60 mois)
# ✅ dataset159demandes_grp133 complété (205 mois)
# ✅ dataset159demandes_grp134 complété (52 mois)
# ✅ dataset159demandes_grp138 complété (72 mois)
# ✅ dataset159demandes_grp153 complété (203 mois)
# ✅ dataset159demandes_grp172 complété (204 mois)
# ✅ dataset159mandats_grp5 complété (204 mois)
# ✅ dataset159mandats_grp13 complété (204 mois)
# ✅ dataset159mandats_grp14 complété (204 mois)
# ✅ dataset159mandats_grp29 complété (186 mois)
# ✅ dataset159mandats_grp35 complété (181 mois)
# ✅ dataset159mandats_grp38 complété (204 mois)
# ✅ dataset159mandats_grp39 complété (204 mois)
# ✅ dataset159mandats_grp45 complété (157 mois)
# ✅ dataset159mandats_grp47 complété (154 mois)
# ✅ dataset159mandats_grp50 complété (204 mois)
# ✅ dataset159mandats_grp53 complété (144 mois)
# ✅ dataset159mandats_grp56 complété (204 mois)
# ✅ dataset159mandats_grp64 complété (129 mois)
# ✅ dataset159mandats_grp67 complété (204 mois)
# ✅ dataset159mandats_grp72 complété (120 mois)
# ✅ dataset159mandats_grp75 complété (205 mois)
# ✅ dataset159mandats_grp76 complété (114 mois)
# ✅ dataset159mandats_grp79 complété (204 mois)
# ✅ dataset159mandats_grp80 complété (111 mois)
# ✅ dataset159mandats_grp83 complété (204 mois)
# ✅ dataset159mandats_grp85 complété (105 mois)
# ✅ dataset159mandats_grp86 complété (205 mois)
# ✅ dataset159mandats_grp89 complété (101 mois)
# ✅ dataset159mandats_grp98 complété (138 mois)
# ✅ dataset159mandats_grp100 complété (87 mois)
# ✅ dataset159mandats_grp101 complété (87 mois)
# ✅ dataset159mandats_grp107 complété (203 mois)
# ✅ dataset159mandats_grp108 complété (204 mois)
# ✅ dataset159mandats_grp114 complété (72 mois)
# ✅ dataset159mandats_grp118 complété (106 mois)
# ✅ dataset159mandats_grp120 complété (67 mois)
# ✅ dataset159mandats_grp128 complété (60 mois)
# ✅ dataset159mandats_grp153 complété (203 mois)
# ✅ dataset164simple_grp5 complété (204 mois)
# ✅ dataset164simple_grp13 complété (204 mois)
# ✅ dataset164simple_grp14 complété (156 mois)
# ✅ dataset164simple_grp29 complété (198 mois)
# ✅ dataset164simple_grp35 complété (183 mois)
# ✅ dataset164simple_grp38 complété (204 mois)
# ✅ dataset164simple_grp39 complété (113 mois)
# ✅ dataset164simple_grp43 complété (120 mois)
# ✅ dataset164simple_grp45 complété (175 mois)
# ✅ dataset164simple_grp47 complété (204 mois)
# ✅ dataset164simple_grp50 complété (204 mois)
# ✅ dataset164simple_grp53 complété (155 mois)
# ✅ dataset164simple_grp56 complété (204 mois)
# ✅ dataset164simple_grp61 complété (136 mois)
# ✅ dataset164simple_grp64 complété (147 mois)
# ✅ dataset164simple_grp67 complété (136 mois)
# ✅ dataset164simple_grp68 complété (131 mois)
# ✅ dataset164simple_grp72 complété (143 mois)
# ✅ dataset164simple_grp75 complété (204 mois)
# ✅ dataset164simple_grp76 complété (204 mois)
# ✅ dataset164simple_grp79 complété (204 mois)
# ✅ dataset164simple_grp83 complété (204 mois)
# ✅ dataset164simple_grp85 complété (171 mois)
# ✅ dataset164simple_grp86 complété (204 mois)
# ✅ dataset164simple_grp89 complété (154 mois)
# ✅ dataset164simple_grp96 complété (158 mois)
# ✅ dataset164simple_grp98 complété (115 mois)
# ✅ dataset164simple_grp100 complété (74 mois)
# ✅ dataset164simple_grp101 complété (115 mois)
# ✅ dataset164simple_grp108 complété (204 mois)
# ✅ dataset164simple_grp114 complété (85 mois)
# ✅ dataset164simple_grp118 complété (83 mois)
# ✅ dataset164simple_grp124 complété (80 mois)
# ✅ dataset164simple_grp133 complété (67 mois)
# ✅ dataset164simple_grp135 complété (50 mois)
# ✅ dataset164simple_grp153 complété (181 mois)
# ✅ dataset164simple_grp154 complété (170 mois)
# ✅ dataset164simple_grp172 complété (204 mois)
# ✅ dataset164demande_grp29 complété (146 mois)
# ✅ dataset164demande_grp38 complété (204 mois)
# ✅ dataset164demande_grp47 complété (153 mois)
# ✅ dataset164demande_grp50 complété (160 mois)
# ✅ dataset164demande_grp64 complété (74 mois)
# ✅ dataset164demande_grp76 complété (112 mois)
# ✅ dataset164demande_grp86 complété (52 mois)
# ✅ dataset164demande_grp108 complété (65 mois)
# ✅ dataset164demande_grp114 complété (71 mois)
# ✅ dataset164demande_grp133 complété (54 mois)
# ✅ dataset164exclusif_grp13 complété (204 mois)
# ✅ dataset164exclusif_grp14 complété (133 mois)
# ✅ dataset164exclusif_grp35 complété (179 mois)
# ✅ dataset164exclusif_grp38 complété (204 mois)
# ✅ dataset164exclusif_grp45 complété (170 mois)
# ✅ dataset164exclusif_grp47 complété (169 mois)
# ✅ dataset164exclusif_grp50 complété (204 mois)
# ✅ dataset164exclusif_grp56 complété (204 mois)
# ✅ dataset164exclusif_grp64 complété (136 mois)
# ✅ dataset164exclusif_grp68 complété (146 mois)
# ✅ dataset164exclusif_grp75 complété (204 mois)
# ✅ dataset164exclusif_grp76 complété (115 mois)
# ✅ dataset164exclusif_grp79 complété (204 mois)
# ✅ dataset164exclusif_grp86 complété (118 mois)
# ✅ dataset164exclusif_grp100 complété (71 mois)
# ✅ dataset164exclusif_grp101 complété (104 mois)
# ✅ dataset164exclusif_grp114 complété (82 mois)
# ✅ dataset164exclusif_grp118 complété (76 mois)
# ✅ dataset164exclusif_grp124 complété (68 mois)
# ✅ dataset164exclusif_grp128 complété (54 mois)
# ✅ dataset164exclusif_grp133 complété (71 mois)
# ✅ dataset164coexclusif_grp13 complété (204 mois)
# ✅ dataset164coexclusif_grp14 complété (144 mois)
# ✅ dataset164coexclusif_grp38 complété (204 mois)
# ✅ dataset164coexclusif_grp50 complété (204 mois)
# ✅ dataset164coexclusif_grp56 complété (204 mois)
# ✅ dataset164coexclusif_grp67 complété (123 mois)
# ✅ dataset164coexclusif_grp72 complété (126 mois)
# ✅ dataset164coexclusif_grp75 complété (202 mois)
# ✅ dataset164coexclusif_grp79 complété (204 mois)
# ✅ dataset164coexclusif_grp89 complété (106 mois)
# ✅ dataset164coexclusif_grp100 complété (70 mois)
# ✅ dataset164coexclusif_grp114 complété (73 mois)
# ✅ dataset164coexclusif_grp124 complété (39 mois)
# ✅ dataset164coexclusif_grp133 complété (79 mois)
# ✅ dataset164coexclusif_grp153 complété (179 mois)
# ✅ dataset164triexclusif_grp13 complété (204 mois)
# ✅ dataset164triexclusif_grp14 complété (142 mois)
# ✅ dataset164triexclusif_grp38 complété (189 mois)
# ✅ dataset164triexclusif_grp39 complété (107 mois)
# ✅ dataset164triexclusif_grp47 complété (131 mois)
# ✅ dataset164triexclusif_grp50 complété (204 mois)
# ✅ dataset164triexclusif_grp56 complété (204 mois)
# ✅ dataset164triexclusif_grp67 complété (124 mois)
# ✅ dataset164triexclusif_grp68 complété (136 mois)
# ✅ dataset164triexclusif_grp75 complété (124 mois)
# ✅ dataset164triexclusif_grp76 complété (114 mois)
# ✅ dataset164triexclusif_grp79 complété (204 mois)
# ✅ dataset164triexclusif_grp86 complété (127 mois)
# ✅ dataset164triexclusif_grp108 complété (70 mois)
# ✅ dataset164triexclusif_grp114 complété (84 mois)
# ✅ dataset164triexclusif_grp124 complété (51 mois)
# ✅ dataset164triexclusif_grp133 complété (70 mois)
# ✅ dataset164triexclusif_grp153 complété (197 mois)
# ✅ dataset164preferentiel_grp35 complété (182 mois)
# ✅ dataset164preferentiel_grp38 complété (177 mois)
# ✅ dataset164preferentiel_grp56 complété (204 mois)
# ✅ dataset164preferentiel_grp64 complété (126 mois)
# ✅ dataset164preferentiel_grp68 complété (87 mois)
# ✅ dataset164preferentiel_grp79 complété (76 mois)
# ✅ dataset164preferentiel_grp86 complété (120 mois)
# ✅ dataset164delegation_grp13 complété (204 mois)
# ✅ dataset164delegation_grp38 complété (201 mois)
# ✅ dataset164delegation_grp47 complété (181 mois)
# ✅ dataset164delegation_grp56 complété (131 mois)
# ✅ dataset164delegation_grp86 complété (128 mois)
# ✅ dataset164delegation_grp114 complété (79 mois)
# ✅ dataset164delegation_grp153 complété (204 mois)
# ✅ dataset164quadriexclusif_grp13 complété (204 mois)
# ✅ dataset164quadriexclusif_grp14 complété (61 mois)
# ✅ dataset164quadriexclusif_grp38 complété (181 mois)
# ✅ dataset164quadriexclusif_grp39 complété (106 mois)
# ✅ dataset164quadriexclusif_grp50 complété (154 mois)
# ✅ dataset164quadriexclusif_grp56 complété (204 mois)
# ✅ dataset164quadriexclusif_grp114 complété (49 mois)
# ✅ dataset164quadriexclusif_grp133 complété (61 mois)

# %%
# Pour ne faire tourner qu'à partir d'un certain dataset (remplacer alors dans la cellule suivante datasets_groupes par nouveau_dico)

start_key = 'dataset164triexclusif_grp76'
trouver = False
nouveau_dico = {}

for key in datasets_groupes.keys() :
    if key == start_key:
        trouver = True
    if trouver:
        nouveau_dico[key] = datasets_groupes[key]

print(nouveau_dico.keys())
print(len(nouveau_dico))
# Out:
# dict_keys(['dataset164triexclusif_grp76', 'dataset164triexclusif_grp79', 'dataset164triexclusif_grp86', 'dataset164triexclusif_grp108', 'dataset164triexclusif_grp114', 'dataset164triexclusif_grp124', 'dataset164triexclusif_grp133', 'dataset164triexclusif_grp153', 'dataset164preferentiel_grp35', 'dataset164preferentiel_grp38', 'dataset164preferentiel_grp56', 'dataset164preferentiel_grp64', 'dataset164preferentiel_grp68', 'dataset164preferentiel_grp79', 'dataset164preferentiel_grp86', 'dataset164delegation_grp13', 'dataset164delegation_grp38', 'dataset164delegation_grp47', 'dataset164delegation_grp56', 'dataset164delegation_grp86', 'dataset164delegation_grp114', 'dataset164delegation_grp153', 'dataset164quadriexclusif_grp13', 'dataset164quadriexclusif_grp14', 'dataset164quadriexclusif_grp38', 'dataset164quadriexclusif_grp39', 'dataset164quadriexclusif_grp50', 'dataset164quadriexclusif_grp56', 'dataset164quadriexclusif_grp114', 'dataset164quadriexclusif_grp133'])
# 30

# %%
keys = list(datasets_groupes.keys())
print(f"Index de départ : {keys.index(start_key)}")
print(f"Clés à partir de start_key : {keys[keys.index(start_key):]}")
print(f"Nombre attendu : {len(keys[keys.index(start_key):])}")
# Out:
# Index de départ : 659
# Clés à partir de start_key : ['dataset164triexclusif_grp76', 'dataset164triexclusif_grp79', 'dataset164triexclusif_grp86', 'dataset164triexclusif_grp108', 'dataset164triexclusif_grp114', 'dataset164triexclusif_grp124', 'dataset164triexclusif_grp133', 'dataset164triexclusif_grp153', 'dataset164preferentiel_grp35', 'dataset164preferentiel_grp38', 'dataset164preferentiel_grp56', 'dataset164preferentiel_grp64', 'dataset164preferentiel_grp68', 'dataset164preferentiel_grp79', 'dataset164preferentiel_grp86', 'dataset164delegation_grp13', 'dataset164delegation_grp38', 'dataset164delegation_grp47', 'dataset164delegation_grp56', 'dataset164delegation_grp86', 'dataset164delegation_grp114', 'dataset164delegation_grp153', 'dataset164quadriexclusif_grp13', 'dataset164quadriexclusif_grp14', 'dataset164quadriexclusif_grp38', 'dataset164quadriexclusif_grp39', 'dataset164quadriexclusif_grp50', 'dataset164quadriexclusif_grp56', 'dataset164quadriexclusif_grp114', 'dataset164quadriexclusif_grp133']
# Nombre attendu : 30

# %% [markdown]
# **A partir de là, on peut commencer l'analyse des séries temporelles**

# %% [markdown]
# Le modèle utilisé est Prophet, un modèle de prévisions de séries temporelles développé par deux ingénieurs de Facebook en 2017. Il se veut paramétrable par les non experts en statistiques pour que des prévisions puissent être générées par des personnes ayant avant tout une connaissance profonde du métier. On détaille ci-dessous l'essentiel pour bien comprendre les foncdements mathématiques à la base du fonctionnement de ce type de modèles. Les commentaires du code sont à usage davantage pratique.
#
# (une série temporelle = une suite de variables aléatoires $(y_t)_{t\in\mathbb{Z}}$ généralement non indépendantes)
#
# L'idée générale est la suivante : une série temporelle est constituée de quatre composantes principales, qui sont la tendance, la saisonnalité, les jours fériés, et les erreurs (les variations totalement imprévisibles de la série temporelle, qu'il est impossible de prédire). On peut ainsi écrire la valeur prise par la série temporelle à la période $t$ de la manière suivante : $$y(t)=g(t)+s(t)+h(t)+\varepsilon_t$$
# Avec $y(t)$ la valeur de la série temporelle en $t$, $g(t)$ la tendance de la série en $t$, $s(t)$ l'impact de l'éventuel jour férié ou de vacances, et enfin $\varepsilon_t$ le terme "idiosyncratique", c'est à dire l'erreur imprévisible.
#
# L'objectif de ce modèle n'est pas de prédire les valeurs futures de la série temporelle par une simple prolongation de la tendance détectée, comme on pourrait le faire avec une simple régression linéaire, mais d'atteindre un plus grand niveau de finesse. Ainsi, les fonctions $g$, $s$ et $h$ ne sont pas des fonctions affines, elles peuvent prendre n'importe quelle forme : une forme de cloche, une forme logarithmique, exponentielle, etc.
#
# Il est aussi possible de considérer une variante de ce modèle, avec la fonction $s$ en facteur de la fonction $g$ : $$y(t)=g(t)s(t)+h(t)+\varepsilon_t$$, ce qui permet de mieux coller à la série temporelle en cas d'amplification ou de contraction des variations saisonnières en fonction de la hauteur de la tendance (par exemple, un faible écart entre les valeurs des jours habituels et des jours fériés quand la valeur de la série est basse, et une différence plus importante quand la valeur de la série est haute. On parle dans ce cas d'hétéroscédasticité).
#
# On se donne ensuite $k$ un taux de croissance au départ de la série temporelle, ainsi qu'un ensemble $(s_i)_{i\in[[1,25]]}$ de 25 points également espacés (on peut choisir soi-même leur nombre et leur position) auxquels ce taux est susceptible de changer, et on note $\delta=(\delta_i)_{i\in[[1,25]]}$ la valeur de cet ajustement du taux en chacun des points $s_i$. Ainsi, au moment $t$, le taux de croissance de la série temporelle vaut : $$k+\sum_{j=1}^t\delta_j$$, c'est à dire la somme de toutes les variations qui ont été subies par la série jusque-là. Attention toutefois, ce n'est qu'un taux de croissance, et non la valeur de la tendance, qui elle fait intervenir ce taux de croissance dans une fonction plus complexe (par exemple $x\mapsto \frac{C}{1+e^{-k(x-m)}}$, appelée la fonction logistique, qui permet de modéliser la croissance d'une quantité dans un environnement qui limite à une certaine valeurl'expansion de la quantité observée), mais cette fonction peut tout aussi bien être l'identité ($f : x\mapsto x$).
#
# On a deux possibilités pour détecter les points de changement de tendance : soit on les connaît parce que on connaît les déterminants des variations de la série temporelle, et dans ce cas il suffit de les renseigner, soit on ne les connaît pas. Nous nous trouvons ici dans ce deuxième cas, car au vu du nombre de séries temporelles à analyser, on ne peut pas se permettre de manuellement saisir tous les points de changements de tendance éventuels, même si on connaissait tous les déterminants des variations de toutes les séries. Comment alors détecter les points de changement de tendance ? Pour rappel, au début de l'analyse de la tendance de la série, on s'est donné un ensemble $(s_i)_{i\in[[1,25]]}$ de points auxquels le taux de croissance est susceptible de changer. Prophet suppose a priori que la force des changements de taux de croissance suit une loi de Laplace : $$\forall \delta_j \in (\delta_i)_{i\in[[1,T]]}, \delta_j \sim L(0,\tau)$$
# (une loi de Laplace $L(0,\tau)$ est une distribution de probabilité en forme de toît de chapiteau plus pointu à mesure que $\tau$ est petit : la plupart des valeurs vont tomber très proches de $0$). Une fois cette hypothèse faite, Prophet tente de trouver la valeur la plus probable des changements de taux de croissance de la série (donc en ayant en tête que la plupart des changements seront proches de $0$). Les valeurs étant trop proches de $0$ sont ensuite ramenées à exactement $0$, pour simplifier le modèle. Il ne reste alors comme vrai points de changement du taux de croissance que les points auxquels on a estimé une force du changement suffisamment élevée !
#
# La quantité de points à garder est paramétrable. En effet, la variable changepoint_prior_scale est le $\tau$ : plus on le choisit élevé, plus le modèle aura tendance à garder les $s_i$ auxquels la valeur du changement de taux de croissance $\delta_i$ est "fort mais sans plus" comme un vrai point de changement de tendance. On obtient alors un modèle qui collera mieux aux données en s'adaptant plus vite et plus souvent aux changements de tendance, mais qui présentera le risque d'apprendre les chocs ponctuels et imprévisibles comme une réelle variation de tendance, ce qui n'est pas souhaitable ! (tenter de reproduire des variations imprévisibles mène à plus d'erreur).
#
# Comment Prophet prédit-il ensuite les points de changement de tedance pour les valeurs futures de la série ? On part d'un a priori simple : la fréquence d'apparition des changements de tendance dans le futur sera la même que dans le passé. S'il y a eu $S$ points auxquels la tendance a changé sur $T$ valeurs observées au total, on considèrera que dans le futur, la probabilité qu'un point soit un point de changement de tendance sera de $\frac{S}{T}$, et inversement, la probabilité que ce point ne soit pas un point de changement de tendance sera de $\frac{T-S}{T}$. Dans le cas où un changement de tendnace a lieu en un point, la force du changement du taux de croissance suivra la même loi de Laplace que précédemment. Mathématiquement, on pet écrire : $$\left\{
# \begin{array}{ll}
# \mathbb{P}([\delta_j=0])=\frac{T-S}{T} &  \\
# \mathbb{P}([\delta_j \sim L(0,\hat{\tau})])=\frac{S}{T}
# \end{array}
# \right. $$
# Avec $\hat{\tau}=\frac{1}{S}\sum_{j=1}^S|\delta_j|$ la valeur estimée de $\tau$.
#
# Pour estimer la tracjectoire future que suivra la série temporelle, on modélise plusieurs trajectoires possibles avec la méthode exposée ci-dessus, puis on conserve comme meilleure prédiction pour la date $t$ la médiane des valeurs prédites pour cette date. Pour les bornes inférieures et supérieures des intervalles de confiance, on conserve les quantiles d'ordre respectivement $10\%$ et $90\%$ des différentes valeurs générées.
#
# L'estimation de la force des effets de saisonnalité pour les dates futures se fait à l'aide de séries de Fourier tronquées (on ne somme pas jusqu'à l'infini). On peut donc écrire de la manière suivante la fonction $s$ de saisonnalité :
# $$s(t)=\sum_{n=1}^N\left( a_ncos\left(\frac{2\pi nt}{P}\right) +b_nsin\left(\frac{2\pi nt}{P}\right)\right)$$
# Avec $P$ la période saisonnalité (par exemple $12$ si les données sont mensuelles et la saisonnalité annuelle), $t$ la date, et $N$ le numéro du terme auquel on tronque la série de Fourier. Plus $N$ est grand, plus on pourra capturer des effets de saisonnalité complexes. Par contre, un $N$ trop grand risque d'overfit les données, en interprétant comme de la saisonnalité un simple bruit. La sélection du $N$ optimal se fait automatiquement par Prophet grâce à un critère choisissant le meilleur compromis entre précision  du modèle pour expliquer les données, et simplicité. Les $(a_n)$ et $(b_n)$ sont ensuite choisis de la même manière que les $(\delta_i)$ pour la tendance : on se fixe une hypothèse sur la distribution de leurs valeurs, puis on estime la véritable valeur, et enfin on ne garde que les coefficients significativement différents de $0$.
#
# La fonction $h$ qui représente l'impact des vacances et des jours fériés sur la série temporelle est estimée de la même manière que la saisonnalité.
#
# Pour évaluer la performance du modèle sélectionné (c'est à dire la qualité de l'ensemble des paramètres choisis), on évalue la différence entre valeur prédite et valeur réellement observée si le modèle avait à prédire une valeur "future" que l'on a en fait déjà observée. On définit la précision empirique comme suit :
# $$\phi(T,h)=d\left(\hat{y}_{T+h|T}, y_{T+h}\right)$$
# Avec $d$ une distance (par exemple $d : x,y \mapsto |x-y|$, ou $d : x,y\mapsto (x-y)^2$) (c'est de laracine de la moyenne des valeurs prises par cette deuxième fonction dont on parle quand il s'agit de calculer la RMSE ("rooted mean square error") du modèle), $\hat{y}_{T+h|T}$ la prévision que le modèle fait pour la date $T+h$ en ne disposant que des données jusqu'en $T$, et $y_{T+h}$ la véritable valeur à la date $T+h$. Ce que l'on cherche à estimer est la famille de fonctions suivante :
# $$\zeta_T(h)=\mathbb{E}[\phi(T,h)]$$
# On l'estime par régression isotone (c'est à dire que l'on force cette fonction à être croissante, de manière assez logique, car l'erreur de prévision augmente à mesure que l'on essaye de prévoir à un horizon temporel éloigné).
#
# Pour plus d'informations sur le fonctionnement de Prophet, consulter https://peerj.com/preprints/3190/. L'essentiel des informations contenues dans cet article des ingénieurs de Facebook ayant construit ce modèle ont été retranscrites ici.
#
# Remarque : le modèle étant stochastique, les résultats ne sont pas toujours les mêmes ! Pour les séries avec beaucoup de points, d'une fois sur l'autre ils se ressembleront beaucoup, mais pour les séries que l'on devra raccourcir pour obtenir une meilleure performance, les résultats présenteront une forte variabilité d'une exécution du programme à l'autre.

# %%
moins_de_100 = sum(len(df) < 100 for df in datasets_groupes.values())
total_series = len(datasets_groupes)

print(f"La proportion de séries qui ont moins de 100 points est de {(moins_de_100 / total_series) * 100:.2f}%")
# Out:
# La proportion de séries qui ont moins de 100 points est de 23.37%

# %%
print(nouveau_dico.keys()) # Prour regarder le nom de la derniere serie et verifier que tout a bien ete fait
# Out:
# dict_keys(['dataset164triexclusif_grp76', 'dataset164triexclusif_grp79', 'dataset164triexclusif_grp86', 'dataset164triexclusif_grp108', 'dataset164triexclusif_grp114', 'dataset164triexclusif_grp124', 'dataset164triexclusif_grp133', 'dataset164triexclusif_grp153', 'dataset164preferentiel_grp35', 'dataset164preferentiel_grp38', 'dataset164preferentiel_grp56', 'dataset164preferentiel_grp64', 'dataset164preferentiel_grp68', 'dataset164preferentiel_grp79', 'dataset164preferentiel_grp86', 'dataset164delegation_grp13', 'dataset164delegation_grp38', 'dataset164delegation_grp47', 'dataset164delegation_grp56', 'dataset164delegation_grp86', 'dataset164delegation_grp114', 'dataset164delegation_grp153', 'dataset164quadriexclusif_grp13', 'dataset164quadriexclusif_grp14', 'dataset164quadriexclusif_grp38', 'dataset164quadriexclusif_grp39', 'dataset164quadriexclusif_grp50', 'dataset164quadriexclusif_grp56', 'dataset164quadriexclusif_grp114', 'dataset164quadriexclusif_grp133'])

# %%
liste_noms = list(datasets_groupes.keys())

for nom in liste_noms :
    if nom in nouveau_dico.keys() :
        nouveau_dico[nom] = nouveau_dico[nom].rename(columns={'date' : 'ds', 'valeur' : 'y'})
    datasets_groupes[nom] = datasets_groupes[nom].rename(columns={'date' : 'ds', 'valeur' : 'y'})
    if nom in globals():
        globals()[nom] = datasets_groupes[nom]
    print(f"{nom} : {datasets_groupes[nom].columns}")
# Out:
# dataset146visite_grp29 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset146visite_grp35 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset146visite_grp38 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset146visite_grp47 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset146visite_grp50 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset146visite_grp56 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset146visite_grp67 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset146visite_grp68 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset146visite_grp75 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset146visite_grp76 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset146visite_grp79 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset146visite_grp83 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset146visite_grp86 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset146visite_grp100 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset146visite_grp107 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset146visite_grp108 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset146visite_grp118 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset146visite_grp133 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset146visite_grp153 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset146rdv_grp13 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset146rdv_grp35 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset146rdv_grp83 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset146rdv_grp118 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset146rdv_grp133 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset146rdv_grp153 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset147_grp13 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset147_grp14 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset147_grp35 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset147_grp38 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset147_grp39 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset147_grp50 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset147_grp133 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset147_grp153 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset148_grp7 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset148_grp13 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset148_grp14 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset148_grp35 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset148_grp38 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset148_grp43 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset148_grp47 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset148_grp50 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset148_grp54 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset148_grp56 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset148_grp64 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset148_grp67 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset148_grp72 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset148_grp75 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset148_grp76 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset148_grp79 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset148_grp80 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset148_grp83 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset148_grp85 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset148_grp86 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset148_grp89 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset148_grp100 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset148_grp101 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset148_grp107 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset148_grp109 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset148_grp114 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset148_grp118 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset148_grp128 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset148_grp138 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset148_grp153 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset148_grp172 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset149_grp7 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset149_grp13 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset149_grp14 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset149_grp29 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset149_grp35 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset149_grp38 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset149_grp43 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset149_grp47 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset149_grp50 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset149_grp56 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset149_grp60 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# data
: Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset164quadriexclusif_grp114 : Index(['ds', 'groupe_id', 'y'], dtype='object')
# dataset164quadriexclusif_grp133 : Index(['ds', 'groupe_id', 'y'], dtype='object')

# %%
# On initialise un dataframe de statistiques descriptives sur les séries avant de faire les prévisions.
# On va essayer de les clusteriser là-dessus, en ajoutant d'autres indicateurs qui leur sont propre (variance, etc.)
# On commence par boucler sur les séries pour leur ajouter leur variance dans le tableau

series_temp_features = []

for nom, df in datasets_groupes.items():
    match = re.search(r'grp(\d+)', nom)
    groupe_id = int(match.group(1)) if match else None
    longueur_serie = df.shape[0]
    
    y = df['y'].dropna().reset_index(drop=True)
    moyenne = y.mean()
    std = y.std()
    std_normalise = std / moyenne if moyenne != 0 else None

    # Découper la série en 2 moitiés
    n = len(y)
    mid = n // 2
    y_first = y.iloc[:mid]
    y_second = y.iloc[mid:]
    
    moyenne1 = y_first.mean()
    moyenne2 = y_second.mean()
    
    std1 = y_first.std() / moyenne1 if moyenne1 != 0 else None
    std2 = y_second.std() / moyenne2 if moyenne2 != 0 else None

    # Moyennes locales pour le ratio début / fin
    moyenne_debut = y.iloc[:6].mean() if len(y) >= 6 else None
    moyenne_fin = y.iloc[-9:-3].mean() if len(y) >= 9 else None
    ratio_debut_fin = moyenne_debut / moyenne_fin if moyenne_fin and moyenne_fin != 0 else None

    # Assymétrie et aplatissement (skewness et kurtosis)
    skewness_val = skew(y) if len(y) >= 3 else None
    kurtosis_val = kurtosis(y) if len(y) >= 4 else None  # sinon division par zéro potentielle

    # Test de stationnarité ADF
    try:
        adf_result = adfuller(y.dropna())
        adf_pvalue = adf_result[1]  # p-value
    except Exception:
        adf_pvalue = None

    # On calcule les composantes de Fourier
    fft_vals = fft(y - y.mean())  # centrer la série avant fft
    fft_freqs = np.fft.fftfreq(len(y))
    positive_freq_idxs = np.where(fft_freqs > 0)

    if len(positive_freq_idxs[0]) > 0:
        dominant_idx = positive_freq_idxs[0][np.argmax(np.abs(fft_vals[positive_freq_idxs]))]
        dominant_freq = fft_freqs[dominant_idx]
        dominant_amp = np.abs(fft_vals[dominant_idx])
        dominant_phase = np.angle(fft_vals[dominant_idx])
    else:
        dominant_freq = None
        dominant_amp = None
        dominant_phase = None

    # On crée un histogramme normalisé des valeurs (ex: 10 bins)
    hist, bin_edges = np.histogram(y, bins=10, density=True)
    hist = hist + 1e-12  # éviter log(0)
    shannon_entropy = entropy(hist)

    series_temp_features.append({
        'nom_serie': nom,
        'groupe_id': groupe_id,
        'longueur_serie': longueur_serie,
        'mean_abs_diff' : np.mean(np.abs(np.diff(y))),
        'std_normalise': std_normalise,
        'std_normalise_first_half': std1,
        'std_normalise_second_half': std2,
        'std_normalise_ecart': abs(std1 - std2) if std1 is not None and std2 is not None else None,
        'moyenne1': moyenne1,
        'moyenne2': moyenne2,
        'ecart_moyennes_normalise': abs(moyenne1 - moyenne2)/moyenne if moyenne1 is not None and moyenne2 is not None and moyenne != 0 else None,
        'skewness': skewness_val,
        'kurtosis': kurtosis_val,
        'moyenne_debut': moyenne_debut,
        'moyenne_fin': moyenne_fin,
        'ratio_debut_fin': ratio_debut_fin,
        'ecart_interquantile' : y.quantile(0.75) - y.quantile(0.25),
        'autocorr' : y.autocorr(lag=1),
        'autocorrelation_saisonniere' : y.autocorr(lag=12) if len(y) >= 24 else None,
        'turning_points' : np.sum(np.diff(np.sign(np.diff(y))) != 0)/len(y),
        'mediane' : y.median(),
        'tendance' : linregress(range(len(y)), y).slope,
        'adf_pvalue': adf_pvalue,
        'fft_dominant_freq': dominant_freq,
        'fft_dominant_amp': dominant_amp,
        'fft_dominant_phase': dominant_phase,
        'shannon_entropy': shannon_entropy
    })

# Convertir en DataFrame
series_temp_features = pd.DataFrame(series_temp_features)

print(series_temp_features)
# Out:
#                            nom_serie  groupe_id  longueur_serie  \
# 0             dataset146visite_grp29         29             188
# 1             dataset146visite_grp35         35             181
# 2             dataset146visite_grp38         38             204
# 3             dataset146visite_grp47         47             152
# 4             dataset146visite_grp50         50             156
# ..                               ...        ...             ...
# 684   dataset164quadriexclusif_grp39         39             106
# 685   dataset164quadriexclusif_grp50         50             154
# 686   dataset164quadriexclusif_grp56         56             204
# 687  dataset164quadriexclusif_grp114        114              49
# 688  dataset164quadriexclusif_grp133        133              61
#
#      mean_abs_diff  std_normalise  std_normalise_first_half  \
# 0         4.000000       0.703946                  0.766521
# 1        10.083333       0.543934                  0.634311
# 2        83.133005       0.645064                  1.022729
# 3         5.940397       0.605898                  0.679773
# 4        15.670968       0.667443                  0.417841
# ..             ...            ...                       ...
# 684       0.190476       0.404755                  0.496835
# 685       0.241830       0.465195                  0.384907
# 686       0.310345       0.472021                  0.543903
# 687       0.145833       0.443155                  0.353861
# 688       0.283333       0.511120                  0.558619
#
#      std_normalise_second_half  std_normalise_ecart    moyenne1    moyenne2  \
# 0                     0.580183             0.186338    9.712766    8.058511
# 1                     0.456052             0.178259   23.944444   28.148352
# 2                     0.287664             0.735065  209.691176  418.960784
# 3                     0.535558             0.144215   10.006579   11.855263
# 4                     0.575614             0.157773   64.102564   23.730769
# ..                         ...                  ...         ...         ...
# 684                   0.297949             0.198886    2.113208    2.188679
# 685                   0.393208             0.008300    3.987013    2.435065
# 686                   0.252599             0.291303    3.137255    6.000000
# 687                   0.494309             0.140448    1.250000    1.440000
# 688                   0.312602             0.246016    1.466667    2.903226
#
#      ...  autocorr  autocorrelation_saisonniere  turning_points  mediane  \
# 0    ...  0.611852                     0.339815        0.622340      7.5
# 1    ...  0.585736                     0.260423        0.613260     24.0
# 2    ...  0.836555                     0.739422        0.568627    363.5
# 3    ...  0.346892                     0.281021        0.657895     10.0
# 4    ...  0.731378                     0.696385        0.576923     40.5
# ..   ...       ...                          ...             ...      ...
# 684  ...  0.833861                    -0.332453        0.292453      2.0
# 685  ...  0.925360                     0.350789        0.350649      3.0
# 686  ...  0.958036                     0.541014        0.406863      5.0
# 687  ...  0.733159                    -0.264073        0.244898      1.0
# 688  ...  0.859947                     0.461760        0.409836      2.0
#
#      tendance  adf_pvalue  fft_dominant_freq  fft_dominant_amp  \
# 0    0.005587    0.000029           0.010638        378.752349
# 1    0.059253    0.021671           0.005525        997.505443
# 2    2.087990    0.421944           0.004902      19016.923836
# 3    0.029091    0.094122           0.006579        329.694819
# 4   -0.404414    0.851648           0.006410       2463.006165
# ..        ...         ...                ...               ...
# 684 -0.003305    0.030091           0.018868         29.024393
# 685 -0.011092    0.096148           0.006494        105.092735
# 686  0.027272    0.190249           0.004902        160.978158
# 687  0.013776    0.099564           0.020408          9.753816
# 688  0.047964    0.194967           0.016393         36.775273
#
#      fft_dominant_phase  shannon_entropy
# 0              1.771944         1.838656
# 1              2.776892         1.966724
# 2              2.134162         2.166942
# 3              3.121939         1.884520
# 4             -1.881775         1.994511
# ..                  ...              ...
# 684           -2.182951         1.228306
# 685           -1.732228         1.671197
# 686            1.807904         1.941439
# 687            0.129560         0.746721
# 688            1.714787         1.382843
#
# [689 rows x 27 columns]

# %%
comptage_noms = Counter(datasets_groupes.keys())
doublons_groupes = {k: v for k, v in comptage_noms.items() if v > 1}
print(doublons_groupes) # Juste pour voir si on n'aurait pas des datasets en double
# Out:
# {}

# %%
# Première méthode : on fait une boucle qui permettra d'analyser une série temporelle du début à la fin automatiquement
# Compter deux heures d'exécution

# Les valeurs des parametres qu'on va balayer :
prior_scale_possibles = [0.01, 0.03, 0.05] # Pour contrôler la vitesse d'adaptation du modèle aux changements de tendance
saisonnalite_oui_non_possibles = [True, False] # Soit on dit qu'il y a de la saisonnalité et on la recherche, soit on dit qu'il n'y en a pas et donc on ne la recherche pas
modes_possibles = ['multiplicative', 'additive'] # multiplicative : la saisonnalité sera modélisée comme la valeur prédite par la tendance fois un certain coeff, et pour additive, ce sera un + qqch
niveau_surajustement = 0.15
taille_minimale = 36
max_essais = 3

# Ce qui va évoluer au cours de la boucle
dico_des_methodes = {cle : None for cle in datasets_groupes.keys()}
dico_des_rmsse = {cle : None for cle in datasets_groupes.keys()}
i = 0 # On initialise un compteur du nombre de séries temporelles qui vont utiliser un mcmc sampling
j = 0 # On initialise un compteur de la somme de toutes les rmsse de toutes les séries temporelles
l = 0 # On initialise un compteur du nombre de séries qui ont pu être traitées
k = 0 # On initialise un compteur de prévisions aberrantes qu'on décidera de ne pas enregistrer et ne pas montrer

# On va stocker là-dedans les prévisions : valeur prédite, borne inférieure de l'intervalle de confiance (95%), borne sup
# de l'intervalle de confiance, l'identifiant du groupe auquel se réfère la prédiction, et enfin la date pour laquelle 
# ces valeurs sont valables
resultats_previsions = []

print(f'{len(datasets_groupes)} datasets encore en lice')
# Out:
# 689 datasets encore en lice

# %%
with warnings.catch_warnings() :
    warnings.simplefilter("ignore")

    for nom, df_prophet in datasets_groupes.items() :
        # Extraire le groupe_id depuis le nom si possible
        match = re.search(r'grp(\d+)', nom)
        niveau_raccourcissement = None
        nb_essais = 0

        try : 
            recommencer = True

            while recommencer == True and nb_essais < max_essais :
                nb_essais += 1
                prediction_constante = False
                recommencer = False  # par défaut, on ne recommence pas
                forecast = None  # Réinitialiser à chaque itération
                forecast_12 = None
                rmsse_actualisee = None
                id = None # Pour identifier ce qu'il s'est passé dans la boucle
                surajustement = False
                params_et_resultats = [] # On stockera dedans les caractéristiques de chaque modèle testé

                # On ajuste le paramètre de sensibilité de l'adaptation de la tendance détectée aux chocs brutaux
                for prior_scale_param in prior_scale_possibles :
                    # Normalement si on met True et qu'il s'avere qu'il n'y a pas de saisonnalité, le modèle apprendra
                    # que ca ne sert à rien de la prendre en compte et donc mettra les coeffs des composantes saisonnières
                    # à 0. Mais on risque d'interpréter le bruit comme de la saisonnalité, donc autant tester la rmse 
                    # dans les deux cas

                    for saisonnalite_oui_non in saisonnalite_oui_non_possibles :
                        # Multiplicative : la saisonnalité est proportionnellement forte avec la tendance
                        # Additive : la saisonnalité a toujours la même force. 
                        # On peut être dans les deux cas donc on teste les deux

                        for mode in modes_possibles :
                            model = Prophet(seasonality_mode=mode,
                            weekly_seasonality=False,
                            daily_seasonality=False,
                            yearly_seasonality=saisonnalite_oui_non,
                            changepoint_prior_scale=prior_scale_param,
                            n_changepoints=int(np.floor(df_prophet.shape[0]/3)))

                            try :
                                with contextlib.redirect_stdout(io.StringIO()), contextlib.redirect_stderr(io.StringIO()):
                                    model.fit(df_prophet)
                            except Exception as e :
                                print(f"Erreur pendant le fit sur {nom} : {e}")
                                continue  # passe à la série suivante

                            # Vérifications
                            if not hasattr(model, "stan_fit") or model.stan_fit is None :
                                print(f"Erreur : model.stan_fit est None pour {nom}")
                                continue
                            if not hasattr(model.stan_fit, "runset") or model.stan_fit.runset is None :
                                print(f"Erreur : model.stan_fit.runset est None pour {nom}")
                                continue

                            # C'est la validation croisée qui prend beaucoup de temps. 
                            # Pour raccourcir le temps d'exécution : 
                            # initial donne la durée du premier intervalle sur lequel on entraîne le modèle.
                            # Plus il est long, moins on aura de validations croisées à faire
                            # period donne le nombre de jours qu'on va ajouter aux données d'entraînement pour la prochaine validation
                            # Plus on en ajoute, moins on fera de validation (donc plus ce sera rapide)
                            # On ne touche pas à horizon, c'est le nombre de mois qu'on prédit, et comme on est sur des données
                            # mensuelles, on prédit sur les douze mois qui viennent

                            nb_mois = len(df_prophet)
                            jours_total = int(nb_mois * 30.44)
                            param_initial = f'{int(jours_total * 0.75)} days'
                            param_period = f'{int(jours_total * 0.20)} days'
                            param_horizon = f'{int(jours_total * 0.05)} days'  # 5% du total

                            df_cv = cross_validation(
                                model,
                                initial=param_initial,
                                period=param_period,
                                horizon=param_horizon,
                                disable_tqdm=True)

                            rmse_provisoire = performance_metrics(df_cv)['rmse'].mean()
                            params_et_resultats.append([prior_scale_param, saisonnalite_oui_non, mode, rmse_provisoire])

                params_et_resultats = np.array(params_et_resultats, dtype=object)
                colonne_rmse = params_et_resultats[:, -1].astype(float)
                meilleur_indice_rmse = np.argmin(colonne_rmse)
                meilleurs_parametres = params_et_resultats[meilleur_indice_rmse]
                use_mcmc = meilleurs_parametres[1] is True

                model_prophet = Prophet(
                    seasonality_mode=meilleurs_parametres[2],
                    weekly_seasonality=False,
                    daily_seasonality=False,
                    yearly_seasonality=meilleurs_parametres[1],
                    n_changepoints=int(np.floor(df_prophet.shape[0]/3)),
                    changepoint_prior_scale = meilleurs_parametres[0],
                    **({'mcmc_samples': 150} if use_mcmc else {}),
                    uncertainty_samples=1000)

                with contextlib.redirect_stdout(io.StringIO()), contextlib.redirect_stderr(io.StringIO()) :
                    if use_mcmc :
                        try :
                            model_prophet.fit(df_prophet, show_progress=False)
                        except Exception :
                            pass  # ignore errors silently, optionally log internally
                    else :
                        try :
                            model_prophet.fit(df_prophet)
                        except Exception :
                            pass
                
                # On est obligé de refaire une validation croisée pcq sinon df_cv donne les resultats de la derniere qui a 
                # été faite, et non ceux de la meilleure

                nb_mois = len(df_prophet)
                jours_total = int(nb_mois * 30.44)
                param_initial = f'{int(jours_total * 0.75)} days'
                param_period = f'{int(jours_total * 0.20)} days'
                param_horizon = f'{int(jours_total * 0.05)} days'  # 5% du total

                df_cv = cross_validation(
                    model,
                    initial=param_initial,
                    period=param_period,
                    horizon=param_horizon,
                    disable_tqdm=True)

                # Calcul de la RMSSE (rmse normalisée pour être comparable sur des séries d'échelle très diverses)
                y_test = df_cv['y'].values
                y_pred = df_cv['yhat'].values
                y_train = df_prophet['y'].values
                denom = np.sqrt(np.sum(np.diff(y_train) ** 2) / (len(y_train) - 1))
                rmsse = meilleurs_parametres[3] / denom

                # On a maintenant le meilleur modèle sur la série brute. 
                # Il y a maintenant 4 cas de figure : 
                # Soit les résultats sont satisfaisants et on les garde
                # Soit les résultats sont mauvais et la série fait plus de 96 points : on rétrécit à 60
                # Soit les résultats sont mauvais et la série fait entre 36 et 96 points : on rétrécit à 36
                # Soit la série fait 36 points et les résultats sont toujours mauvais : on tente de surajuster

                # 1er cas : les résultats sont satisfaisants 
                if rmsse < 1 :
                    rmsse_finale = rmsse

                    # Prédiction Prophet sur 12 mois
                    future = model_prophet.make_future_dataframe(periods=12, freq='MS')
                    forecast = model_prophet.predict(future)

                    forecast[['yhat', 'yhat_lower', 'yhat_upper']] = forecast[['yhat', 'yhat_lower', 'yhat_upper']].clip(lower=0)
                    forecast_12 = forecast.tail(12).copy()
                    forecast_12[['yhat', 'yhat_lower', 'yhat_upper']] = forecast_12[['yhat', 'yhat_lower', 'yhat_upper']].clip(lower=0)
                    forecast_12['dataset_nom'] = nom
                    forecast_12['groupe_id'] = int(match.group(1)) if match else None
                    forecast_12 = forecast_12[['ds', 'yhat', 'yhat_lower', 'yhat_upper', 'dataset_nom', 'groupe_id']]

                # 2e cas : les résultats ne sont pas satisfaisants et la série fait plus de 96 points
                if rmsse > 1 and df_prophet.shape[0] > 96 :
                    recommencer = True
                    df_prophet=df_prophet.tail(60)
                    niveau_raccourcissement = '60'
                    continue # On repart du début de la boucle while avec la série raccourcie

                # 3e cas : les résultats ne sont pas satisfaisants et la série fait entre 36 et 96 points
                if rmsse > 1 and 36 < df_prophet.shape[0] <= 96 :
                    recommencer = True
                    df_prophet = df_prophet.tail(36)
                    niveau_raccourcissement = '36'
                    continue # On repart du début de la boucle while avec une série raccourcie

                # 4e et dernier cas : la série fait déjà 36 points mais les résultats ne sont toujours pas satisfaisants
                if rmsse > 1 and df_prophet.shape[0] == 36 :
                    
                    # On surajuste et on voit ce qui se passe
                    # Gros bloc ici parce qu'on refait tout, mais juste sans passer par le balayage des valeur possibles de changepoints_prior_scale
                    surajustement = True
                    params_et_resultats = []

                    # On reparcourt les différents paramètres de saisonnalité possibles
                    for saisonnalite_oui_non in saisonnalite_oui_non_possibles :

                        for mode in modes_possibles :
                            # Ici on recalcule le modèle avec surajustement 
                            model = Prophet(seasonality_mode=mode,
                                weekly_seasonality=False,
                                daily_seasonality=False,
                                yearly_seasonality=saisonnalite_oui_non,
                                changepoint_prior_scale=niveau_surajustement,
                                n_changepoints=int(np.floor(df_prophet.shape[0]/3)))

                            # On refit le modele
                            try :
                                with contextlib.redirect_stdout(io.StringIO()), contextlib.redirect_stderr(io.StringIO()) :
                                    model.fit(df_prophet)
                            except Exception as e :
                                print(f"Erreur pendant le fit sur {nom} : {e}")
                                continue  # passe à la série suivante

                            # Vérifications
                            if not hasattr(model, "stan_fit") or model.stan_fit is None :
                                print(f"Erreur : model.stan_fit est None pour {nom}")
                                continue
                            if not hasattr(model.stan_fit, "runset") or model.stan_fit.runset is None :
                                print(f"Erreur : model.stan_fit.runset est None pour {nom}")
                                continue

                            nb_mois = len(df_prophet)
                            jours_total = int(nb_mois * 30.44)
                            param_initial = f'{int(jours_total * 0.75)} days'
                            param_period = f'{int(jours_total * 0.20)} days'
                            param_horizon = f'{int(jours_total * 0.05)} days'  # 5% du total

                            df_cv = cross_validation(
                                model,
                                initial=param_initial,
                                period=param_period,
                                horizon=param_horizon,
                                disable_tqdm=True)

                            rmse_provisoire = performance_metrics(df_cv)['rmse'].mean()
                            params_et_resultats.append([niveau_surajustement, saisonnalite_oui_non, mode, rmse_provisoire])

                    params_et_resultats = np.array(params_et_resultats, dtype=object)
                    colonne_rmse = params_et_resultats[:, -1].astype(float)
                    meilleur_indice_rmse = np.argmin(colonne_rmse)
                    meilleurs_parametres = params_et_resultats[meilleur_indice_rmse]
                    use_mcmc = meilleurs_parametres[1] is True

                    model_prophet = Prophet(
                        seasonality_mode=meilleurs_parametres[2],
                        weekly_seasonality=False,
                        daily_seasonality=False,
                        yearly_seasonality=meilleurs_parametres[1],
                        n_changepoints=int(np.floor(df_prophet.shape[0]/3)),
                        changepoint_prior_scale = meilleurs_parametres[0],
                        **({'mcmc_samples': 150} if use_mcmc else {}),
                        uncertainty_samples=1000)

                    with contextlib.redirect_stdout(io.StringIO()), contextlib.redirect_stderr(io.StringIO()) :
                        if use_mcmc :
                            try :
                                model_prophet.fit(df_prophet, show_progress=False)
                            except Exception :
                                pass  # ignore errors silently, optionally log internally
                        else :
                            try :
                                model_prophet.fit(df_prophet)
                            except Exception :
                                pass
                    
                    # On est obligé de refaire une validation croisée pcq sinon df_cv donne les resultats de la derniere qui a 
                    # été faite, et non ceux de la meilleure

                    nb_mois = len(df_prophet)
                    jours_total = int(nb_mois * 30.44)
                    param_initial = f'{int(jours_total * 0.75)} days'
                    param_period = f'{int(jours_total * 0.20)} days'
                    param_horizon = f'{int(jours_total * 0.05)} days'  # 5% du total

                    df_cv = cross_validation(
                        model,
                        initial=param_initial,
                        period=param_period,
                        horizon=param_horizon,
                        disable_tqdm=True)

                    # Calcul de la RMSSE (rmse normalisée pour être comparable sur des séries d'échelle très diverses)
                    y_test = df_cv['y'].values
                    y_pred = df_cv['yhat'].values
                    y_train = df_prophet['y'].values
                    denom = np.sqrt(np.sum(np.diff(y_train) ** 2) / (len(y_train) - 1))
                    rmsse = meilleurs_parametres[3] / denom

                    # On a maintenant récupéré la rmsse du meilleur modèle surajusté pour la série raccourcie au maximum. 
                    # On a deux possibilités : soit c'est enfin bon (rmsse < 1), soit on abandonne et on fait une prévision constante

                    # 1er cas : ça marche enfin
                    if rmsse < 1 : 
                        surajustement = True
                        rmsse_finale = rmsse
                        niveau_raccourcissement = '36'

                        # Prédiction Prophet sur 12 mois
                        future = model_prophet.make_future_dataframe(periods=12, freq='MS')
                        forecast = model_prophet.predict(future)

                        forecast[['yhat', 'yhat_lower', 'yhat_upper']] = forecast[['yhat', 'yhat_lower', 'yhat_upper']].clip(lower=0)
                        forecast_12 = forecast.tail(12).copy()
                        forecast_12[['yhat', 'yhat_lower', 'yhat_upper']] = forecast_12[['yhat', 'yhat_lower', 'yhat_upper']].clip(lower=0)
                        forecast_12['dataset_nom'] = nom
                        forecast_12['groupe_id'] = int(match.group(1)) if match else None
                        forecast_12 = forecast_12[['ds', 'yhat', 'yhat_lower', 'yhat_upper', 'dataset_nom', 'groupe_id']]

                    # 2e cas : ça ne marche toujours pas : prévision constante
                    if rmsse > 1 :
                        surajustement = False
                        niveau_raccourcssement = '36'
                        use_mcmc = False
                        rmsse_finale = 1

                        valeur_constante = df_prophet['y'].tail(12).mean()
                        future_dates = pd.date_range(start=df_prophet['ds'].max() + pd.DateOffset(months=1), periods=12, freq='MS')

                        forecast_12 = pd.DataFrame({
                            'ds': future_dates,
                            'yhat': [valeur_constante] * 12,
                            'yhat_lower': [valeur_constante] * 12,
                            'yhat_upper': [valeur_constante] * 12,
                            'dataset_nom': nom,
                            'groupe_id': int(match.group(1)) if match else None
                        })

                        future = model_prophet.make_future_dataframe(periods=12, freq='MS')
                        forecast = pd.DataFrame({
                            'ds': future['ds'],
                            'yhat': list(df_prophet['y']) + [valeur_constante] * 12,
                            'yhat_lower': list(df_prophet['y']) + [valeur_constante] * 12,
                            'yhat_upper': list(df_prophet['y']) + [valeur_constante] * 12
                        })

                        prediction_constante = True

            dico_des_rmsse[nom] = rmsse_finale
            
            if nb_essais == 1 and rmsse_finale < 1 :
                id = 'succes_immediat'
            if nb_essais == 2 and df_prophet.shape[0] == 60 and rmsse_finale < 1 :
                id = 'serie_raccourcie_60'
            if nb_essais == 2 and df_prophet.shape[0] == 36 and rmsse_finale < 1 :
                id = 'serie_raccourcie_36'
            if nb_essais == 3 and df_prophet.shape[0] == 36 and rmsse_finale < 1 :
                id = 'serie_raccourcie_36'
            if nb_essais == 3 and df_prophet.shape[0] == 36 and rmsse_finale == 1 :
                id = 'echec'
            if nb_essais == 2 and df_prophet.shape[0] == 36 and rmsse_finale == 1 :
                id = 'echec'

            # Pour éviter de garder des prévisions aberrantes, on ne sait jamais
            if (forecast_12['yhat_upper'] < forecast_12['yhat']).any() :
                forecast_12 = None
                k += 1

            if forecast_12 is not None :
                resultats_previsions.append(forecast_12)
                if use_mcmc :
                    i += 1

            dico_des_methodes[nom] = id

            if id in ['succes_immediat', 'serie_raccourcie_60', 'serie_raccourcie_36'] :
                # fig = model_prophet.plot(forecast)
                # fig.suptitle(nom, fontsize=14)
                # plt.show()
                pass
            if id == 'echec' :
                # fig = plt.figure()
                # plt.plot(df_prophet['ds'], df_prophet['y'], label='Historique')
                # plt.plot(forecast_12['ds'], forecast_12['yhat'], label='Prévision constante')
                # plt.fill_between(forecast_12['ds'], forecast_12['yhat_lower'], forecast_12['yhat_upper'], alpha=0.2)
                # plt.title(f"{nom} (Prédiction constante)")
                # plt.legend()
                # plt.show()
                pass

            # On affiche l'avancement
            print(f"{nom} faite, plus que {len(list(datasets_groupes.keys())[list(datasets_groupes.keys()).index(nom)+1:])}. RMSSE : {rmsse_finale} ({id}) MCMC : {use_mcmc}, Surajustement : {surajustement}, raccourcissement : {niveau_raccourcissement}")
            if forecast_12 is None :
                print("MAJ : prévisions aberrantes et donc non retenues")
                
            l += 1
            j += rmsse_finale

            # Trouver l'index de la ligne correspondant à la série
            index_ligne = series_temp_features[series_temp_features['nom_serie'] == nom].index

            if not index_ligne.empty :
                index_ligne = index_ligne[0]
                series_temp_features.loc[index_ligne, 'mcmc_utilise'] = use_mcmc
                series_temp_features.loc[index_ligne, 'saisonnalite'] = meilleurs_parametres[1]
                series_temp_features.loc[index_ligne, 'mode_saisonnalite'] = meilleurs_parametres[2] if meilleurs_parametres[1] == True else None
                series_temp_features.loc[index_ligne, 'changepoint_prior_scale'] = meilleurs_parametres[0]
                series_temp_features.loc[index_ligne, 'rmsse'] = rmsse_finale
                series_temp_features.loc[index_ligne, 'id_methode'] = id
                series_temp_features.loc[index_ligne, 'surajustement'] = surajustement
            else:
                print(f"⚠️  La série {nom} n'existe pas dans series_temp_features.")

        except Exception as e :
            print(f'{nom} N\'A PAS PU ÊTRE TRAITEE : {e}')
            recommencer = False

            # Pour éviter un crash plus bas
            use_mcmc = None
            meilleurs_parametres = None
            rmsse_finale = None
            id = None
            surajustement = None

# %%
# Résultats

print(f'{i} séries temporelles sur {len(datasets_groupes)} ont utilisé un mcmc sampling')

df_previsions_complet = pd.concat(resultats_previsions, ignore_index=True)

df_previsions_complet = df_previsions_complet.rename(columns={
    'dataset_nom': 'graphique_id',
    'groupe_id': 'groupe_id',
    'ds': 'gd_date',
    'yhat': 'gd_y',
    'yhat_lower': 'gd_inf',
    'yhat_upper': 'gd_sup'
})

# ATTENTION !!! LES INTERVALLES DE CONFIANCE OBTENUS [yhat_lower ; yhat_upper] NE SONT PAS FORCEMENT CENTRES EN yhat !!!
# En fait, Prophet se base sur les quantiles des distributions empiriques des trajectoires simulées pour les yhat_lower
# et yhat_upper dans le cas de l'utilisation d'un mcmc sampling et garde la médiane pour yhat. DONC pas de symétrie de
# l'intervalle de confiance !!! Et même pour le maximum a poteriori, on n'a pas de centrage de l'intervalle de confiance

series_temp_features = pd.DataFrame(series_temp_features)

print(dico_des_methodes)
if l > 0:
    print(f'Somme de toutes les rmsse : {j} : on prédit en moyenne {(1 - (j/l))*100}% mieux qu\'avec un modèle naïf')
else:
    print("⚠️ Aucune série n'a pu être traitée.")

# Filtrer les entrées où la RMSSE est définie (non None)
rmsse_filtrees = {k: v for k, v in dico_des_rmsse.items() if v is not None}

# S'il en reste, on affiche la meilleure
if rmsse_filtrees :
    meilleur_dataset = min(rmsse_filtrees, key=rmsse_filtrees.get)
    meilleure_rmsse = rmsse_filtrees[meilleur_dataset]
    print(f"Meilleure RMSSE : {meilleure_rmsse:.4f} pour le dataset {meilleur_dataset}")
else :
    print("⚠️ Aucune RMSSE valide disponible pour les séries analysées.")

print(f'RMSSE moyenne : {j/len(datasets_groupes)}')
nb_rmsse_egales_1 = sum(1 for v in dico_des_rmsse.values() if v == 1)
print(f'Proportion de séries totalement imprévisibles : {(nb_rmsse_egales_1/len(datasets_groupes))*100} %')
print(f'{l} séries ont pu être traitées')
print(f"{len(series_temp_features[series_temp_features['id_methode'] == 'echec'])} échecs")
nb_raccourcies = len(series_temp_features[series_temp_features['id_methode'].isin(['serie_raccourcie_60', 'serie_raccourcie_36'])])
print(f"{nb_raccourcies} séries raccourcies")
print(f"{len(series_temp_features[series_temp_features['id_methode'] == 'succes_immediat'])} succès immédiats")
print(f"{k} prévisions étaient aberrantes et ont été supprimées, elles ne seront pas montrées")

print(series_temp_features)
print(df_previsions_complet.head())
print(df_previsions_complet.tail())
# Out:
# 434 séries temporelles sur 689 ont utilisé un mcmc sampling
# {'dataset146visite_grp29': 'succes_immediat', 'dataset146visite_grp35': 'succes_immediat', 'dataset146visite_grp38': 'serie_raccourcie_60', 'dataset146visite_grp47': 'succes_immediat', 'dataset146visite_grp50': 'succes_immediat', 'dataset146visite_grp56': 'succes_immediat', 'dataset146visite_grp67': 'succes_immediat', 'dataset146visite_grp68': 'succes_immediat', 'dataset146visite_grp75': 'succes_immediat', 'dataset146visite_grp76': 'succes_immediat', 'dataset146visite_grp79': 'succes_immediat', 'dataset146visite_grp83': 'succes_immediat', 'dataset146visite_grp86': 'succes_immediat', 'dataset146visite_grp100': 'succes_immediat', 'dataset146visite_grp107': 'succes_immediat', 'dataset146visite_grp108': 'succes_immediat', 'dataset146visite_grp118': 'succes_immediat', 'dataset146visite_grp133': 'succes_immediat', 'dataset146visite_grp153': 'succes_immediat', 'dataset146rdv_grp13': 'succes_immediat', 'dataset146rdv_grp35': 'succes_immediat', 'dataset146rdv_grp83': 'succes_immediat', 'dataset146rdv_grp118': 'serie_raccourcie_36', 'dataset146rdv_grp133': 'succes_immediat', 'dataset146rdv_grp153': 'succes_immediat', 'dataset147_grp13': 'succes_immediat', 'dataset147_grp14': 'serie_raccourcie_60', 'dataset147_grp35': 'serie_raccourcie_36', 'dataset147_grp38': 'echec', 'dataset147_grp39': 'echec', 'dataset147_grp50': 'succes_immediat', 'dataset147_grp133': 'succes_immediat', 'dataset147_grp153': 'succes_immediat', 'dataset148_grp7': 'succes_immediat', 'dataset148_grp13': 'succes_immediat', 'dataset148_grp14': 'succes_immediat', 'dataset148_grp35': 'succes_immediat', 'dataset148_grp38': 'serie_raccourcie_36', 'dataset148_grp43': 'succes_immediat', 'dataset148_grp47': 'echec', 'dataset148_grp50': 'succes_immediat', 'dataset148_grp54': 'succes_immediat', 'dataset148_grp56': 'succes_immediat', 'dataset148_grp64': 'serie_raccourcie_60', 'dataset148_grp67': 'succes_immediat', 'dataset148_grp72': 'succes_immediat', 'dataset148_grp75': 'succes_immediat', 'dataset148_grp76': 'succes_immediat', 'dataset148_grp79': 'succes_immediat', 'dataset148_grp80': 'succes_immediat', 'dataset148_grp83': 'succes_immediat', 'dataset148_grp85': 'serie_raccourcie_36', 'dataset148_grp86': 'serie_raccourcie_60', 'dataset148_grp89': 'succes_immediat', 'dataset148_grp100': 'succes_immediat', 'dataset148_grp101': 'succes_immediat', 'dataset148_grp107': 'succes_immediat', 'dataset148_grp109': 'serie_raccourcie_36', 'dataset148_grp114': 'succes_immediat', 'dataset148_grp118': 'succes_immediat', 'dataset148_grp128': 'succes_immediat', 'dataset148_grp138': 'succes_immediat', 'dataset148_grp153': 'succes_immediat', 'dataset148_grp172': 'succes_immediat', 'dataset149_grp7': 'succes_immediat', 'dataset149_grp13': 'succes_immediat', 'dataset149_grp14': 'succes_immediat', 'dataset149_grp29': 'succes_immediat', 'dataset149_grp35': 'serie_raccourcie_60', 'dataset149_grp38': 'serie_raccourcie_36', 'dataset149_grp43': 'succes_immediat', 'dataset149_grp47': 'echec', 'dataset149_grp50': 'succes_immediat', 'dataset149_grp56': 'succes_immediat', 'dataset149_grp60': 'succes_immediat', 'dataset149_grp64': 'serie_raccourcie_60', 'dataset149_grp67': 'succes_immediat', 'dataset149_grp72': 'succes_immediat', 'dataset149_grp75': 'succes_immediat', 'dataset149_grp76': 'succes_immediat', 'dataset149_grp79': 'succes_immediat', 'dataset149_grp80': 'succes_immediat', 'dataset149_grp83': 'succes_immediat', 'dataset149_grp85': 'succes_immediat', 'dataset149_grp86': 'echec', 'dataset149_grp89': 'succes_immediat', 'dataset149_grp100': 'echec', 'dataset149_grp101': 'succes_immediat', 'dataset149_grp107': 'succes_immediat', 'dataset149_grp109': 'serie_raccourcie_36', 'dataset149_grp114': 'serie_raccourcie_36', 'dataset149_grp118': 'succes_immediat', 'dataset149_grp128': 'succes_immediat', 'dataset149_grp134': 'succes_immediat', 'dataset149_grp138': 'succes_immediat', 'dataset149_grp153': 'succes_immediat', 'dataset149_grp172': 'succes_immediat', 'dataset150_grp7': 'succes_immediat', 'dataset150_grp13':  ...
# Somme de toutes les rmsse : 418.70026674363527 : on prédit en moyenne 39.05381852348832% mieux qu'avec un modèle naïf
# Meilleure RMSSE : 0.0212 pour le dataset dataset156action5_grp128
# RMSSE moyenne : 0.6076926948383676
# Proportion de séries totalement imprévisibles : 9.433962264150944 %
# 687 séries ont pu être traitées
# 65 échecs
# 144 séries raccourcies
# 478 succès immédiats
# 3 prévisions étaient aberrantes et ont été supprimées, elles ne seront pas montrées
#                            nom_serie  groupe_id  longueur_serie  \
# 0             dataset146visite_grp29         29             188
# 1             dataset146visite_grp35         35             181
# 2             dataset146visite_grp38         38             204
# 3             dataset146visite_grp47         47             152
# 4             dataset146visite_grp50         50             156
# ..                               ...        ...             ...
# 684   dataset164quadriexclusif_grp39         39             106
# 685   dataset164quadriexclusif_grp50         50             154
# 686   dataset164quadriexclusif_grp56         56             204
# 687  dataset164quadriexclusif_grp114        114              49
# 688  dataset164quadriexclusif_grp133        133              61
#
#      mean_abs_diff  std_normalise  std_normalise_first_half  \
# 0         4.000000       0.703946                  0.766521
# 1        10.083333       0.543934                  0.634311
# 2        83.133005       0.645064                  1.022729
# 3         5.940397       0.605898                  0.679773
# 4        15.670968       0.667443                  0.417841
# ..             ...            ...                       ...
# 684       0.190476       0.404755                  0.496835
# 685       0.241830       0.465195                  0.384907
# 686       0.310345       0.472021                  0.543903
# 687       0.145833       0.443155                  0.353861
# 688       0.283333       0.511120                  0.558619
#
#      std_normalise_second_half  std_normalise_ecart    moyenne1    moyenne2  \
# 0                     0.580183             0.186338    9.712766    8.058511
# 1                     0.456052             0.178259   23.944444   28.148352
# 2                     0.287664             0.735065  209.691176  418.960784
# 3                     0.535558             0.144215   10.006579   11.855263
# 4                     0.575614             0.157773   64.102564   23.730769
# ..                         ...                  ...         ...         ...
# 684                   0.297949             0.198886    2.113208    2.188679
# 685                   0.393208             0.008300    3.987013    2.435065
# 686                   0.252599             0.291303    3.137255    6.000000
# 687                   0.494309             0.140448    1.250000    1.440000
# 688                   0.312602             0.246016    1.466667    2.903226
#
#      ...  fft_dominant_amp  fft_dominant_phase  shannon_entropy  mcmc_utilise  \
# 0    ...        378.752349            1.771944         1.838656          True
# 1    ...        997.505443            2.776892         1.966724         False
# 2    ...      19016.923836            2.134162         2.166942          True
# 3    ...        329.694819            3.121939         1.884520         False
# 4    ...       2463.006165           -1.881775         1.994511         False
# ..   ...               ...                 ...              ...           ...
# 684  ...         29.024393           -2.182951         1.228306         False
# 685  ...        105.092735           -1.732228         1.671197         False
# 686  ...        160.978158            1.807904         1.941439         False
# 687  ...          9.753816            0.129560         0.746721         False
# 688  ...         36.775273            1.714787         1.382843          True
#
#      saisonnalite  mode_saisonnalite  changepoint_prior_scale     rmsse  \
# 0            True     multiplicative                     0.05  0.666927
# 1           False               None                     0.05  0.719142
# 2            True           additive                     0.05  0.549287
# 3           False               None                     0.03  0.562822
# 4           False               None                     0.03  0.162885
# ..            ...                ...                      ...       ...
# 684         False               None                     0.15  1.000000
# 685         False               None                     0.05  0.717014
# 686          True     multiplicative                     0.15  1.000000
# 687         False               None                     0.05  0.999699
# 688          True     multiplicative                     0.15  0.294282
#
#               id_methode  surajustement
# 0        succes_immediat          False
# 1        succes_immediat          False
# 2    serie_raccourcie_60          False
# 3        succes_immediat          False
# 4        succes_immediat          False
# ..                   ...            ...
# 684                echec          False
# 685      succes_immediat          False
# 686                echec          False
# 687      succes_immediat          False
# 688  serie_raccourcie_36           True
#
# [689 rows x 34 columns]
#      gd_date       gd_y    gd_inf     gd_sup            graphique_id  \
# 0 2025-12-01   8.162814  0.897830  15.820875  dataset146visite_grp29
# 1 2026-01-01  10.569183  2.690929  18.295820  dataset146visite_grp29
# 2 2026-02-01  13.218024  5.142073  20.354557  dataset146visite_grp29
# 3 2026-03-01  10.303404  2.330336  17.959768  dataset146visite_grp29
# 4 2026-04-01   8.378138  0.705220  16.154658  dataset146visite_grp29
#
#    groupe_id
# 0         29
# 1         29
# 2         29
# 3         29
# 4         29
#         gd_date      gd_y    gd_inf    gd_sup  \
# 8203 2026-08-01  1.792454  1.075095  2.532301
# 8204 2026-09-01  1.806599  1.107133  2.554465
# 8205 2026-10-01  1.820287  1.060378  2.547045
# 8206 2026-11-01  1.834432  1.109914  2.522549
# 8207 2026-12-01  1.848121  1.154651  2.534663
#
#                          graphique_id  groupe_id
# 8203  dataset164quadriexclusif_grp114        114
# 8204  dataset164quadriexclusif_grp114        114
# 8205  dataset164quadriexclusif_grp114        114
# 8206  dataset164quadriexclusif_grp114        114
# 8207  dataset164quadriexclusif_grp114        114

# %%
print(series_temp_features)

series_temp_features.to_excel("series_temp_features.xlsx", index=False)
# Out:
#                            nom_serie  groupe_id  longueur_serie  \
# 0             dataset146visite_grp29         29             188
# 1             dataset146visite_grp35         35             181
# 2             dataset146visite_grp38         38             204
# 3             dataset146visite_grp47         47             152
# 4             dataset146visite_grp50         50             156
# ..                               ...        ...             ...
# 684   dataset164quadriexclusif_grp39         39             106
# 685   dataset164quadriexclusif_grp50         50             154
# 686   dataset164quadriexclusif_grp56         56             204
# 687  dataset164quadriexclusif_grp114        114              49
# 688  dataset164quadriexclusif_grp133        133              61
#
#      mean_abs_diff  std_normalise  std_normalise_first_half  \
# 0         4.000000       0.703946                  0.766521
# 1        10.083333       0.543934                  0.634311
# 2        83.133005       0.645064                  1.022729
# 3         5.940397       0.605898                  0.679773
# 4        15.670968       0.667443                  0.417841
# ..             ...            ...                       ...
# 684       0.190476       0.404755                  0.496835
# 685       0.241830       0.465195                  0.384907
# 686       0.310345       0.472021                  0.543903
# 687       0.145833       0.443155                  0.353861
# 688       0.283333       0.511120                  0.558619
#
#      std_normalise_second_half  std_normalise_ecart    moyenne1    moyenne2  \
# 0                     0.580183             0.186338    9.712766    8.058511
# 1                     0.456052             0.178259   23.944444   28.148352
# 2                     0.287664             0.735065  209.691176  418.960784
# 3                     0.535558             0.144215   10.006579   11.855263
# 4                     0.575614             0.157773   64.102564   23.730769
# ..                         ...                  ...         ...         ...
# 684                   0.297949             0.198886    2.113208    2.188679
# 685                   0.393208             0.008300    3.987013    2.435065
# 686                   0.252599             0.291303    3.137255    6.000000
# 687                   0.494309             0.140448    1.250000    1.440000
# 688                   0.312602             0.246016    1.466667    2.903226
#
#      ...  fft_dominant_amp  fft_dominant_phase  shannon_entropy  mcmc_utilise  \
# 0    ...        378.752349            1.771944         1.838656          True
# 1    ...        997.505443            2.776892         1.966724         False
# 2    ...      19016.923836            2.134162         2.166942          True
# 3    ...        329.694819            3.121939         1.884520         False
# 4    ...       2463.006165           -1.881775         1.994511         False
# ..   ...               ...                 ...              ...           ...
# 684  ...         29.024393           -2.182951         1.228306         False
# 685  ...        105.092735           -1.732228         1.671197         False
# 686  ...        160.978158            1.807904         1.941439         False
# 687  ...          9.753816            0.129560         0.746721         False
# 688  ...         36.775273            1.714787         1.382843          True
#
#      saisonnalite  mode_saisonnalite  changepoint_prior_scale     rmsse  \
# 0            True     multiplicative                     0.05  0.666927
# 1           False               None                     0.05  0.719142
# 2            True           additive                     0.05  0.549287
# 3           False               None                     0.03  0.562822
# 4           False               None                     0.03  0.162885
# ..            ...                ...                      ...       ...
# 684         False               None                     0.15  1.000000
# 685         False               None                     0.05  0.717014
# 686          True     multiplicative                     0.15  1.000000
# 687         False               None                     0.05  0.999699
# 688          True     multiplicative                     0.15  0.294282
#
#               id_methode  surajustement
# 0        succes_immediat          False
# 1        succes_immediat          False
# 2    serie_raccourcie_60          False
# 3        succes_immediat          False
# 4        succes_immediat          False
# ..                   ...            ...
# 684                echec          False
# 685      succes_immediat          False
# 686                echec          False
# 687      succes_immediat          False
# 688  serie_raccourcie_36           True
#
# [689 rows x 34 columns]

# %%
# Il nous faut maintenant une correspondance entre les numéros des graphiques dans Superset et les noms datasetX_grpX
# Attention, ici on autoincrémente les numéros des graphiques de prévision à partir du numéro 168 mais si on vient à ajouter 
# Dans les graphiques de base un nouveau graphique, son identifiant superset sera 206 (à chaque fois qu'on ajoute un graphique)
# dans Superset, son identifiant est : identifiant du dernier graphique créé + 1. 
# Donc ici, le prochain graphique de base sera le 206, et donc si on veut dans le même temps ajouter son graphique de
# prévisions, il faur=dra lui attribuer comme identifiant le numéro 207 car ce sera le graphique créé juste après 

previsions_nom = [
    'dataset146visite',
    'dataset146proposition',
    'dataset146rdv',
    'dataset147',
    'dataset148',
    'dataset149',
    'dataset150',
    'dataset151',
    'dataset152',
    'dataset153',
    'dataset154',
    'dataset155',
    'dataset156action1',
    'dataset156action2',
    'dataset156action3',
    'dataset156action4',
    'dataset156action5',
    'dataset157',
    'dataset158offres',
    'dataset158demandes',
    'dataset158mandats',
    'dataset159offres',
    'dataset159demandes',
    'dataset159mandats',
    'dataset160rejete',
    'dataset160npai',
    'dataset161delivres',
    'dataset161cliques',
    'dataset161ouverts',
    'dataset161rejetes',
    'dataset164simple',
    'dataset164demande',
    'dataset164exclusif',
    'dataset164coexclusif',
    'dataset164triexclusif',
    'dataset164preferentiel',
    'dataset164delegation',
    'dataset164quadriexclusif'
]

# On auto-incrémente les identifiants à partir de 168 car jusque 166, c'est les graphiques des données historiques, 
# ensuite on a le 167 qui était un graphique de test
# Et donc nos graphiques de prévisions auront des identifiants qui commenceront à 168

df_ids = pd.DataFrame({
    'nom': previsions_nom,
    'id': list(range(168, 168 + len(previsions_nom)))
})

# %%
# On rouvre la connexion pyodbc à SQL Server

conn_str = (
    "DRIVER={ODBC Driver 17 for SQL Server};"
    "SERVER=172.16.11.34;"
    "DATABASE=Superset;"
    "UID=quentin;"
    "PWD={Barbidur1;SQL}"
)

conn = pyodbc.connect(conn_str)
cursor = conn.cursor()

for _, row in df_ids.iterrows():
    nom = row['nom']
    id = row['id']
    cursor.execute(
        "INSERT INTO previsions_graphiques_noms (previsions_graphique_id, previsions_graphique_nom) VALUES (?, ?)",
        (id, nom)
    )
conn.commit()

# %%
# On remplace les noms datasetX..._grpX par des noms de la forme : datasetX (pas besoin de savoir le groupe dans le nom,
# de toute facon il y a dejà une colonne groupe_id et on filtrera une fois dans Superset)

# ATTENTION ! ON IDENTIFIE ICI LES GRAPHIQUES DE PREVISIONS, PAS LES GRAPHIQUES HISTORIQUES AUXQUELS SONT RELIEES LES PREVISIONS !

# On enlève les _grpX des noms dans df_previsions_complet
df_previsions_complet['graphique_id'] = df_previsions_complet['graphique_id'].str.replace(r'_grp\d+$', '', regex=True)

# On crée un dico de correspondance avec df_ids
mapping_ids = df_ids.set_index('nom')['id']

# On remplace les noms par les vrais identifiants
df_previsions_complet['graphique_id'] = df_previsions_complet['graphique_id'].map(mapping_ids)

df_previsions_complet = df_previsions_complet.rename(columns={
    'gd_date' : 'prevision_date',
    'gd_y' : 'yhat',
    'gd_inf' : 'yhat_inf',
    'gd_sup' : 'yhat_sup',
    'graphique_id' : 'previsions_graphique_id'
})

print(df_previsions_complet)
# Out:
#      prevision_date       yhat  yhat_inf   yhat_sup  previsions_graphique_id  \
# 0        2025-12-01   8.162814  0.897830  15.820875                      168
# 1        2026-01-01  10.569183  2.690929  18.295820                      168
# 2        2026-02-01  13.218024  5.142073  20.354557                      168
# 3        2026-03-01  10.303404  2.330336  17.959768                      168
# 4        2026-04-01   8.378138  0.705220  16.154658                      168
# ...             ...        ...       ...        ...                      ...
# 8203     2026-08-01   1.792454  1.075095   2.532301                      205
# 8204     2026-09-01   1.806599  1.107133   2.554465                      205
# 8205     2026-10-01   1.820287  1.060378   2.547045                      205
# 8206     2026-11-01   1.834432  1.109914   2.522549                      205
# 8207     2026-12-01   1.848121  1.154651   2.534663                      205
#
#       groupe_id
# 0            29
# 1            29
# 2            29
# 3            29
# 4            29
# ...         ...
# 8203        114
# 8204        114
# 8205        114
# 8206        114
# 8207        114
#
# [8208 rows x 6 columns]

# %%
df_previsions_complet.to_excel("df_previsions_complet.xlsx", index=False)

# %% [markdown]
# **Pour finir, on insère les données générées dans la table dbo.t_graphique_donnee**

# %%
# Compter deux minutes d'exécution

# On définit une insertion SQL qu'on effectuera ultérieurement, quand les ? seront précisés
insert_sql = """
    INSERT INTO previsions_graphiques (previsions_graphique_id, groupe_id, prevision_date, yhat, yhat_inf, yhat_sup)
    VALUES (?, ?, ?, ?, ?, ?)
"""

print("Insertion des nouvelles données...")

# Parcours des lignes du DataFrame
for _, row in df_previsions_complet.iterrows():
    cursor.execute(insert_sql, (
        int(row['previsions_graphique_id']),
        int(row['groupe_id']),
        row['prevision_date'],
        float(row['yhat']),
        float(row['yhat_inf']),
        float(row['yhat_sup'])
    ))

conn.commit()
cursor.close()
conn.close()

# On ferme la connexion

print("Données insérées avec succès.")
# Out:
# Insertion des nouvelles données...
# Données insérées avec succès.
